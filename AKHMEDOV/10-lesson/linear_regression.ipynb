# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/a1/Desktop/MLFoundation/cleaned_merged_seasons.csv')
# Out:
# /var/folders/5h/9l3v88x94dgfs7159k0nvb2w0000gn/T/ipykernel_14050/174375154.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/Users/a1/Desktop/MLFoundation/cleaned_merged_seasons.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96169 entries, 0 to 96168
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   season_x           96169 non-null  object
#  1   name               96169 non-null  object
#  2   position           96169 non-null  object
#  3   team_x             76317 non-null  object
#  4   assists            96169 non-null  int64
#  5   bonus              96169 non-null  int64
#  6   bps                96169 non-null  int64
#  7   clean_sheets       96169 non-null  int64
#  8   creativity         96169 non-null  float64
#  9   element            96169 non-null  int64
#  10  fixture            96169 non-null  int64
#  11  goals_conceded     96169 non-null  int64
#  12  goals_scored       96169 non-null  int64
#  13  ict_index          96169 non-null  float64
#  14  influence          96169 non-null  float64
#  15  kickoff_time       96169 non-null  object
# ...

# %% [markdown]
# # data bn tanishuv

# %%
df.head()
# Out:
#   season_x                name position team_x  assists  bonus  bps  \
# 0  2016-17     Aaron Cresswell      DEF    NaN        0      0    0
# 1  2016-17        Aaron Lennon      MID    NaN        0      0    6
# 2  2016-17        Aaron Ramsey      MID    NaN        0      0    5
# 3  2016-17  Abdoulaye Doucouré      MID    NaN        0      0    0
# 4  2016-17        Adam Forshaw      MID    NaN        0      0    3
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0      454  ...           2.0     0.0             0
# 1             0         0.3      142  ...           1.0     0.0             1
# 2             0         4.9       16  ...           3.0    23.0             2
# 3             0         0.0      482  ...           1.0     0.0             0
# 4             0         1.3      286  ...           1.0     0.0             1
#
#    transfers_balance  transfers_in transfers_out  value  was_home  \
# ...

# %%
df.drop(columns=['season_x', 'name'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96169 entries, 0 to 96168
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   position           96169 non-null  object
#  1   team_x             76317 non-null  object
#  2   assists            96169 non-null  int64
#  3   bonus              96169 non-null  int64
#  4   bps                96169 non-null  int64
#  5   clean_sheets       96169 non-null  int64
#  6   creativity         96169 non-null  float64
#  7   element            96169 non-null  int64
#  8   fixture            96169 non-null  int64
#  9   goals_conceded     96169 non-null  int64
#  10  goals_scored       96169 non-null  int64
#  11  ict_index          96169 non-null  float64
#  12  influence          96169 non-null  float64
#  13  kickoff_time       96169 non-null  object
#  14  minutes            96169 non-null  int64
#  15  opponent_team      96169 non-null  int64
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# position                 0
# team_x               19852
# assists                  0
# bonus                    0
# bps                      0
# clean_sheets             0
# creativity               0
# element                  0
# fixture                  0
# goals_conceded           0
# goals_scored             0
# ict_index                0
# influence                0
# kickoff_time             0
# minutes                  0
# opponent_team            0
# opp_team_name            0
# own_goals                0
# penalties_missed         0
# penalties_saved          0
# red_cards                0
# round                    0
# saves                    0
# selected                 0
# team_a_score             0
# team_h_score             0
# threat                   0
# total_points             0
# transfers_balance        0
# transfers_in             0
# transfers_out            0
# value                    0
# was_home                 0
# yellow_cards             0
# ...

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
cols_to_process = [col for col in df.columns if df[col].dtype == 'object']

for col in cols_to_process:
    if df[col].nunique() <= 5:
        dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
        df = pd.concat([df.drop(columns=col), dummies], axis=1)
    else:
        df[col] = encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96169 entries, 0 to 96168
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   team_x             96169 non-null  int64
#  1   assists            96169 non-null  int64
#  2   bonus              96169 non-null  int64
#  3   bps                96169 non-null  int64
#  4   clean_sheets       96169 non-null  int64
#  5   creativity         96169 non-null  float64
#  6   element            96169 non-null  int64
#  7   fixture            96169 non-null  int64
#  8   goals_conceded     96169 non-null  int64
#  9   goals_scored       96169 non-null  int64
#  10  ict_index          96169 non-null  float64
#  11  influence          96169 non-null  float64
#  12  kickoff_time       96169 non-null  int64
#  13  minutes            96169 non-null  int64
#  14  opponent_team      96169 non-null  int64
#  15  opp_team_name      96169 non-null  int64
# ...

# %% [markdown]
# # Scaling

# %%
df.head()
# Out:
#    team_x  assists  bonus  bps  clean_sheets  creativity  element  fixture  \
# 0      25        0      0    0             0         0.0      454       10
# 1      25        0      0    6             0         0.3      142        3
# 2      25        0      0    5             0         4.9       16        8
# 3      25        0      0    0             0         0.0      482        7
# 4      25        0      0    3             0         1.3      286        6
#
#    goals_conceded  goals_scored  ...  transfers_out  value  was_home  \
# 0               0             0  ...              0     55     False
# 1               0             0  ...              0     60      True
# 2               3             0  ...              0     80      True
# 3               0             0  ...              0     50     False
# 4               1             0  ...              0     45      True
#
#    yellow_cards  GW  position_DEF  position_FWD  position_GK  position_GKP  \
# ...

# %%
 from sklearn.preprocessing import MinMaxScaler
 scaler = MinMaxScaler()

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns.drop('goals', errors='ignore')

# %%
df[num_col] = scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#    team_x  assists  bonus       bps  clean_sheets  creativity   element  \
# 0     1.0      0.0    0.0  0.140940           0.0    0.000000  0.583012
# 1     1.0      0.0    0.0  0.181208           0.0    0.001755  0.181467
# 2     1.0      0.0    0.0  0.174497           0.0    0.028672  0.019305
# 3     1.0      0.0    0.0  0.140940           0.0    0.000000  0.619048
# 4     1.0      0.0    0.0  0.161074           0.0    0.007607  0.366795
#
#     fixture  goals_conceded  goals_scored  ...  transfers_out     value  \
# 0  0.023747        0.000000           0.0  ...            0.0  0.187500
# 1  0.005277        0.000000           0.0  ...            0.0  0.239583
# 2  0.018470        0.333333           0.0  ...            0.0  0.447917
# 3  0.015831        0.000000           0.0  ...            0.0  0.135417
# 4  0.013193        0.111111           0.0  ...            0.0  0.083333
#
#    was_home  yellow_cards   GW  position_DEF  position_FWD  position_GK  \
# ...

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# # Training

# %%
x = df.drop('goals_scored', axis=1)
y = df['goals_scored']

print("Features shape:", x.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (96169, 38)
# Target shape: (96169,)

# %%
x = df.drop('goals_scored', axis=1)
y = df['goals_scored']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Prediction

# %%
y_pred = lr.predict(x_test)

# %%
y_pred[1]
# Out:
# np.float64(0.0012432176933902528)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.013865095932638577
# Mean Squared Error: 0.0005080592693511028
# R-squared: 0.8456803046680481
