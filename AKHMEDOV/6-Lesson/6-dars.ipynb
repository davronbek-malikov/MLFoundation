# %%
# 1. Son 2 ga bo‘linsa
n = int(input())
print("yaxshi" if n % 2 == 0 else "yomon")

# 2. Son musbat bo‘lsa
print("yaxshi" if n > 0 else "yomon")

# 3. Son 3 va 5 ga bo‘linsa
print("yaxshi" if n % 3 == 0 and n % 5 == 0 else "yomon")

# 4. So‘z bosh harfi 'a'
s = input()
print("yaxshi" if s[0] == 'a' else "yomon")

# 5. So‘z oxirgi harfi 'a'
print("yaxshi" if s[-1] == 'a' else "yomon")

# 6. So‘z bosh harfi 'b' va oxiri 'a'
print("yaxshi" if s[0] == 'b' and s[-1] == 'a' else "yomon")

# 7. Son musbatligini isbotlash
print(n > 0)

# 8. Son manfiyligini isbotlash
print(n < 0)

# 9. Son nol ekanligini isbotlash
print(n == 0)

# 10. Son 2 ga bo‘linishini isbotlash
print(n % 2 == 0)

# %%
# 1. Mean orqali to‘ldirish
df['col'].fillna(df['col'].mean(), inplace=True)

# 2. Mode orqali to‘ldirish
df['col'].fillna(df['col'].mode()[0], inplace=True)

# 3. Median orqali to‘ldirish
df['col'].fillna(df['col'].median(), inplace=True)

# 4. Fixed qiymat bilan to‘ldirish
df['col'].fillna(0, inplace=True)

# 5. Ustunni tashlab yuborish
df.drop('col', axis=1, inplace=True)

# 6. Qatorni tashlab yuborish
df.dropna(inplace=True)
