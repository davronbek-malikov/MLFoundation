# %% [markdown]
# Data Types

# %%
#int
#float
#str
#boolean

# %%
#int
a = 5
type(a)
# Out:
# int

# %%
#float
b = 4.7
type(b)
# Out:
# float

# %%
#str
c = "Hello, World!"
type(c)
# Out:
# str

# %%
#Boolean
1>3
# Out:
# False

# %%
3==3
# Out:
# True

# %%
3!=3
# Out:
# False

# %% [markdown]
# Operation

# %%
#Math (+, -, *, /, **, //, %)
a=4
b=3
print(a/b) #6
# Out:
# 1.3333333333333333

# %%
print(a//b) #butun qismii olish
# Out:
# 1

# %%
print(a%b) #qoldiqni olish
# Out:
# 1

# %%
print(a**b)
# Out:
# 64

# %%
print(pow(a,b)) #a ning b-darajasi
# Out:
# 64

# %% [markdown]
# LOGIC OPERATIONS

# %%
# and Ikki shart ham to'g'ri bo'lishi kerak
# or Shartlardan biri to'g'ri bo'lsa kifoya
# not Shartni inkor qiladi

# %% [markdown]
#     comperative operations

# %%
#<, >, <=, >=, ==, !=

# %% [markdown]
# INDEXING

# %%
s='Hello'
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# 'o'

# %%
import pandas as pd

# %%
df=pd.read_csv('2-dars/WA_Fn-UseC_-Telco-Customer-Churn.csv.xls')
