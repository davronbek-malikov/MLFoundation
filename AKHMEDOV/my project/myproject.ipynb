# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/a1/Desktop/MLFoundation/autos.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                371528 non-null  int64
#  1   dateCrawled          371528 non-null  object
#  2   name                 371528 non-null  object
#  3   seller               371528 non-null  object
#  4   offerType            371528 non-null  object
#  5   price                371528 non-null  int64
#  6   abtest               371528 non-null  object
#  7   vehicleType          333659 non-null  object
#  8   yearOfRegistration   371528 non-null  int64
#  9   gearbox              351319 non-null  object
#  10  powerPS              371528 non-null  int64
#  11  model                351044 non-null  object
#  12  kilometer            371528 non-null  int64
#  13  monthOfRegistration  371528 non-null  int64
#  14  fuelType             338142 non-null  object
# ...

# %%
for col in df.columns:
    if df[col].nunique() <=10:
        print(col, df[col].unique())
# Out:
# seller ['privat' 'gewerblich']
# offerType ['Angebot' 'Gesuch']
# abtest ['test' 'control']
# vehicleType [nan 'coupe' 'suv' 'kleinwagen' 'limousine' 'cabrio' 'bus' 'kombi'
#  'andere']
# gearbox ['manuell' 'automatik' nan]
# fuelType ['benzin' 'diesel' nan 'lpg' 'andere' 'hybrid' 'cng' 'elektro']
# notRepairedDamage [nan 'ja' 'nein']
# nrOfPictures [0]

# %%
df.head()
# Out:
#    index          dateCrawled                            name  seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   offerType  price abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    model kilometer  monthOfRegistration  fuelType       brand  \
# ...

# %%
# 1. Simple list of column names
print("Column names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['index', 'dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode', 'lastSeen']

# %%
df["price"].describe()
# Out:
# count    3.715280e+05
# mean     1.729514e+04
# std      3.587954e+06
# min      0.000000e+00
# 25%      1.150000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      2.147484e+09
# Name: price, dtype: float64

# %%
df = df[(df["price"] > 100) & (df["price"] > 100000)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 403 entries, 996 to 368656
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                403 non-null    int64
#  1   dateCrawled          403 non-null    object
#  2   name                 403 non-null    object
#  3   seller               403 non-null    object
#  4   offerType            403 non-null    object
#  5   price                403 non-null    int64
#  6   abtest               403 non-null    object
#  7   vehicleType          361 non-null    object
#  8   yearOfRegistration   403 non-null    int64
#  9   gearbox              336 non-null    object
#  10  powerPS              403 non-null    int64
#  11  model                294 non-null    object
#  12  kilometer            403 non-null    int64
#  13  monthOfRegistration  403 non-null    int64
#  14  fuelType             338 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# index                    0
# dateCrawled              0
# name                     0
# seller                   0
# offerType                0
# price                    0
# abtest                   0
# vehicleType             42
# yearOfRegistration       0
# gearbox                 67
# powerPS                  0
# model                  109
# kilometer                0
# monthOfRegistration      0
# fuelType                65
# brand                    0
# notRepairedDamage       64
# dateCreated              0
# nrOfPictures             0
# postalCode               0
# lastSeen                 0
# dtype: int64

# %%
df.drop(columns=["index", "nrOfPictures", "postalCode"], inplace=True)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Handling Missing VAlues

# %%
df.isnull().sum()
# Out:
# dateCrawled              0
# name                     0
# seller                   0
# offerType                0
# price                    0
# abtest                   0
# vehicleType             42
# yearOfRegistration       0
# gearbox                 67
# powerPS                  0
# model                  109
# kilometer                0
# monthOfRegistration      0
# fuelType                65
# brand                    0
# notRepairedDamage       64
# dateCreated              0
# lastSeen                 0
# dtype: int64

# %%
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype == "object":
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
                df[coll].fillnadf([col].mean())
# Out:
# /var/folders/5h/9l3v88x94dgfs7159k0nvb2w0000gn/T/ipykernel_18977/1347267251.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 403 entries, 996 to 368656
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          403 non-null    object
#  1   name                 403 non-null    object
#  2   seller               403 non-null    object
#  3   offerType            403 non-null    object
#  4   price                403 non-null    int64
#  5   abtest               403 non-null    object
#  6   vehicleType          403 non-null    object
#  7   yearOfRegistration   403 non-null    int64
#  8   gearbox              403 non-null    object
#  9   powerPS              403 non-null    int64
#  10  model                403 non-null    object
#  11  kilometer            403 non-null    int64
#  12  monthOfRegistration  403 non-null    int64
#  13  fuelType             403 non-null    object
#  14  brand                403 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# lastSeen               0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
df.nunique()
# Out:
# dateCrawled            403
# name                   366
# seller                   1
# offerType                1
# price                  212
# abtest                   2
# vehicleType              8
# yearOfRegistration      74
# gearbox                  2
# powerPS                140
# model                   45
# kilometer               13
# monthOfRegistration     13
# fuelType                 6
# brand                   24
# notRepairedDamage        2
# dateCreated             35
# lastSeen               402
# dtype: int64

# %%
for col in df.columns:
 if df[col].nunique() <= 5:
    print(col, df[col].unique())
# Out:
# seller ['privat']
# offerType ['Angebot']
# abtest ['test' 'control']
# gearbox ['manuell' 'automatik']
# notRepairedDamage ['nein' 'ja']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for col in df.columns:
    if df[col].dtype == "object":
        if df[col].nunique() <= 5:
            dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
            df = pd.concat([df.drop(columns=[col]), dummies], axis=1)
        else:
            df[col] = encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#       dateCrawled  name   price  vehicleType  yearOfRegistration  powerPS  \
# 996           235   276  139997            3                2010      435
# 1846           55    33  579000            3                1980      277
# 2735          114    66  120000            2                2012      666
# 4359          263   161  185000            2                1971      170
# 5907          190   183  119000            2                1973      140
#
#       model  kilometer  monthOfRegistration  fuelType  ...  dateCreated  \
# 996       5      20000                    3         1  ...           21
# 1846     11      20000                   12         1  ...            6
# 2735      5      20000                    7         1  ...           12
# 4359     37       5000                    7         1  ...           23
# 5907      5     150000                    4         1  ...           17
#
#       lastSeen  seller_privat  offerType_Angebot  abtest_control  abtest_test  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 403 entries, 996 to 368656
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   dateCrawled             403 non-null    int64
#  1   name                    403 non-null    int64
#  2   price                   403 non-null    int64
#  3   vehicleType             403 non-null    int64
#  4   yearOfRegistration      403 non-null    int64
#  5   powerPS                 403 non-null    int64
#  6   model                   403 non-null    int64
#  7   kilometer               403 non-null    int64
#  8   monthOfRegistration     403 non-null    int64
#  9   fuelType                403 non-null    int64
#  10  brand                   403 non-null    int64
#  11  dateCreated             403 non-null    int64
#  12  lastSeen                403 non-null    int64
#  13  seller_privat           403 non-null    int64
# ...

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler
# Out:
# MinMaxScaler()

# %%
num_cols=df.select_dtypes(include=["int64"]).columns.drop("price")

# %%
num_cols
# Out:
# Index(['dateCrawled', 'name', 'vehicleType', 'yearOfRegistration', 'powerPS',
#        'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'dateCreated', 'lastSeen', 'seller_privat', 'offerType_Angebot',
#        'abtest_control', 'abtest_test', 'gearbox_automatik', 'gearbox_manuell',
#        'notRepairedDamage_ja', 'notRepairedDamage_nein'],
#       dtype='object')

# %%
 df[num_cols]=scaler.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#       dateCrawled      name   price  vehicleType  yearOfRegistration  \
# 996      0.584577  0.756164  139997     0.428571            0.112235
# 1846     0.136816  0.090411  579000     0.428571            0.108901
# 2735     0.283582  0.180822  120000     0.285714            0.112457
# 4359     0.654229  0.441096  185000     0.285714            0.107901
# 5907     0.472637  0.501370  119000     0.285714            0.108123
#
#        powerPS     model  kilometer  monthOfRegistration  fuelType  ...  \
# 996   0.037435  0.113636   0.103448             0.250000       0.2  ...
# 1846  0.023838  0.250000   0.103448             1.000000       0.2  ...
# 2735  0.057315  0.113636   0.103448             0.583333       0.2  ...
# 4359  0.014630  0.840909   0.000000             0.583333       0.2  ...
# 5907  0.012048  0.113636   1.000000             0.333333       0.2  ...
#
#       dateCreated  lastSeen  seller_privat  offerType_Angebot  abtest_control  \
# ...

# %% [markdown]
# # Model Selection

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# # Training

# %%
x=df.drop("price", axis=1)

# %%
y=df["price"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (322, 20)

# %%
y_train.shape
# Out:
# (322,)

# %%
x_test.shape
# Out:
# (81, 20)

# %%
y_test.shape
# Out:
# (81,)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Prediction

# %%
y_predict=lr.predict(x_test)

# %%
y_predict
# Out:
# array([11360396.15562418,  1089799.69991119, 11591840.98919784,
#        21098673.08782574,  3797363.16776165, -2447258.28862765,
#         6929497.37466177, -1159243.17975003,  5736316.69710627,
#         4140020.27768034,   748239.57003935,  2582254.25256958,
#        -3861940.40107554, 17019493.18135817, 12100935.04487339,
#        13202038.82004445,  9627999.11539226, 11370469.43180241,
#         8049633.60116049,  6320149.50768773, 17388693.61962637,
#        12718901.71804399,  7519164.92526291, 11668191.17397875,
#        11742568.45491788, -1450836.04704414, 10844567.96769169,
#        -2053511.16325022,  2292942.20674351, 23003567.32463808,
#         -338875.43906557, 10692265.51895601,  2789803.71616962,
#         1908755.0546637 , 11405453.14821279,   668481.76887577,
#         9584569.20480388, -4859585.73783953, -3718085.38353717,
#         1239322.55938353,  6150019.57238326,  3041398.65095134,
#         5818920.08136862, 21842910.96651295, -5247340.19851787,
# ...

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test, y_predict)
mse=mean_squared_error(y_test, y_predict)
r2=r2_score(y_test, y_predict)

# %%
print("mae", mae)
print("mse", mse)
print("r2", r2)
# Out:
# mae 35223533.47444835
# mse 5.653944080600999e+16
# r2 -0.003913192067276805
