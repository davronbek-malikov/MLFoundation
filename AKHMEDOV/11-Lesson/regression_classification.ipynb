# %% [markdown]
# # Model Review

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/a1/Desktop/MLFoundation/df_merged.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8499 entries, 0 to 8498
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8499 non-null   object
#  1   T           8499 non-null   float64
#  2   T_a         8499 non-null   float64
#  3   Ff          8499 non-null   float64
#  4   N           8491 non-null   float64
#  5   Nh          6727 non-null   float64
#  6   Cl          8499 non-null   int64
#  7   Po          8496 non-null   float64
#  8   U           8488 non-null   float64
#  9   Ch          3019 non-null   object
#  10  Cm          5181 non-null   object
#  11  H           6739 non-null   object
#  12  RRR         2141 non-null   object
#  13  DD_         8499 non-null   object
#  14  diff        8499 non-null   float64
#  15  abs_diff    8499 non-null   float64
#  16  T_kal       8488 non-null   float64
#  17  T_sher      8494 non-null   float64
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 644 entries, 11 to 8476
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  644 non-null    object
#  1   T           644 non-null    float64
#  2   T_a         644 non-null    float64
#  3   Ff          644 non-null    float64
#  4   N           644 non-null    float64
#  5   Nh          644 non-null    float64
#  6   Cl          644 non-null    int64
#  7   Po          644 non-null    float64
#  8   U           644 non-null    float64
#  9   Ch          644 non-null    object
#  10  Cm          644 non-null    object
#  11  H           644 non-null    object
#  12  RRR         644 non-null    object
#  13  DD_         644 non-null    object
#  14  diff        644 non-null    float64
#  15  abs_diff    644 non-null    float64
#  16  T_kal       644 non-null    float64
#  17  T_sher      644 non-null    float64
#  18  T_sar       644 non-null    float64
# ...

# %%
df.head()
# Out:
#              Unnamed: 0     T   T_a   Ff      N    Nh  Cl     Po     U  \
# 11  2012-11-02 09:00:00  -1.6  -1.0  2.0  100.0  75.0   7  760.1  62.0
# 15  2012-11-02 21:00:00   1.4   1.0  2.0  100.0  25.0   7  754.0  52.0
# 39  2012-11-05 21:00:00  -4.5  -4.0  1.0   90.0  60.0   0  756.2  96.0
# 47  2012-11-06 21:00:00 -14.0 -13.0  3.0  100.0  75.0   6  755.8  80.0
# 59  2012-11-08 09:00:00 -21.6 -19.0  0.0  100.0   0.0   7  764.2  80.0
#
#                                                    Ch  ...            RRR  \
# 11  Перистые нитевидные, иногда когтевидные, не ра...  ...  Следы осадков
# 15  Перистые нитевидные, иногда когтевидные, не ра...  ...    Осадков нет
# 39  Перистых, перисто-кучевых или перисто-слоистых...  ...            2.0
# 47  Перистые нитевидные, иногда когтевидные, не ра...  ...            4.0
# 59  Перистые нитевидные, иногда когтевидные, не ра...  ...    Осадков нет
#
#       DD_ diff abs_diff  T_kal  T_sher  T_sar  three_mean    diff_3  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
encoder = LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

encoder = LabelEncoder()

# First, drop rows with NaN values
df.dropna(inplace=True)

# Encode categorical columns
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = encoder.fit_transform(df[col])

# Scale numeric columns (but NOT the target columns 'diff' and 'Ch')
scaler = MinMaxScaler()
for col in df.columns:
    if df[col].dtype != 'object' and col not in ['diff', 'Ch']:
        df[col] = scaler.fit_transform(df[[col]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 644 entries, 11 to 8476
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  644 non-null    float64
#  1   T           644 non-null    float64
#  2   T_a         644 non-null    float64
#  3   Ff          644 non-null    float64
#  4   N           644 non-null    float64
#  5   Nh          644 non-null    float64
#  6   Cl          644 non-null    float64
#  7   Po          644 non-null    float64
#  8   U           644 non-null    float64
#  9   Ch          644 non-null    int64
#  10  Cm          644 non-null    float64
#  11  H           644 non-null    float64
#  12  RRR         644 non-null    float64
#  13  DD_         644 non-null    float64
#  14  diff        644 non-null    float64
#  15  abs_diff    644 non-null    float64
#  16  T_kal       644 non-null    float64
#  17  T_sher      644 non-null    float64
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('diff',axis=1)

# %%
y=df['diff']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model=LinearRegression()

# %%
lr_model
# Out:
# LinearRegression()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 644 entries, 11 to 8476
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  644 non-null    float64
#  1   T           644 non-null    float64
#  2   T_a         644 non-null    float64
#  3   Ff          644 non-null    float64
#  4   N           644 non-null    float64
#  5   Nh          644 non-null    float64
#  6   Cl          644 non-null    float64
#  7   Po          644 non-null    float64
#  8   U           644 non-null    float64
#  9   Ch          644 non-null    int64
#  10  Cm          644 non-null    float64
#  11  H           644 non-null    float64
#  12  RRR         644 non-null    float64
#  13  DD_         644 non-null    float64
#  14  diff        644 non-null    float64
#  15  abs_diff    644 non-null    float64
#  16  T_kal       644 non-null    float64
#  17  T_sher      644 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# T             0
# T_a           0
# Ff            0
# N             0
# Nh            0
# Cl            0
# Po            0
# U             0
# Ch            0
# Cm            0
# H             0
# RRR           0
# DD_           0
# diff          0
# abs_diff      0
# T_kal         0
# T_sher        0
# T_sar         0
# three_mean    0
# diff_3        0
# abs_diff_3    0
# dtype: int64

# %%
lr_model.fit(x_train, y_train)
print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred=lr_model.predict(x_test) 
print("Model trained successfully")
# Out:
# Model trained successfully

# %%
y_pred
# Out:
# array([ 5.00000000e-01,  1.70000000e+00, -4.00000000e-01,  9.00000000e-01,
#         6.00000000e-01,  2.00000000e-01, -5.00000000e-01,  2.10000000e+00,
#         8.00000000e-01, -3.00000000e-01,  2.20000000e+00,  6.00000000e-01,
#         1.40000000e+00,  4.00000000e-01,  8.00000000e-01,  4.50000000e+00,
#        -3.00000000e-01, -4.50000000e+00,  2.40000000e+00,  1.40000000e+00,
#         1.10000000e+00, -1.30000000e+00,  5.00000000e-01, -2.00000000e-01,
#         1.00000000e-01,  6.00000000e-01,  1.60000000e+00,  2.00000000e+00,
#         2.60000000e+00, -4.00000000e-01,  9.00000000e-01,  2.70000000e+00,
#         1.50000000e+00, -1.00000000e-01, -1.10000000e+00,  2.00000000e-01,
#        -1.00000000e-01,  9.00000000e-01, -2.00000000e-01,  2.60000000e+00,
#         1.00000000e-01,  9.00000000e-01, -3.00000000e-01,  2.00000000e+00,
#        -8.00000000e-01, -5.00000000e-01, -1.90000000e+00, -2.00000000e-01,
# ...

# %%
y_pred=lr_model.predict(x_train)

# %%
y_pred
# Out:
# array([ 2.00000000e-01, -7.00000000e-01,  2.00000000e-01,  3.00000000e-01,
#         7.00000000e-01,  4.00000000e-01,  1.20000000e+00, -1.10000000e+00,
#         2.30000000e+00, -1.60000000e+00,  1.42108547e-14,  3.00000000e-01,
#         1.40000000e+00,  1.00000000e-01, -3.00000000e-01,  2.90000000e+00,
#         1.00000000e-01, -4.00000000e-01,  1.50000000e+00,  1.50000000e+00,
#         3.73034936e-14,  5.00000000e-01, -4.00000000e-01, -1.59872116e-14,
#        -5.00000000e-01,  4.00000000e-01,  2.90000000e+00, -2.00000000e-01,
#         3.00000000e-01,  1.40000000e+00,  1.60000000e+00, -1.00000000e+00,
#         1.60000000e+00, -8.00000000e-01,  1.20000000e+00,  3.00000000e-01,
#        -5.00000000e-01,  2.00000000e-01, -5.00000000e-01,  1.00000000e+00,
#        -1.30000000e+00,  1.80000000e+00,  2.60000000e+00,  5.00000000e-01,
#        -9.00000000e-01, -3.00000000e-01, -1.10000000e+00,  2.10000000e+00,
# ...

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# Make predictions on test data
y_pred = lr_model.predict(x_test)

# Calculate metrics
r2 = r2_score(y_test, y_pred)
mean= mean_absolute_error(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")
# Out:
# R² Score: 1.0000
# Mean Absolute Error: 0.0000

# %%
print(r2)
print(mean)
# Out:
# 1.0
# 2.2558182711976726e-14

# %% [markdown]
# # Logistic Regression

# %%
df.head()
# Out:
#     Unnamed: 0         T       T_a        Ff         N    Nh        Cl  \
# 11    0.000000  0.817181  0.826087  0.333333  1.000000  0.75  0.777778
# 15    0.001555  0.883260  0.869565  0.333333  1.000000  0.25  0.777778
# 39    0.003110  0.753304  0.760870  0.166667  0.888889  0.60  0.000000
# 47    0.004666  0.544053  0.565217  0.500000  1.000000  0.75  0.666667
# 59    0.006221  0.376652  0.434783  0.000000  1.000000  0.00  0.777778
#
#           Po         U  Ch  ...       RRR   DD_  diff  abs_diff     T_kal  \
# 11  0.520576  0.296296   4  ...  1.000000  0.75  -0.6  0.061856  0.749495
# 15  0.395062  0.111111   4  ...  0.933333  0.75   0.4  0.041237  0.816162
# 39  0.440329  0.925926   7  ...  0.600000  0.25  -0.5  0.051546  0.703030
# 47  0.432099  0.629630   4  ...  0.733333  0.50  -1.0  0.103093  0.498990
# 59  0.604938  0.629630   4  ...  0.933333  0.00  -2.6  0.268041  0.286869
#
#       T_sher     T_sar  three_mean    diff_3  abs_diff_3
# ...

# %%
df['Ch'].nunique()
# Out:
# 8

# %%
x=df.drop('Ch',axis=1)

# %%
y=df['Ch']

# %%
# Check y values
print("Unique values in y:")
print(y.unique())
print(f"\nNumber of unique classes: {y.nunique()}")
print(f"y dtype: {y.dtype}")
# Out:
# Unique values in y:
# [4 7 1 2 5 0 3 6]
#
# Number of unique classes: 8
# y dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(x_train, y_train)
print("Logistic Regression model trained successfully!")
# Out:
# Logistic Regression model trained successfully!
# /Users/a1/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
log_model
# Out:
# LogisticRegression()

# %%
y_pred=log_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test,y_pred)

# %%
print(score)
# Out:
# 0.7906976744186046
