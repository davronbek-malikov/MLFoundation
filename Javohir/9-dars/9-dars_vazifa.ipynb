# %% [markdown]
# # Vazifalar

# %% [markdown]
# Github/Kaggledan dataset toping:

# %% [markdown]
# For loop bn to’liq data preprocessing qiling

# %% [markdown]
# Logistic Regression bn model yasang

# %% [markdown]
# Kodlarni xar bir bosqich uchun mustaqil yozing

# %% [markdown]
# # Data Preprocessing + for loop

# %%
import pandas as pd

# %%
df=pd.read_csv('IMDB_Movies_Dataset.csv')

# %% [markdown]
# # 1. Handling missing values + for loop

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Title                   0
# Average Rating          2
# Director                0
# Writer                  1
# Metascore            1934
# Cast                    7
# Release Date            0
# Country of Origin       3
# Languages              21
# Budget               2338
# Worldwide Gross      1094
# Runtime                 0
# Writer.1                1
# Average Rating.1        0
# dtype: int64

# %%
df.drop(['Budget'],axis=1,inplace=True)
df.drop(['Worldwide Gross'],axis=1,inplace=True)
df.drop(['Metascore'],axis=1,inplace=True)
df.drop(['Title'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Average Rating        2
# Director              0
# Writer                1
# Cast                  7
# Release Date          0
# Country of Origin     3
# Languages            21
# Runtime               0
# Writer.1              1
# Average Rating.1      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4991 entries, 0 to 4990
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4991 non-null   str
#  1   Average Rating     4989 non-null   float64
#  2   Director           4991 non-null   str
#  3   Writer             4990 non-null   str
#  4   Cast               4984 non-null   str
#  5   Release Date       4991 non-null   str
#  6   Country of Origin  4988 non-null   str
#  7   Languages          4970 non-null   str
#  8   Runtime            4991 non-null   str
#  9   Writer.1           4990 non-null   str
#  10  Average Rating.1   4991 non-null   float64
# dtypes: float64(2), str(9)
# memory usage: 429.0 KB

# %%
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype=='str':
            df[col]=df[col].fillna(df[col].mode()[0])
        else:
            df[col]=df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Average Rating       0
# Director             0
# Writer               0
# Cast                 0
# Release Date         0
# Country of Origin    0
# Languages            0
# Runtime              0
# Writer.1             0
# Average Rating.1     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4991 entries, 0 to 4990
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4991 non-null   str
#  1   Average Rating     4991 non-null   float64
#  2   Director           4991 non-null   str
#  3   Writer             4991 non-null   str
#  4   Cast               4991 non-null   str
#  5   Release Date       4991 non-null   str
#  6   Country of Origin  4991 non-null   str
#  7   Languages          4991 non-null   str
#  8   Runtime            4991 non-null   str
#  9   Writer.1           4991 non-null   str
#  10  Average Rating.1   4991 non-null   float64
# dtypes: float64(2), str(9)
# memory usage: 429.0 KB

# %% [markdown]
# # 2. Encoding + for loop

# %%
from sklearn.preprocessing import LabelEncoder

encoder=LabelEncoder()

for col in df.columns:
    if df[col].dtype=='str':
        df[col]=encoder.fit_transform(df[col])

# %%
print(df.dtypes)
# Out:
# Unnamed: 0             int64
# Average Rating       float64
# Director               int64
# Writer                 int64
# Cast                   int64
# Release Date           int64
# Country of Origin      int64
# Languages              int64
# Runtime                int64
# Writer.1               int64
# Average Rating.1     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4991 entries, 0 to 4990
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4991 non-null   int64
#  1   Average Rating     4991 non-null   float64
#  2   Director           4991 non-null   int64
#  3   Writer             4991 non-null   int64
#  4   Cast               4991 non-null   int64
#  5   Release Date       4991 non-null   int64
#  6   Country of Origin  4991 non-null   int64
#  7   Languages          4991 non-null   int64
#  8   Runtime            4991 non-null   int64
#  9   Writer.1           4991 non-null   int64
#  10  Average Rating.1   4991 non-null   float64
# dtypes: float64(2), int64(9)
# memory usage: 429.0 KB

# %% [markdown]
# # 3. Scaling + for loop

# %%
df.head()
# Out:
#    Unnamed: 0  Average Rating  Director  Writer  Cast  Release Date  \
# 0           0             9.3       711    3851  4504          3606
# 1           1             9.3      2620    2884  3367          3504
# 2         112             9.2       703    2592  3002            17
# 3         224             9.2       661    4123  3312            47
# 4         335             9.2      1962    3286   396          4337
#
#    Country of Origin  Languages  Runtime  Writer.1  Average Rating.1
# 0                678         87       74      3851               9.3
# 1                384        801       77      2884               9.3
# 2                678        317      110      2592               9.2
# 3                568       1064       18      4123               9.2
# 4                303         87       66      3286               9.2

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns.drop('Average Rating.1')   # izoh: Target qiymat scalimng qilinmaydi

# %%
scaler=MinMaxScaler()

# %%
scaler
# Out:
# MinMaxScaler()

# %%
scaler=MinMaxScaler()
for col in df.columns:
    if df[col].dtype!='object':
        df[col]=scaler.fit_transform(df[[col]])

# %%
df.head()
# Out:
#    Unnamed: 0  Average Rating  Director    Writer      Cast  Release Date  \
# 0       0.000        1.000000  0.268606  0.871070  0.904418      0.798671
# 1       0.002        1.000000  0.989800  0.652341  0.676104      0.776080
# 2       0.224        0.952381  0.265584  0.586293  0.602811      0.003765
# 3       0.448        0.952381  0.249717  0.932594  0.665060      0.010410
# 4       0.670        0.952381  0.741216  0.743271  0.079518      0.960576
#
#    Country of Origin  Languages   Runtime  Writer.1  Average Rating.1
# 0           0.836005   0.080332  0.408840  0.871070          1.000000
# 1           0.473490   0.739612  0.425414  0.652341          1.000000
# 2           0.836005   0.292705  0.607735  0.586293          0.952381
# 3           0.700370   0.982456  0.099448  0.932594          0.952381
# 4           0.373613   0.080332  0.364641  0.743271          0.952381

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4991 entries, 0 to 4990
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4991 non-null   float64
#  1   Average Rating     4991 non-null   float64
#  2   Director           4991 non-null   float64
#  3   Writer             4991 non-null   float64
#  4   Cast               4991 non-null   float64
#  5   Release Date       4991 non-null   float64
#  6   Country of Origin  4991 non-null   float64
#  7   Languages          4991 non-null   float64
#  8   Runtime            4991 non-null   float64
#  9   Writer.1           4991 non-null   float64
#  10  Average Rating.1   4991 non-null   float64
# dtypes: float64(11)
# memory usage: 429.0 KB

# %% [markdown]
# # Data Preprocessing done

# %% [markdown]
# # Logistic Regression bn model yasang

# %%
x----inputlar
y--output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[318], line 1
# ----> 1 x----inputlar
#       2 y--output
#
# NameError: name 'inputlar' is not defined

# %%
num_col=df.select_dtypes(include=['float64']).columns

# %%
num_col
# Out:
# Index(['Unnamed: 0', 'Average Rating', 'Director', 'Writer', 'Cast',
#        'Release Date', 'Country of Origin', 'Languages', 'Runtime', 'Writer.1',
#        'Average Rating.1'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4991 entries, 0 to 4990
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4991 non-null   float64
#  1   Average Rating     4991 non-null   float64
#  2   Director           4991 non-null   float64
#  3   Writer             4991 non-null   float64
#  4   Cast               4991 non-null   float64
#  5   Release Date       4991 non-null   float64
#  6   Country of Origin  4991 non-null   float64
#  7   Languages          4991 non-null   float64
#  8   Runtime            4991 non-null   float64
#  9   Writer.1           4991 non-null   float64
#  10  Average Rating.1   4991 non-null   float64
# dtypes: float64(11)
# memory usage: 429.0 KB

# %%
x=df.drop('Average Rating.1',axis=1)

# %%
y=df['Average Rating.1'].astype(int)

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 4986    0
# 4987    0
# 4988    0
# 4989    1
# 4990    1
# Name: Average Rating.1, Length: 4991, dtype: int64

# %%
x
# Out:
#       Unnamed: 0  Average Rating  Director    Writer      Cast  Release Date  \
# 0          0.000        1.000000  0.268606  0.871070  0.904418      0.798671
# 1          0.002        1.000000  0.989800  0.652341  0.676104      0.776080
# 2          0.224        0.952381  0.265584  0.586293  0.602811      0.003765
# 3          0.448        0.952381  0.249717  0.932594  0.665060      0.010410
# 4          0.670        0.952381  0.741216  0.743271  0.079518      0.960576
# ...          ...             ...       ...       ...       ...           ...
# 4986       0.886        0.000000  0.890064  0.358064  0.841365      0.017719
# 4987       0.888        0.000000  0.797884  0.794390  0.768273      0.053378
# 4988       0.890        0.000000  0.513034  0.527030  0.988153      0.601329
# 4989       0.000        1.000000  0.268606  0.871070  0.904418      0.798671
# 4990       0.000        1.000000  0.268606  0.871070  0.904418      0.798671
#
# ...

# %% [markdown]
# # Modelimizni train qilamiz

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (3493, 10)

# %%
x_test.shape
# Out:
# (1498, 10)

# %%
y_train.shape
# Out:
# (3493,)

# %%
y_test.shape
# Out:
# (1498,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()

# %%
log_reg
# Out:
# LogisticRegression()

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log_reg.predict(x_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test,y_pred)

# %%
print('Modelning aniqlik darajasi:',score) # bu hamma structurelarni ishlatgan holatidagi natija
# Out:
# Modelning aniqlik darajasi: 0.9993324432576769

# %%
print('Modelning aniqlik darajasi:',score) # bu Encoding qilinmagan holatida
# Out:
# Modelning aniqlik darajasi: 0.0

# %%
print('Modelning aniqlik darajasi:',score) # bu Scaling qilinmagan holatida
# Out:
# Modelning aniqlik darajasi: 0.794392523364486
