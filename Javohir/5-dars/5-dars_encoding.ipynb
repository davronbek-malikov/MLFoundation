# %% [markdown]
# ENCODING
# ONE-HOT,
# LABEL USULLARINI MASHQ QILISH

# %%
import pandas as pd

# %%
df=pd.read_csv('netflix_titles.csv')

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Birinchi tushib qolgan qiymalarni to'ldirib chiqamiz

# %%
# directorda 2634ta qiymat tushib qolibdi va bu strda ekan 
df['director']=df['director'].fillna(df['director'].mode()[0])

# %%
# director cast  country  date_added  rating  duration qiymat tushib qolgan bularni hammasi categorical bo'lgani uchun mode usulidan foydalandim

df['director']=df['director'].fillna(df['director'].mode()[0])

df['cast']=df['cast'].fillna(df['cast'].mode()[0])

df['country']=df['country'].fillna(df['country'].mode()[0])

df['date_added']=df['date_added'].fillna(df['date_added'].mode()[0])

df['rating']=df['rating'].fillna(df['rating'].mode()[0])

df['duration']=df['duration'].fillna(df['duration'].mode()[0])

# %% [markdown]
# Tushib qolgan qiymatlar to'ldirildi

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# ENCODING

# %% [markdown]
# Encodingdan oldingi holati

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water    Rajiv Chilaka
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4      s5  TV Show           Kota Factory    Rajiv Chilaka
#
#                                                 cast        country  \
# 0                                 David Attenborough  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                 David Attenborough  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Bu encodingdan keyini holati

# %%
df.head()
# Out:
#    show_id  title  director  cast  country  date_added  release_year  rating  \
# 0        0   1975      2295  1699      603        1711          2020       7
# 1     1111   1091      3392   409      426        1706          2021      11
# 2     2222   2651      2105  6296      603        1706          2021      11
# 3     3333   3506      3392  1699      603        1706          2021      11
# 4     4444   3861      3392  4815      251        1706          2021      11
#
#    duration  listed_in  description  ustun_Movie  ustun_TV Show
# 0       210        274         2577            1              0
# 1       110        414         1762            0              1
# 2         0        242         7341            0              1
# 3         0        297         3617            0              1
# 4       110        393         4416            0              1

# %% [markdown]
# Bu yerda release_year mana shu ustundan tashqari hammasi categorical

# %% [markdown]
# one-hot usuliga TYPE ustuni tushishi mumkin ekan qoganlari juda ko'p klaslar bo'gani uchun

# %%
dummies=pd.get_dummies(df['type'],prefix='ustun',dtype=int)

# %%
dummies
# Out:
#       ustun_Movie  ustun_TV Show
# 0               1              0
# 1               0              1
# 2               0              1
# 3               0              1
# 4               0              1
# ...           ...            ...
# 8802            1              0
# 8803            0              1
# 8804            1              0
# 8805            1              0
# 8806            1              0
#
# [8807 rows x 2 columns]

# %%
df=pd.concat([df.drop(columns=['type']),dummies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8807 non-null   str
#  1   title          8807 non-null   str
#  2   director       8807 non-null   str
#  3   cast           8807 non-null   str
#  4   country        8807 non-null   str
#  5   date_added     8807 non-null   str
#  6   release_year   8807 non-null   int64
#  7   rating         8807 non-null   str
#  8   duration       8807 non-null   str
#  9   listed_in      8807 non-null   str
#  10  description    8807 non-null   str
#  11  ustun_Movie    8807 non-null   int64
#  12  ustun_TV Show  8807 non-null   int64
# dtypes: int64(3), str(10)
# memory usage: 894.6 KB

# %% [markdown]
# Endi LABEL usulidan foydalanib qolgan ustunlarni numericalga o'tkazamiz

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder

# %%
encoder
# Out:
# sklearn.preprocessing._label.LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['show_id'] = encoder.fit_transform(df['show_id'])
df['title'] = encoder.fit_transform(df['title'])
df['director'] = encoder.fit_transform(df['director'])
df['cast']=encoder.fit_transform(df['cast'])
df['country']=encoder.fit_transform(df['country'])
df['date_added']=encoder.fit_transform(df['date_added'])
df['rating']=encoder.fit_transform(df['rating'])
df['duration']=encoder.fit_transform(df['duration'])
df['listed_in']=encoder.fit_transform(df['listed_in'])
df['description']=encoder.fit_transform(df['description'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8807 non-null   int64
#  1   title          8807 non-null   int64
#  2   director       8807 non-null   int64
#  3   cast           8807 non-null   int64
#  4   country        8807 non-null   int64
#  5   date_added     8807 non-null   int64
#  6   release_year   8807 non-null   int64
#  7   rating         8807 non-null   int64
#  8   duration       8807 non-null   int64
#  9   listed_in      8807 non-null   int64
#  10  description    8807 non-null   int64
#  11  ustun_Movie    8807 non-null   int64
#  12  ustun_TV Show  8807 non-null   int64
# dtypes: int64(13)
# memory usage: 894.6 KB

# %%
df.head()
# Out:
#    show_id  title  director  cast  country  date_added  release_year  rating  \
# 0        0   1975      2295  1699      603        1711          2020       7
# 1     1111   1091      3392   409      426        1706          2021      11
# 2     2222   2651      2105  6296      603        1706          2021      11
# 3     3333   3506      3392  1699      603        1706          2021      11
# 4     4444   3861      3392  4815      251        1706          2021      11
#
#    duration  listed_in  description  ustun_Movie  ustun_TV Show
# 0       210        274         2577            1              0
# 1       110        414         1762            0              1
# 2         0        242         7341            0              1
# 3         0        297         3617            0              1
# 4       110        393         4416            0              1

# %% [markdown]
# Datadagi tushib qolgan qiymatlar to'ldirildi va hammasi numerical qiymatlarga aylantirildi
