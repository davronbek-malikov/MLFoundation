# %% [markdown]
# # Linear regression uchun loyiha

# %%
import pandas as pd

# %%
df=pd.read_csv('AI_Impact_Student_Life_2026.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Student_ID               1500 non-null   str
#  1   Age                      1500 non-null   int64
#  2   Major                    978 non-null    str
#  3   Primary_AI_Tool          910 non-null    str
#  4   Task_Frequency_Daily     1500 non-null   int64
#  5   Main_Usage_Case          1214 non-null   str
#  6   GPA_Baseline             1480 non-null   float64
#  7   GPA_Post_AI              1354 non-null   float64
#  8   Time_Saved_Hours_Weekly  1500 non-null   int64
#  9   AI_Ethics_Concern        1500 non-null   str
#  10  Career_Confidence_Score  1500 non-null   int64
# dtypes: float64(2), int64(4), str(5)
# memory usage: 129.0 KB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Missing

# %%
df.isnull().sum()
# Out:
# Student_ID                   0
# Age                          0
# Major                      522
# Primary_AI_Tool            590
# Task_Frequency_Daily         0
# Main_Usage_Case            286
# GPA_Baseline                20
# GPA_Post_AI                146
# Time_Saved_Hours_Weekly      0
# AI_Ethics_Concern            0
# Career_Confidence_Score      0
# dtype: int64

# %%
def yigishtir(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype =='str':
                df[col]=df[col].fillna(df[col].mode()[0])
            else:
                df[col]=df[col].fillna(df[col].mean())
    return df

# %%
yigishtir(df)
df.isnull().sum()
# Out:
# Student_ID                 0
# Age                        0
# Major                      0
# Primary_AI_Tool            0
# Task_Frequency_Daily       0
# Main_Usage_Case            0
# GPA_Baseline               0
# GPA_Post_AI                0
# Time_Saved_Hours_Weekly    0
# AI_Ethics_Concern          0
# Career_Confidence_Score    0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

def encodla(df):
    encoder = LabelEncoder()

    for col in df.columns.to_list(): 
        if df[col].dtype == 'str':
            if df[col].nunique() <= 5:
                dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
                df.drop(columns=[col], inplace=True)
                df[dummies.columns] = dummies
            else:
                df[col] = encoder.fit_transform(df[col].astype(str))
    
    return df

# %%
df = encodla(df)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Student_ID                         1500 non-null   int64
#  1   Age                                1500 non-null   int64
#  2   Task_Frequency_Daily               1500 non-null   int64
#  3   GPA_Baseline                       1500 non-null   float64
#  4   GPA_Post_AI                        1500 non-null   float64
#  5   Time_Saved_Hours_Weekly            1500 non-null   int64
#  6   Career_Confidence_Score            1500 non-null   int64
#  7   Major_Biology                      1500 non-null   int64
#  8   Major_Business Administration      1500 non-null   int64
#  9   Major_Modern History               1500 non-null   int64
#  10  Major_Software Engineering         1500 non-null   int64
# ...

# %% [markdown]
# # Scaling

# %%
df.head()
# Out:
#    Student_ID  Age  Task_Frequency_Daily  GPA_Baseline  GPA_Post_AI  \
# 0         927   23                     1          2.62     2.620000
# 1        1076   22                     3          3.99     3.276573
# 2         355   18                     2          2.57     2.570000
# 3         205   19                     5          2.67     2.870000
# 4         281   19                    10          3.65     3.850000
#
#    Time_Saved_Hours_Weekly  Career_Confidence_Score  Major_Biology  \
# 0                        9                        3              0
# 1                        7                        4              0
# 2                       15                        7              1
# 3                       12                        5              1
# 4                        5                        9              1
#
#    Major_Business Administration  Major_Modern History  ...  \
# 0                              0                     0  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
def scaling_qil(df):
    scaler=MinMaxScaler()
    num_col=df.select_dtypes(include=['int64','float64']).columns.drop('GPA_Post_AI')
    for col in num_col:
        df[col]=scaler.fit_transform(df[[col]])
    return df

# %%
scaling_qil(df)
# Out:
#       Student_ID       Age  Task_Frequency_Daily  GPA_Baseline  GPA_Post_AI  \
# 0       0.618412  0.714286              0.000000      0.080537     2.620000
# 1       0.717812  0.571429              0.222222      1.000000     3.276573
# 2       0.236825  0.000000              0.111111      0.046980     2.570000
# 3       0.136758  0.142857              0.444444      0.114094     2.870000
# 4       0.187458  0.142857              1.000000      0.771812     3.850000
# ...          ...       ...                   ...           ...          ...
# 1495    0.280854  0.428571              0.333333      0.570470     3.550000
# 1496    0.513009  0.428571              0.222222      0.731544     3.890000
# 1497    0.018012  0.714286              0.777778      0.469799     3.400000
# 1498    0.454970  0.714286              0.555556      1.000000     3.276573
# 1499    0.488993  0.714286              0.333333      0.691275     3.430000
#
# ...

# %% [markdown]
# # Model

# %%
x=df.drop('GPA_Post_AI',axis=1)

# %%
y=df['GPA_Post_AI'].astype(int)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([3.07574264, 2.39659827, 2.64386624, 2.36974658, 2.66248145,
#        2.94576086, 3.22343028, 2.464367  , 3.18986699, 2.96698775,
#        2.40466894, 3.21840836, 3.18084574, 2.71617504, 2.65502027,
#        2.20487388, 3.08800483, 2.30340531, 3.21240929, 3.29849007,
#        2.78549409, 3.18193969, 2.28277443, 2.79282588, 3.17831908,
#        2.89231543, 2.40254011, 2.8995293 , 2.54000249, 2.83354283,
#        3.30799957, 2.65938007, 3.16972429, 2.27759533, 2.53334483,
#        3.25277639, 3.08269836, 2.38649258, 2.38469954, 2.67770705,
#        3.22652746, 2.91480013, 2.82633481, 2.27879719, 3.26199399,
#        3.0063606 , 2.72061356, 3.06283708, 2.65031706, 2.7805767 ,
#        2.53389812, 2.85215099, 2.92525675, 2.88321698, 2.87701174,
#        3.22993479, 3.04463787, 2.20842354, 2.36574153, 2.68908478,
#        2.77465822, 3.20334294, 2.64482192, 2.60379515, 2.21052093,
#        2.41622396, 2.67757628, 3.12824753, 2.85721719, 2.6043655 ,
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2=r2_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=pow(mse,(1/2))
mae=mean_absolute_error(y_test,y_pred)

# %%
print('r2',r2)
print('mse',mse)
print('rmse',rmse)
print('mae',mae)
# Out:
# r2 0.5385534714794487
# mse 0.09118639153223894
# rmse 0.3019708455004207
# mae 0.25945450856459956
