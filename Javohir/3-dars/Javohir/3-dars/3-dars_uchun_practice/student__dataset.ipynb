# %% [markdown]
# STUDENTLARNI DATASETI

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv('student_dataset.csv')

# %%
import os # BU KOD HOZIR QAYSI PAPKADA TURGANIMNI KO'RSATADI
print(os.getcwd())
# Out:
# c:\Users\Javohir\Desktop\ML\3-dars\3-dars_uchun_practice

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0           23.5        84.2                  Low                 Low
# 1           19.7        63.6               Medium                High
# 2           24.4        98.4               Medium              Medium
# 3           29.6        88.6               Medium                High
# 4           19.1        91.5                 High              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                        Yes          7.4             50.3           Medium
# 1                        Yes          6.7             83.1              Low
# 2                        Yes          8.0             63.5           Medium
# 3                        Yes          6.3             57.5           Medium
# 4                        Yes          6.2             66.0           Medium
#
#   Internet_Access  Tutoring_Sessions  Final_Exam_Score
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602           26.0        69.5                 High              Medium
# 6603           23.0        75.9                 High                 Low
# 6604           20.1        90.3                 High                 Low
# 6605           10.3        86.0                 High                High
# 6606           15.6        67.1                  Low              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No          7.0             80.1
# 6603                         No          6.4             93.2
# 6604                        Yes          7.7             79.4
# 6605                         No          6.8             72.1
# 6606                        Yes          6.9             78.9
#
#      Motivation_Level Internet_Access  Tutoring_Sessions  Final_Exam_Score
# 6602           Medium             Yes                  1              58.8
# ...

# %%
df.nunique()
# Out:
# Hours_Studied                 352
# Attendance                    401
# Parental_Involvement            3
# Access_to_Resources             3
# Extracurricular_Activities      2
# Sleep_Hours                    61
# Previous_Scores               501
# Motivation_Level                3
# Internet_Access                 2
# Tutoring_Sessions               9
# Final_Exam_Score              477
# dtype: int64

# %%
df['Hours_Studied'].nunique()
# Out:
# 352

# %%
df['Hours_Studied']
# Out:
# 0       23.5
# 1       19.7
# 2       24.4
# 3       29.6
# 4       19.1
#         ...
# 6602    26.0
# 6603    23.0
# 6604    20.1
# 6605    10.3
# 6606    15.6
# Name: Hours_Studied, Length: 6607, dtype: float64

# %%
df[['Hours_Studied','Tutoring_Sessions','Final_Exam_Score']]
# Out:
#       Hours_Studied  Tutoring_Sessions  Final_Exam_Score
# 0              23.5                  1              54.3
# 1              19.7                  2              59.4
# 2              24.4                  0              63.8
# 3              29.6                  2              61.0
# 4              19.1                  2              60.7
# ...             ...                ...               ...
# 6602           26.0                  1              58.8
# 6603           23.0                  2              67.0
# 6604           20.1                  0              58.5
# 6605           10.3                  1              58.7
# 6606           15.6                  4              52.3
#
# [6607 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   float64
#  1   Attendance                  6607 non-null   float64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   float64
#  6   Previous_Scores             6607 non-null   float64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Final_Exam_Score            6607 non-null   float64
# dtypes: float64(5), int64(1), str(5)
# memory usage: 567.9 KB

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Final_Exam_Score              0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Hours_Studied                 False
# Attendance                    False
# Parental_Involvement          False
# Access_to_Resources           False
# Extracurricular_Activities    False
# Sleep_Hours                   False
# Previous_Scores               False
# Motivation_Level              False
# Internet_Access               False
# Tutoring_Sessions             False
# Final_Exam_Score              False
# dtype: bool

# %% [markdown]
# DATA HAQIDA YAKUNIY XULOSAM HECH QAYSI QATORDA TUSHIB QOLGAN QIYMAT YO'Q DATA TOZA VA ISHLATSA BO'LADI DEB O'YLAYMAN
