# %% [markdown]
# preprocessed_youtube_comments data setini tahlil qilish

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df=pd.read_csv('preprocessed_youtube_comments.csv')

# %%
df.tail()
# Out:
#           video_id         video_title  \
# 64203  mcjjPpd5s1A  Squid Game Trailer
# 64204  mcjjPpd5s1A  Squid Game Trailer
# 64205  mcjjPpd5s1A  Squid Game Trailer
# 64206  mcjjPpd5s1A  Squid Game Trailer
# 64207  mcjjPpd5s1A  Squid Game Trailer
#
#                                                  comment  \
# 64203    hey bro without gi hun squid game is alone 😔😔😭😭
# 64204  Wow, epic! Maybe now the plot won’t have rando...
# 64205  No way! Amaizing work dude. I really hope they...
# 64206                    Simply incredible work bravo! 🎉
# 64207  Wow! What a trailer!\r\nLooks really cool\r\nI...
#
#                                          cleaned_comment  \
# 64203        hey bro without gi hun squid game is alone
# 64204  wow epic maybe now the plot wont have random g...
# 64205  no way amaizing work dude i really hope they m...
# 64206                      simply incredible work bravo
# 64207  wow what a trailer\r\nlooks really cool\r\nit ...
#
# ...

# %%
df.head()
# Out:
#       video_id               video_title  \
# 0  TcMBFSGVi1c  Avengers Endgame Trailer
# 1  TcMBFSGVi1c  Avengers Endgame Trailer
# 2  TcMBFSGVi1c  Avengers Endgame Trailer
# 3  TcMBFSGVi1c  Avengers Endgame Trailer
# 4  TcMBFSGVi1c  Avengers Endgame Trailer
#
#                                              comment  \
# 0                  Furei a boca com espinho de peixe
# 1                           Sou budista Jesus Cristo
# 2  Is there any chance of iron man returning back...
# 3                   TOMORROW. DOOM COMES FOR US ALL.
# 4                         saw this movie again today
#
#                                      cleaned_comment  \
# 0                  furei a boca com espinho de peixe
# 1                           sou budista jesus cristo
# 2  is there any chance of iron man returning back...
# 3                     tomorrow doom comes for us all
# 4                         saw this movie again today
#
#                         processed_comment  sentiment
# ...

# %%
df.nunique()
# Out:
# video_id               114
# video_title              9
# comment              64205
# cleaned_comment      61023
# processed_comment    56981
# sentiment                3
# dtype: int64

# %%
df[['video_title','sentiment']] # BULAR MULTI CLASSLI USTUNLAR
# Out:
#                     video_title  sentiment
# 0      Avengers Endgame Trailer          0
# 1      Avengers Endgame Trailer          0
# 2      Avengers Endgame Trailer          1
# 3      Avengers Endgame Trailer         -1
# 4      Avengers Endgame Trailer          0
# ...                         ...        ...
# 64203        Squid Game Trailer         -1
# 64204        Squid Game Trailer          1
# 64205        Squid Game Trailer          1
# 64206        Squid Game Trailer          1
# 64207        Squid Game Trailer          1
#
# [64208 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64208 entries, 0 to 64207
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           64208 non-null  str
#  1   video_title        64208 non-null  str
#  2   comment            64208 non-null  str
#  3   cleaned_comment    64208 non-null  str
#  4   processed_comment  64208 non-null  str
#  5   sentiment          64208 non-null  int64
# dtypes: int64(1), str(5)
# memory usage: 2.9 MB

# %%
df.isnull().sum()
# Out:
# video_id             0
# video_title          0
# comment              0
# cleaned_comment      0
# processed_comment    0
# sentiment            0
# dtype: int64

# %%
df.isnull().any()
# Out:
# video_id             False
# video_title          False
# comment              False
# cleaned_comment      False
# processed_comment    False
# sentiment            False
# dtype: bool
