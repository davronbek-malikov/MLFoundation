# %% [markdown]
# Youtube Comments

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv('youtube_comments.csv')

# %%
df.head()
# Out:
#       video_id               video_title  \
# 0  TcMBFSGVi1c  Avengers Endgame Trailer
# 1  TcMBFSGVi1c  Avengers Endgame Trailer
# 2  TcMBFSGVi1c  Avengers Endgame Trailer
# 3  TcMBFSGVi1c  Avengers Endgame Trailer
# 4  TcMBFSGVi1c  Avengers Endgame Trailer
#
#                                              comment
# 0                  Furei a boca com espinho de peixe
# 1                           Sou budista Jesus Cristo
# 2  Is there any chance of iron man returning back...
# 3                   TOMORROW. DOOM COMES FOR US ALL.
# 4                         saw this movie again today

# %%
df.tail()
# Out:
#           video_id         video_title  \
# 66798  mcjjPpd5s1A  Squid Game Trailer
# 66799  mcjjPpd5s1A  Squid Game Trailer
# 66800  mcjjPpd5s1A  Squid Game Trailer
# 66801  mcjjPpd5s1A  Squid Game Trailer
# 66802  mcjjPpd5s1A  Squid Game Trailer
#
#                                                  comment
# 66798    hey bro without gi hun squid game is alone 😔😔😭😭
# 66799  Wow, epic! Maybe now the plot won’t have rando...
# 66800  No way! Amaizing work dude. I really hope they...
# 66801                    Simply incredible work bravo! 🎉
# 66802  Wow! What a trailer!\r\nLooks really cool\r\nI...

# %%
df.nunique() # xar bir ustundagi classlar soni
# Out:
# video_id         115
# video_title        9
# comment        66799
# dtype: int64

# %%
df['video_id'].nunique() # BU KOD ALOHIDA BIR USTUNDA NECHTA KLASSLAR BORLIGINI KO'RSATADI
# Out:
# 115

# %%
df['video_id'] # BU KOD BITTA USTUNNI ALOHIDA CHIQARIB BERADI
# Out:
# 0        TcMBFSGVi1c
# 1        TcMBFSGVi1c
# 2        TcMBFSGVi1c
# 3        TcMBFSGVi1c
# 4        TcMBFSGVi1c
#             ...
# 66798    mcjjPpd5s1A
# 66799    mcjjPpd5s1A
# 66800    mcjjPpd5s1A
# 66801    mcjjPpd5s1A
# 66802    mcjjPpd5s1A
# Name: video_id, Length: 66803, dtype: str

# %%
df['video_id'] # BU KOD BITTA USTUNNI ALOHIDA CHIQARIB BERADI
# Out:
# 0        TcMBFSGVi1c
# 1        TcMBFSGVi1c
# 2        TcMBFSGVi1c
# 3        TcMBFSGVi1c
# 4        TcMBFSGVi1c
#             ...
# 66798    mcjjPpd5s1A
# 66799    mcjjPpd5s1A
# 66800    mcjjPpd5s1A
# 66801    mcjjPpd5s1A
# 66802    mcjjPpd5s1A
# Name: video_id, Length: 66803, dtype: str

# %%
df.info() # DATA HAQIDA UMUMIY MALUMOT
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 66803 entries, 0 to 66802
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   video_id     66803 non-null  str
#  1   video_title  66803 non-null  str
#  2   comment      66802 non-null  str
# dtypes: str(3)
# memory usage: 1.5 MB

# %%
df.isnull().sum() # BU SON ORQALI ANIQLASH
# Out:
# video_id       0
# video_title    0
# comment        1
# dtype: int64

# %%
df.isnull().any() # BU BOOLEON ORQALI ANIQLASH
# Out:
# video_id       False
# video_title    False
# comment         True
# dtype: bool
