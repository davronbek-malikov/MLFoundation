# %%
# Imtixondan o'tishni nazorat qilish uchun  condition tuzing
# Pasport olish uchun condition tuzing

# %% [markdown]
#  Imtixondan o'tishni nazorat qilish uchun  condition tuzing

# %%
imtihon_natijasi=2113
if imtihon_natijasi==5:
    print("a'lo")
elif imtihon_natijasi==4:
    print('yaxshi')          
elif imtihon_natijasi==3:
    print("o'rtacha")
elif imtihon_natijasi==2:
    print('yomon')  
else:
    print("o'ta yomon yoki xatolik bor")
# Out:
# o'ta yomon yoki xatolik bor

# %% [markdown]
#  Pasport olish uchun condition tuzing

# %%
# bu yerda shunchaki misol tariqasida kod yozdim xolos qonunchilikni kod yozib bo'gandan keyin izlanib ko'rdim xar qanday yoshdagi odam passport olishi mumikin ekan 
print ("O'zbeistonda qonunchilik bo'yicha 16 yoshga to'lgan shaxslar O'zbekiston Respublikasi passportini olishlari shart va")
yosh=150
if yosh<16:
    print("sen passport ololmaysan zumrasha")    
elif yosh>=16 and  yosh<150:
    print("siz passport olishingiz shart") 
elif yosh>150:
    print("yoshingiz normal emas boshqatdan kiriting")
elif yosh>=60:
    print("chetga chiqaman debsizda bobojon passport olishingiz kerak ekan")    
else:
    print ("nimadadur xatolik yuz berdi boshqatdan urinib ko'ring")
# Out:
# O'zbeistonda qonunchilik bo'yicha 16 yoshga to'lgan shaxslar O'zbekiston Respublikasi passportini olishlari shart va
# chetga chiqaman debsizda bobojon passport olishingiz kerak ekan
