# %% [markdown]
# DATA TYPES (Ma’lumot turlari)

# %%
#💣 Savol (o‘ylab javob ber):

#Quyidagilar qaysi tur?
10 int
"10" str
10.0 float
True booleon

# %% [markdown]
# 2. OPERATIONS (Amallar)
# Matematik:

# %%
#💣 Mashq:
a = 7
b = 3
a / b = 2.3
a // b = 2

a % b = 1
9 % 2 = 1
14 % 5 = 3
20 % 4 = 0
17 % 10 =7

# %% [markdown]
#  3. CONDITIONS (Shartlar)a

# %%
# 🧠 MASALA 1:

# Foydalanuvchi son kiritadi.
# Agar son:

# musbat bo‘lsa → "Positive"
# manfiy bo‘lsa → "Negative"
# 0 bo‘lsa → "Zero"

# 👉 Kod yoz.
a=0

if a>0:
    print('Positive')
elif a<0:
    print("Negative")    
else:
    print("Zero")
# Out:
# Zero
