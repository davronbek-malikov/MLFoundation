# %% [markdown]
# # Kaggledan/Githubdan dataset toping:
# # Funksiya+Missing+Encoding
# # Logistic Regression tekshiring
# # Classification Report

# %%
import pandas as pd

# %%
df=pd.read_csv('logistic_regression (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  str
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  str
#  5   sub_grade             396030 non-null  str
#  6   emp_title             373103 non-null  str
#  7   emp_length            377729 non-null  str
#  8   home_ownership        396030 non-null  str
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  str
#  11  issue_d               396030 non-null  str
#  12  loan_status           396030 non-null  str
#  13  purpose               396030 non-null  str
#  14  title                 394274 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# dtype: int64

# %%
df.drop(['emp_title'], axis=1, inplace=True)
df.drop(['title'], axis=1, inplace=True)
df.drop(['address'], axis=1, inplace=True)
df.drop(['sub_grade'], axis=1, inplace=True)
df.drop(['issue_d'], axis=1, inplace=True)
df.drop(['installment'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# grade                       0
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# loan_status                 0
# purpose                     0
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  str
#  2   int_rate              396030 non-null  float64
#  3   grade                 396030 non-null  str
#  4   emp_length            377729 non-null  str
#  5   home_ownership        396030 non-null  str
#  6   annual_inc            396030 non-null  float64
#  7   verification_status   396030 non-null  str
#  8   loan_status           396030 non-null  str
#  9   purpose               396030 non-null  str
#  10  dti                   396030 non-null  float64
#  11  earliest_cr_line      396030 non-null  str
#  12  open_acc              396030 non-null  float64
#  13  pub_rec               396030 non-null  float64
#  14  revol_bal             396030 non-null  float64
# ...

# %% [markdown]
# # Funksiya+Missing+Encoding

# %%
def toldir(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='str':
                df[col]=df[col].fillna(df[col].mode()[0])
            else:
                df[col]=df[col].fillna(df[col].mean())
    return (df)

# %%
toldir(df)
# Out:
#         loan_amnt        term  int_rate grade emp_length home_ownership  \
# 0         10000.0   36 months     11.44     B  10+ years           RENT
# 1          8000.0   36 months     11.99     B    4 years       MORTGAGE
# 2         15600.0   36 months     10.49     B   < 1 year           RENT
# 3          7200.0   36 months      6.49     A    6 years           RENT
# 4         24375.0   60 months     17.27     C    9 years       MORTGAGE
# ...           ...         ...       ...   ...        ...            ...
# 396025    10000.0   60 months     10.99     B    2 years           RENT
# 396026    21000.0   36 months     12.29     C    5 years       MORTGAGE
# 396027     5000.0   36 months      9.99     B  10+ years           RENT
# 396028    21000.0   60 months     15.31     C  10+ years       MORTGAGE
# 396029     2000.0   36 months     13.61     C  10+ years           RENT
#
#         annual_inc verification_status  loan_status             purpose  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# grade                   0
# emp_length              0
# home_ownership          0
# annual_inc              0
# verification_status     0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# dtype: int64

# %% [markdown]
# # Funksiya+Encoding

# %%
def encodla(df):
    from sklearn.preprocessing import LabelEncoder
    encoder=LabelEncoder()
    for col in df.columns:
        if df[col].dtype=='object':
            if df[col].nunique()<=6:
                dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
                df=pd.concat([df.drop(columns=[col]),dummies],axis=1)
        else:
            encoder=LabelEncoder()
            df[col]=encoder.fit_transform(df[col])
    return df

# %%
encodla(df)
# Out:
#         loan_amnt  term  int_rate  grade  emp_length  home_ownership  \
# 0             367     0       131      1           1               5
# 1             287     0       152      1           4               1
# 2             591     0       104      1          10               5
# 3             255     0        10      0           6               5
# 4             942     1       344      2           9               1
# ...           ...   ...       ...    ...         ...             ...
# 396025        367     1       118      1           2               5
# 396026        807     0       162      2           5               1
# 396027        167     0        88      1           1               5
# 396028        807     1       287      2           1               1
# 396029         47     0       213      2           1               5
#
#         annual_inc  verification_status  loan_status  purpose  ...  \
# 0            24266                    0            1       12  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  int64
#  1   term                  396030 non-null  int64
#  2   int_rate              396030 non-null  int64
#  3   grade                 396030 non-null  int64
#  4   emp_length            396030 non-null  int64
#  5   home_ownership        396030 non-null  int64
#  6   annual_inc            396030 non-null  int64
#  7   verification_status   396030 non-null  int64
#  8   loan_status           396030 non-null  int64
#  9   purpose               396030 non-null  int64
#  10  dti                   396030 non-null  int64
#  11  earliest_cr_line      396030 non-null  int64
#  12  open_acc              396030 non-null  int64
#  13  pub_rec               396030 non-null  int64
#  14  revol_bal             396030 non-null  int64
# ...

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
def scaling_qil(df):
    scaler=MinMaxScaler()
    num_col=df.select_dtypes(include=['int64','float64']).columns.drop('loan_status')
    for col in num_col:
        df[col]=scaler.fit_transform(df[[col]])
    return df

# %%
scaling_qil(df)
# Out:
#         loan_amnt  term  int_rate     grade  emp_length  home_ownership  \
# 0        0.262894   0.0  0.231858  0.166667         0.1             1.0
# 1        0.205587   0.0  0.269027  0.166667         0.4             0.2
# 2        0.423352   0.0  0.184071  0.166667         1.0             1.0
# 3        0.182665   0.0  0.017699  0.000000         0.6             1.0
# 4        0.674785   1.0  0.608850  0.333333         0.9             0.2
# ...           ...   ...       ...       ...         ...             ...
# 396025   0.262894   1.0  0.208850  0.166667         0.2             1.0
# 396026   0.578080   0.0  0.286726  0.333333         0.5             0.2
# 396027   0.119628   0.0  0.155752  0.166667         0.1             1.0
# 396028   0.578080   1.0  0.507965  0.333333         0.1             0.2
# 396029   0.033668   0.0  0.376991  0.333333         0.1             1.0
#
#         annual_inc  verification_status  loan_status   purpose  ...  \
# ...

# %% [markdown]
# # Model

# %%
x=df.drop('loan_status',axis=1)

# %%
y=df['loan_status'].astype(int)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (277221, 20)

# %%
x_test.shape
# Out:
# (118809, 20)

# %%
y_train.shape
# Out:
# (277221,)

# %%
y_test.shape
# Out:
# (118809,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()

# %%
log_reg
# Out:
# LogisticRegression()

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log_reg.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
class_report=classification_report(y_test,y_pred)

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.08      0.13     23370
#            1       0.81      0.98      0.89     95439
#
#     accuracy                           0.80    118809
#    macro avg       0.67      0.53      0.51    118809
# weighted avg       0.76      0.80      0.74    118809
