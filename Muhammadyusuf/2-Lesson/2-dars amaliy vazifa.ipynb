# %% [markdown]
#  # Data Types

# %% [markdown]
# # 2-lesson amaliy vazifa

# %% [markdown]
# # 1-savol Istalgan so'zni boshidagi va oxiridagi xarfini topadigan kod yozing

# %%
word = "Windows"

print(word[0])   # birinchi harf
print(word[-1])  # oxirgi harf
# Out:
# W
# s

# %% [markdown]
# # 2-savol Berilgan ikki sonni musbat va juft ekanligini topadigan kod yozing

# %%
a = 6
b = -3

print(a > 0 and a % 2 == 0)
print(b > 0 and b % 2 == 0)
# Out:
# True
# False

# %% [markdown]
# # 3-savol Berilgan so'zni oxiridan ikkinchi xarfini topadigan kod yozing

# %%
word = "olma"

print(word[-2])
# Out:
# m

# %% [markdown]
# # 4-savol Istalgan sonni toq yoki manfiy ekanligini tekshiradigan kod yozing

# %%
num = -5

print(num < 0 or num % 2 == 1)
# Out:
# True
