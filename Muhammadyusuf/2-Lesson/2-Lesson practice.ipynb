# %% [markdown]
# # Data types

# %%
#int
#float
#str
#Boolean

# %%
#int 
a=2 
type(a)
# Out:
# int

# %%
#float
a=0.2 
type(a)
# Out:
# float

# %%
#str
s='Salom'
type(s)
# Out:
# str

# %%
#boolean
1>3
# Out:
# False

# %%
#boolean 
9<10
# Out:
# True

# %%
18==18
# Out:
# True

# %%
3!=3
# Out:
# False

# %% [markdown]
# # INDEXING

# %%
s='hello'
s[1]
# Out:
# 'e'

# %%
s[-1]
# Out:
# 'o'

# %% [markdown]
# # Opirations

# %%
# Math(+,-,*,/,//,%,**) 
a=25
b=5
a**b
# Out:
# 9765625

# %%
a%b   #bo‘lishdan qolgan qoldiqni chiqaradi
# Out:
# 0

# %%
a=7
b=5 
a//b  #butun qismini olish
# Out:
# 1

# %%
a/b  #bo'lish
# Out:
# 5.0

# %%
a*b #ko'paytirish
# Out:
# 125

# %%
a-b #ayirish
# Out:
# 20

# %%
a+b #qo'shish
# Out:
# 30

# %% [markdown]
# # Logic operation

# %%
# and---- ikkkala tomon togri bolish kk
# or ----- bitta tomon yoki ikkala tomon xam

# %% [markdown]
# # Comperative operation

# %%
# >,<, ==, !=
