# %% [markdown]
# # Data bilan tanishuv

# %%
import pandas as pd
df=pd.read_csv('user_music_listen_data.csv') 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       453 non-null    str
#  1   T_Swift       444 non-null    float64
#  2   Drake         439 non-null    float64
#  3   Queen         441 non-null    float64
#  4   The_Weeknd    442 non-null    float64
#  5   Eminem        444 non-null    float64
#  6   Nirvana       435 non-null    float64
#  7   Ed_Sheeran    449 non-null    float64
#  8   T_Scott       441 non-null    float64
#  9   Linkin_Park   443 non-null    float64
#  10  Dua_Lipa      445 non-null    float64
#  11  K_Lamar       438 non-null    float64
#  12  Imag_Dragons  439 non-null    float64
#  13  Ariana_G      440 non-null    float64
# dtypes: float64(13), str(1)
# memory usage: 49.7 KB

# %%
df = df.drop('User_ID', axis=1)

# %% [markdown]
# # Scaling

# %%
import pandas as pd
df=pd.read_csv('user_music_listen_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       453 non-null    str
#  1   T_Swift       444 non-null    float64
#  2   Drake         439 non-null    float64
#  3   Queen         441 non-null    float64
#  4   The_Weeknd    442 non-null    float64
#  5   Eminem        444 non-null    float64
#  6   Nirvana       435 non-null    float64
#  7   Ed_Sheeran    449 non-null    float64
#  8   T_Scott       441 non-null    float64
#  9   Linkin_Park   443 non-null    float64
#  10  Dua_Lipa      445 non-null    float64
#  11  K_Lamar       438 non-null    float64
#  12  Imag_Dragons  439 non-null    float64
#  13  Ariana_G      440 non-null    float64
# dtypes: float64(13), str(1)
# memory usage: 49.7 KB

# %%
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = df[col].fillna(df[col].median())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       453 non-null    str
#  1   T_Swift       453 non-null    float64
#  2   Drake         453 non-null    float64
#  3   Queen         453 non-null    float64
#  4   The_Weeknd    453 non-null    float64
#  5   Eminem        453 non-null    float64
#  6   Nirvana       453 non-null    float64
#  7   Ed_Sheeran    453 non-null    float64
#  8   T_Scott       453 non-null    float64
#  9   Linkin_Park   453 non-null    float64
#  10  Dua_Lipa      453 non-null    float64
#  11  K_Lamar       453 non-null    float64
#  12  Imag_Dragons  453 non-null    float64
#  13  Ariana_G      453 non-null    float64
# dtypes: float64(13), str(1)
# memory usage: 49.7 KB

# %%
df.isnull().sum()
# Out:
# User_ID         0
# T_Swift         0
# Drake           0
# Queen           0
# The_Weeknd      0
# Eminem          0
# Nirvana         0
# Ed_Sheeran      0
# T_Scott         0
# Linkin_Park     0
# Dua_Lipa        0
# K_Lamar         0
# Imag_Dragons    0
# Ariana_G        0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
# Object qiymatlar yoqligi uchun tashlab ketamiz

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       453 non-null    str
#  1   T_Swift       453 non-null    float64
#  2   Drake         453 non-null    float64
#  3   Queen         453 non-null    float64
#  4   The_Weeknd    453 non-null    float64
#  5   Eminem        453 non-null    float64
#  6   Nirvana       453 non-null    float64
#  7   Ed_Sheeran    453 non-null    float64
#  8   T_Scott       453 non-null    float64
#  9   Linkin_Park   453 non-null    float64
#  10  Dua_Lipa      453 non-null    float64
#  11  K_Lamar       453 non-null    float64
#  12  Imag_Dragons  453 non-null    float64
#  13  Ariana_G      453 non-null    float64
# dtypes: float64(13), str(1)
# memory usage: 49.7 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       453 non-null    str
#  1   T_Swift       453 non-null    float64
#  2   Drake         453 non-null    float64
#  3   Queen         453 non-null    float64
#  4   The_Weeknd    453 non-null    float64
#  5   Eminem        453 non-null    float64
#  6   Nirvana       453 non-null    float64
#  7   Ed_Sheeran    453 non-null    float64
#  8   T_Scott       453 non-null    float64
#  9   Linkin_Park   453 non-null    float64
#  10  Dua_Lipa      453 non-null    float64
#  11  K_Lamar       453 non-null    float64
#  12  Imag_Dragons  453 non-null    float64
#  13  Ariana_G      453 non-null    float64
# dtypes: float64(13), str(1)
# memory usage: 49.7 KB

# %% [markdown]
# # Scaling

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       453 non-null    str
#  1   T_Swift       453 non-null    float64
#  2   Drake         453 non-null    float64
#  3   Queen         453 non-null    float64
#  4   The_Weeknd    453 non-null    float64
#  5   Eminem        453 non-null    float64
#  6   Nirvana       453 non-null    float64
#  7   Ed_Sheeran    453 non-null    float64
#  8   T_Scott       453 non-null    float64
#  9   Linkin_Park   453 non-null    float64
#  10  Dua_Lipa      453 non-null    float64
#  11  K_Lamar       453 non-null    float64
#  12  Imag_Dragons  453 non-null    float64
#  13  Ariana_G      453 non-null    float64
# dtypes: float64(13), str(1)
# memory usage: 49.7 KB

# %%
df.head()
# Out:
#      User_ID  T_Swift  Drake  Queen  The_Weeknd  Eminem  Nirvana  Ed_Sheeran  \
# 0  User_1001     53.0    0.0   87.0       102.0     0.0     92.0       112.0
# 1  User_1002    144.0   46.0   53.0       194.0    31.0     44.0       150.0
# 2  User_1003      0.0   47.0   64.0       203.0    75.0     44.0       213.0
# 3  User_1004    136.0   45.0    0.0        97.0    40.0      0.0        71.0
# 4  User_1005    110.0   33.0   52.0       127.0    51.0     23.0        57.0
#
#    T_Scott  Linkin_Park  Dua_Lipa  K_Lamar  Imag_Dragons  Ariana_G
# 0     79.0         64.0       0.0     49.0         212.0     112.0
# 1     47.0         45.0     213.0     47.0         232.0     157.0
# 2     93.0         19.0     180.0    103.0         199.0     176.0
# 3     62.0         15.0     105.0     73.0         190.0     111.0
# 4      0.0          0.0      98.0     66.0         124.0      66.0

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

scaler = StandardScaler()

# %%
num_col=df.select_dtypes(include=['float64']).columns 
# target qiymat scaling qilinmaydi

# %%
num_col
# Out:
# Index(['T_Swift', 'Drake', 'Queen', 'The_Weeknd', 'Eminem', 'Nirvana',
#        'Ed_Sheeran', 'T_Scott', 'Linkin_Park', 'Dua_Lipa', 'K_Lamar',
#        'Imag_Dragons', 'Ariana_G'],
#       dtype='str')

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
df['Drake'] = scaler.fit_transform(df[['Drake']])

# %%
df.head()
# Out:
#      User_ID  T_Swift     Drake  Queen  The_Weeknd  Eminem  Nirvana  \
# 0  User_1001     53.0 -0.977637   87.0       102.0     0.0     92.0
# 1  User_1002    144.0 -0.224485   53.0       194.0    31.0     44.0
# 2  User_1003      0.0 -0.208112   64.0       203.0    75.0     44.0
# 3  User_1004    136.0 -0.240858    0.0        97.0    40.0      0.0
# 4  User_1005    110.0 -0.437333   52.0       127.0    51.0     23.0
#
#    Ed_Sheeran  T_Scott  Linkin_Park  Dua_Lipa  K_Lamar  Imag_Dragons  Ariana_G
# 0       112.0     79.0         64.0       0.0     49.0         212.0     112.0
# 1       150.0     47.0         45.0     213.0     47.0         232.0     157.0
# 2       213.0     93.0         19.0     180.0    103.0         199.0     176.0
# 3        71.0     62.0         15.0     105.0     73.0         190.0     111.0
# 4        57.0      0.0          0.0      98.0     66.0         124.0      66.0

# %% [markdown]
# # MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler
# Out:
# MinMaxScaler()

# %%
df['Queen'] = scaler.fit_transform(df[['Queen']])

# %%
df.head()
# Out:
#      User_ID  T_Swift     Drake     Queen  The_Weeknd  Eminem  Nirvana  \
# 0  User_1001     53.0 -0.977637  0.283388       102.0     0.0     92.0
# 1  User_1002    144.0 -0.224485  0.172638       194.0    31.0     44.0
# 2  User_1003      0.0 -0.208112  0.208469       203.0    75.0     44.0
# 3  User_1004    136.0 -0.240858  0.000000        97.0    40.0      0.0
# 4  User_1005    110.0 -0.437333  0.169381       127.0    51.0     23.0
#
#    Ed_Sheeran  T_Scott  Linkin_Park  Dua_Lipa  K_Lamar  Imag_Dragons  Ariana_G
# 0       112.0     79.0         64.0       0.0     49.0         212.0     112.0
# 1       150.0     47.0         45.0     213.0     47.0         232.0     157.0
# 2       213.0     93.0         19.0     180.0    103.0         199.0     176.0
# 3        71.0     62.0         15.0     105.0     73.0         190.0     111.0
# 4        57.0      0.0          0.0      98.0     66.0         124.0      66.0

# %% [markdown]
# # RobustScaler

# %%
scaler=RobustScaler()

# %%
scaler
# Out:
# RobustScaler()

# %%
df['The_Weeknd'] = scaler.fit_transform(df[['The_Weeknd']])

# %%
df.head()
# Out:
#      User_ID  T_Swift     Drake     Queen  The_Weeknd  Eminem  Nirvana  \
# 0  User_1001     53.0 -0.977637  0.283388   -0.093023     0.0     92.0
# 1  User_1002    144.0 -0.224485  0.172638    0.976744    31.0     44.0
# 2  User_1003      0.0 -0.208112  0.208469    1.081395    75.0     44.0
# 3  User_1004    136.0 -0.240858  0.000000   -0.151163    40.0      0.0
# 4  User_1005    110.0 -0.437333  0.169381    0.197674    51.0     23.0
#
#    Ed_Sheeran  T_Scott  Linkin_Park  Dua_Lipa  K_Lamar  Imag_Dragons  Ariana_G
# 0       112.0     79.0         64.0       0.0     49.0         212.0     112.0
# 1       150.0     47.0         45.0     213.0     47.0         232.0     157.0
# 2       213.0     93.0         19.0     180.0    103.0         199.0     176.0
# 3        71.0     62.0         15.0     105.0     73.0         190.0     111.0
# 4        57.0      0.0          0.0      98.0     66.0         124.0      66.0

# %% [markdown]
# # For loop + Scaling

# %%
#1-usul 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Faqat numeric ustunlarni tanlaymiz
numeric_cols = df.select_dtypes(include=['number']).columns

df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.head()
# Out:
#      User_ID   T_Swift     Drake     Queen  The_Weeknd    Eminem   Nirvana  \
# 0  User_1001  0.141711  0.000000  0.283388    0.303571  0.000000  0.363636
# 1  User_1002  0.385027  0.114144  0.172638    0.577381  0.121569  0.173913
# 2  User_1003  0.000000  0.116625  0.208469    0.604167  0.294118  0.173913
# 3  User_1004  0.363636  0.111663  0.000000    0.288690  0.156863  0.000000
# 4  User_1005  0.294118  0.081886  0.169381    0.377976  0.200000  0.090909
#
#    Ed_Sheeran   T_Scott  Linkin_Park  Dua_Lipa   K_Lamar  Imag_Dragons  \
# 0    0.358974  0.372642     0.212625  0.000000  0.174377      0.452026
# 1    0.480769  0.221698     0.149502  0.702970  0.167260      0.494670
# 2    0.682692  0.438679     0.063123  0.594059  0.366548      0.424307
# 3    0.227564  0.292453     0.049834  0.346535  0.259786      0.405117
# 4    0.182692  0.000000     0.000000  0.323432  0.234875      0.264392
#
#    Ariana_G
# 0  0.449799
# 1  0.630522
# 2  0.706827
# 3  0.445783
# 4  0.265060

# %%
num_col=df.select_dtypes(include=['float64']).columns

# %%
num_col
# Out:
# Index(['T_Swift', 'Drake', 'Queen', 'The_Weeknd', 'Eminem', 'Nirvana',
#        'Ed_Sheeran', 'T_Scott', 'Linkin_Park', 'Dua_Lipa', 'K_Lamar',
#        'Imag_Dragons', 'Ariana_G'],
#       dtype='str')

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#      User_ID   T_Swift     Drake     Queen  The_Weeknd    Eminem   Nirvana  \
# 0  User_1001  0.141711  0.000000  0.283388    0.303571  0.000000  0.363636
# 1  User_1002  0.385027  0.114144  0.172638    0.577381  0.121569  0.173913
# 2  User_1003  0.000000  0.116625  0.208469    0.604167  0.294118  0.173913
# 3  User_1004  0.363636  0.111663  0.000000    0.288690  0.156863  0.000000
# 4  User_1005  0.294118  0.081886  0.169381    0.377976  0.200000  0.090909
#
#    Ed_Sheeran   T_Scott  Linkin_Park  Dua_Lipa   K_Lamar  Imag_Dragons  \
# 0    0.358974  0.372642     0.212625  0.000000  0.174377      0.452026
# 1    0.480769  0.221698     0.149502  0.702970  0.167260      0.494670
# 2    0.682692  0.438679     0.063123  0.594059  0.366548      0.424307
# 3    0.227564  0.292453     0.049834  0.346535  0.259786      0.405117
# 4    0.182692  0.000000     0.000000  0.323432  0.234875      0.264392
#
#    Ariana_G
# 0  0.449799
# 1  0.630522
# 2  0.706827
# 3  0.445783
# 4  0.265060

# %%
#2-usul 
num_col=df.select_dtypes(include=['float64']).columns
for col in num_col:
    df[col]=scaler.fit_transform(df[[col]])

# %%
df.head()
# Out:
#      User_ID   T_Swift     Drake     Queen  The_Weeknd    Eminem   Nirvana  \
# 0  User_1001  0.141711  0.000000  0.283388    0.303571  0.000000  0.363636
# 1  User_1002  0.385027  0.114144  0.172638    0.577381  0.121569  0.173913
# 2  User_1003  0.000000  0.116625  0.208469    0.604167  0.294118  0.173913
# 3  User_1004  0.363636  0.111663  0.000000    0.288690  0.156863  0.000000
# 4  User_1005  0.294118  0.081886  0.169381    0.377976  0.200000  0.090909
#
#    Ed_Sheeran   T_Scott  Linkin_Park  Dua_Lipa   K_Lamar  Imag_Dragons  \
# 0    0.358974  0.372642     0.212625  0.000000  0.174377      0.452026
# 1    0.480769  0.221698     0.149502  0.702970  0.167260      0.494670
# 2    0.682692  0.438679     0.063123  0.594059  0.366548      0.424307
# 3    0.227564  0.292453     0.049834  0.346535  0.259786      0.405117
# 4    0.182692  0.000000     0.000000  0.323432  0.234875      0.264392
#
#    Ariana_G
# 0  0.449799
# 1  0.630522
# 2  0.706827
# 3  0.445783
# 4  0.265060
