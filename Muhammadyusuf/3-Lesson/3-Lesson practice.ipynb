# %% [markdown]
# # data types

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.0

# %%
import pandas as pd 
df=pd.read_csv('Premier_League_Player_Statistics_2023-24_20260207_050947.csv')

# %%
df.head() # datani boshini so'rash uchun ishlatamiz # eng ko'p ishlatiladigan cod
# Out:
#            Player              Team    Position Position_Group  Appearances  \
# 0  Erling Haaland   Manchester City     Forward            FWD           31
# 1     Cole Palmer           Chelsea  Midfielder            MID           33
# 2  Alexander Isak  Newcastle United     Forward            FWD           30
# 3   Ollie Watkins       Aston Villa     Forward            FWD           35
# 4   Mohamed Salah         Liverpool     Forward            FWD           32
#
#    Minutes  Minutes_Per_Appearance  Goals  Assists  Goal_Contributions  ...  \
# 0     2580                      83     27        5                  32  ...
# 1     2880                      87     22       11                  33  ...
# 2     2550                      85     21        2                  23  ...
# 3     3050                      87     19       13                  32  ...
# 4     2750                      86     18       10                  28  ...
#
# ...

# %%
df.head(5) # o'zingizga kerakli qatorgacha so'rash uchun qavs ishiga qatorni raqamini kirgizing
# Out:
#            Player              Team    Position Position_Group  Appearances  \
# 0  Erling Haaland   Manchester City     Forward            FWD           31
# 1     Cole Palmer           Chelsea  Midfielder            MID           33
# 2  Alexander Isak  Newcastle United     Forward            FWD           30
# 3   Ollie Watkins       Aston Villa     Forward            FWD           35
# 4   Mohamed Salah         Liverpool     Forward            FWD           32
#
#    Minutes  Minutes_Per_Appearance  Goals  Assists  Goal_Contributions  ...  \
# 0     2580                      83     27        5                  32  ...
# 1     2880                      87     22       11                  33  ...
# 2     2550                      85     21        2                  23  ...
# 3     3050                      87     19       13                  32  ...
# 4     2750                      86     18       10                  28  ...
#
# ...

# %%
df.tail()   # datani tag qismidan ko'rish
# Out:
#              Player     Team    Position Position_Group  Appearances  Minutes  \
# 47  Raheem Sterling  Chelsea     Forward            FWD           31     2010
# 48       Pedro Neto   Wolves     Forward            FWD           20     1380
# 49   Hwang Hee-chan   Wolves     Forward            FWD           30     1950
# 50     Amadou Onana  Everton  Midfielder            MID           30     2450
# 51     Ashley Young  Everton    Defender            DEF           29     2280
#
#     Minutes_Per_Appearance  Goals  Assists  Goal_Contributions  ...  \
# 47                      65      8        4                  12  ...
# 48                      69      2        9                  11  ...
# 49                      65     12        2                  14  ...
# 50                      82      3        2                   5  ...
# 51                      79      0        1                   1  ...
#
#     Efficiency_Rank  Performance_Category  Discipline_Category  \
# ...

# %%
df.tail(3)  # o'zingizga kerakli qatorgacha so'rash uchun qavs ishiga qatorni raqamini kirgizing
# Out:
#             Player     Team    Position Position_Group  Appearances  Minutes  \
# 49  Hwang Hee-chan   Wolves     Forward            FWD           30     1950
# 50    Amadou Onana  Everton  Midfielder            MID           30     2450
# 51    Ashley Young  Everton    Defender            DEF           29     2280
#
#     Minutes_Per_Appearance  Goals  Assists  Goal_Contributions  ...  \
# 49                      65     12        2                  14  ...
# 50                      82      3        2                   5  ...
# 51                      79      0        1                   1  ...
#
#     Efficiency_Rank  Performance_Category  Discipline_Category  \
# 49               23     Excellent (10-14)            Excellent
# 50               51            Good (5-9)                 Fair
# 51               52      Developing (0-4)                 Poor
#
#     Efficiency_Rating   Season     Competition  Country  \
# 49               1.28  2023/24  Premier League  England
# ...

# %%
df.nunique() # xar bir ustunlar sonini aniqlash uchun ishlatamiz # class lar sonini topish
# Out:
# Player                       52
# Team                         15
# Position                      4
# Position_Group                4
# Appearances                  18
# Minutes                      40
# Minutes_Per_Appearance       25
# Goals                        20
# Assists                      13
# Goal_Contributions           24
# Goals_Per_90                 36
# Assists_Per_90               29
# Goal_Contributions_Per_90    39
# Minutes_Per_Goal             49
# Minutes_Per_Assist           49
# Yellow_Cards                 12
# Red_Cards                     3
# Discipline_Score             12
# Clean_Sheets                 10
# Clean_Sheet_Percentage       11
# Goals_Rank                   20
# Assists_Rank                 13
# Goal_Contributions_Rank      24
# Clean_Sheets_Rank            10
# Efficiency_Rank              46
# Performance_Category          5
# Discipline_Category           5
# Efficiency_Rating            46
# Season                        1
# ...

# %%
df['Team'].nunique()  # ma'lum bir ustundi ajratib olish kerak bo'lsa ishlatamiz
# Out:
# 15

# %%
df['Team'] # Ma'lum bir bitta ustundi ajratib olish uchun ishlatamiz
# Out:
# 0       Manchester City
# 1               Chelsea
# 2      Newcastle United
# 3           Aston Villa
# 4             Liverpool
# 5       Manchester City
# 6               Arsenal
# 7             Tottenham
# 8           Bournemouth
# 9              West Ham
# 10    Manchester United
# 11      Manchester City
# 12              Arsenal
# 13            Tottenham
# 14     Newcastle United
# 15              Arsenal
# 16              Arsenal
# 17            Liverpool
# 18      Manchester City
# 19      Manchester City
# 20              Arsenal
# 21            Liverpool
# 22      Manchester City
# 23          Aston Villa
# 24              Arsenal
# 25              Arsenal
# 26      Manchester City
# 27              Arsenal
# 28            Liverpool
# 29      Manchester City
# 30              Chelsea
# 31       Crystal Palace
# 32       Crystal Palace
# 33            Liverpool
# 34            Tottenham
# 35            Tottenham
# 36              Arsenal
# 37      Manchester City
# ...

# %%
df[['Team','Position']]  # Ma'lum 2,3 va h.k qatorlarni ajratib olish uchun ishlatamiz
# Out:
#                  Team    Position
# 0     Manchester City     Forward
# 1             Chelsea  Midfielder
# 2    Newcastle United     Forward
# 3         Aston Villa     Forward
# 4           Liverpool     Forward
# 5     Manchester City  Midfielder
# 6             Arsenal     Forward
# 7           Tottenham     Forward
# 8         Bournemouth     Forward
# 9            West Ham     Forward
# 10  Manchester United  Midfielder
# 11    Manchester City  Midfielder
# 12            Arsenal  Midfielder
# 13          Tottenham  Midfielder
# 14   Newcastle United     Forward
# 15            Arsenal    Defender
# 16            Arsenal    Defender
# 17          Liverpool    Defender
# 18    Manchester City    Defender
# 19    Manchester City    Defender
# 20            Arsenal  Goalkeeper
# 21          Liverpool  Goalkeeper
# 22    Manchester City  Goalkeeper
# 23        Aston Villa  Goalkeeper
# 24            Arsenal  Goalkeeper
# 25            Arsenal  Midfielder
# ...

# %%
df.info()  # Datada umumiy ma'lumot olish uchun ishlatamiz
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Player                     52 non-null     str
#  1   Team                       52 non-null     str
#  2   Position                   52 non-null     str
#  3   Position_Group             52 non-null     str
#  4   Appearances                52 non-null     int64
#  5   Minutes                    52 non-null     int64
#  6   Minutes_Per_Appearance     52 non-null     int64
#  7   Goals                      52 non-null     int64
#  8   Assists                    52 non-null     int64
#  9   Goal_Contributions         52 non-null     int64
#  10  Goals_Per_90               52 non-null     float64
#  11  Assists_Per_90             52 non-null     float64
#  12  Goal_Contributions_Per_90  52 non-null     float64
#  13  Minutes_Per_Goal           52 non-null     int64
# ...

# %%
df.isnull().sum()  # aniq sonlar orqali ustunlar va ularda tushib qolgan qiymatlar topish
# Out:
# Player                       0
# Team                         0
# Position                     0
# Position_Group               0
# Appearances                  0
# Minutes                      0
# Minutes_Per_Appearance       0
# Goals                        0
# Assists                      0
# Goal_Contributions           0
# Goals_Per_90                 0
# Assists_Per_90               0
# Goal_Contributions_Per_90    0
# Minutes_Per_Goal             0
# Minutes_Per_Assist           0
# Yellow_Cards                 0
# Red_Cards                    0
# Discipline_Score             0
# Clean_Sheets                 0
# Clean_Sheet_Percentage       0
# Goals_Rank                   0
# Assists_Rank                 0
# Goal_Contributions_Rank      0
# Clean_Sheets_Rank            0
# Efficiency_Rank              0
# Performance_Category         0
# Discipline_Category          0
# Efficiency_Rating            0
# Season                       0
# Competition                  0
# ...

# %%
df.isnull().any()  # boolean orqali topish
# Out:
# Player                       False
# Team                         False
# Position                     False
# Position_Group               False
# Appearances                  False
# Minutes                      False
# Minutes_Per_Appearance       False
# Goals                        False
# Assists                      False
# Goal_Contributions           False
# Goals_Per_90                 False
# Assists_Per_90               False
# Goal_Contributions_Per_90    False
# Minutes_Per_Goal             False
# Minutes_Per_Assist           False
# Yellow_Cards                 False
# Red_Cards                    False
# Discipline_Score             False
# Clean_Sheets                 False
# Clean_Sheet_Percentage       False
# Goals_Rank                   False
# Assists_Rank                 False
# Goal_Contributions_Rank      False
# Clean_Sheets_Rank            False
# Efficiency_Rank              False
# Performance_Category         False
# Discipline_Category          False
# ...

# %% [markdown]
# # Conditions

# %%
# agar son musbat bo'lsa yaxshi aks holda yomon degan so'zni ekranga chiqarish

# %%
a=2
if a>1: 
    print('yaxshi')
# Out:
# yaxshi

# %%
a=-0
if a>0: 
    print('yaxshi') 
elif a<0:
    print('yomon') 
else:
    print('nol')
# Out:
# nol

# %%
baho=5
if baho==8:
    print('alo')
elif baho==7:
    print('yaxshi') 
elif baho==6:
    print('namunali') 
elif baho==5: 
    print('qoniqarsiz') 
else:
    print('juda yomon')
# Out:
# qoniqarsiz
