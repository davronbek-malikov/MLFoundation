# %%
# Imtixondan o'tishni nazorat qilish uchun  condition tuzing
# Pasport olish uchun condition tuzing

# %% [markdown]
# # 1-vazifa Imtixondan o'tishni nazorat qilish uchun  condition tuzing

# %%
a = 0

if a > 8:
    print("You passed the next exam")
elif a < 1:
    print("You are disqualified from the exam")
else:
    print("You failed the next exam")
# Out:
# You are disqualified from the exam

# %% [markdown]
# # 2-vazifa Pasport olish uchun condition tuzing

# %%
yosh = 12

if yosh >= 16:
    print("Pasport olasiz")
elif yosh <=15:
    print("Pasport olaolmaysiz")
# Out:
# Pasport olaolmaysiz
