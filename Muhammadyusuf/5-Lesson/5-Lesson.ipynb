# %% [markdown]
# # Encoding 5-Lesson

# %%
import pandas as pd 
df=pd.read_csv('cars.csv')

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.info()
#
# Cell In[37], line 1
# ----> 1 df.info()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\debugpy\_vendored\pydevd\pydevd.py:2199, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2196             from_this_thread.append(frame_custom_thread_id)
#    2198     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2199         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2201 frames_list = None
#    2203 if keep_suspended:
#    2204     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\debugpy\_vendored\pydevd\pydevd.py:2268, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2265                 queue.put(internal_cmd)
#    2266                 wait_timeout = TIMEOUT_FAST
# -> 2268         notify_event.wait(wait_timeout)
#    2269         notify_event.clear()
#    2271 finally:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
df.drop('Price',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.drop('Price',axis=1,inplace=True)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Price'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            2095 non-null   int64
#  1   Model         2095 non-null   str
#  2   Year          2095 non-null   int64
#  3   Condition     2095 non-null   str
#  4   Fuel Type     2095 non-null   str
#  5   Mileage       2095 non-null   str
#  6   Seller Type   2095 non-null   str
#  7   Location      2095 non-null   str
#  8   Insurance     2095 non-null   str
#  9   Transmission  2095 non-null   str
#  10  Color         2095 non-null   str
# dtypes: int64(2), str(9)
# memory usage: 180.2 KB

# %%
df.isnull().sum()
# Out:
# ID              0
# Model           0
# Year            0
# Condition       0
# Fuel Type       0
# Mileage         0
# Seller Type     0
# Location        0
# Insurance       0
# Transmission    0
# Color           0
# dtype: int64

# %%
df.nunique()
# Out:
# ID              2095
# Model            610
# Year              40
# Condition          2
# Fuel Type          5
# Mileage           30
# Seller Type        5
# Location         242
# Insurance          4
# Transmission       2
# Color             20
# dtype: int64

# %% [markdown]
# # One- Hot encoding

# %%
dummies=pd.get_dummies(df['Transmission'],prefix='ustun',dtype=int)

# %%
dummies
# Out:
#       ustun_Automatic  ustun_manual
# 0                   1             0
# 1                   1             0
# 2                   1             0
# 3                   1             0
# 4                   1             0
# ...               ...           ...
# 2090                1             0
# 2091                1             0
# 2092                1             0
# 2093                1             0
# 2094                1             0
#
# [2095 rows x 2 columns]

# %%
df=pd.concat([df.drop(columns=['Transmission']),dummies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2095 non-null   int64
#  1   Model            2095 non-null   str
#  2   Year             2095 non-null   int64
#  3   Condition        2095 non-null   str
#  4   Fuel Type        2095 non-null   str
#  5   Mileage          2095 non-null   str
#  6   Seller Type      2095 non-null   str
#  7   Location         2095 non-null   str
#  8   Insurance        2095 non-null   str
#  9   Color            2095 non-null   str
#  10  ustun_Automatic  2095 non-null   int64
#  11  ustun_manual     2095 non-null   int64
# dtypes: int64(4), str(8)
# memory usage: 196.5 KB

# %% [markdown]
# # Lebel Encoding

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2095 non-null   int64
#  1   Model            2095 non-null   str
#  2   Year             2095 non-null   int64
#  3   Condition        2095 non-null   str
#  4   Fuel Type        2095 non-null   str
#  5   Mileage          2095 non-null   str
#  6   Seller Type      2095 non-null   str
#  7   Location         2095 non-null   str
#  8   Insurance        2095 non-null   str
#  9   Color            2095 non-null   str
#  10  ustun_Automatic  2095 non-null   int64
#  11  ustun_manual     2095 non-null   int64
# dtypes: int64(4), str(8)
# memory usage: 196.5 KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder

# %%
encoder
# Out:
# sklearn.preprocessing._label.LabelEncoder

# %%
encoder = LabelEncoder()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['Location']=encoder.fit_transform(df['Location'])
#
# TypeError: LabelEncoder.fit_transform() missing 1 required positional argument: 'y'

# %%
df['']=encoder.fit_transform(df[''])
