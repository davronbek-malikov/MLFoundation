# %% [markdown]
# # Data bn tanishuv

# %%
import pandas as pd
df=pd.read_csv('Darslar ipynb\synthetic_dataset.csv')

# %%
df=pd.read_csv('Darslar ipynb\synthetic_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  1614 non-null   object
#  1   Price     4188 non-null   float64
#  2   Rating    2312 non-null   float64
#  3   Stock     3010 non-null   object
#  4   Discount  3970 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 170.5+ KB

# %%
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df.drop(['Category'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     4188 non-null   float64
#  1   Rating    2312 non-null   float64
#  2   Stock     3010 non-null   object
#  3   Discount  3970 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 136.4+ KB

# %% [markdown]
# # Scaling

# %%
import pandas as pd
df=pd.read_csv('Darslar ipynb\synthetic_dataset.csv')

# %%
df=pd.read_csv('Darslar ipynb\synthetic_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  1614 non-null   object
#  1   Price     4188 non-null   float64
#  2   Rating    2312 non-null   float64
#  3   Stock     3010 non-null   object
#  4   Discount  3970 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 170.5+ KB

# %% [markdown]
# # For loop orqali missing qiymatlarni tozalang(5 tasini ishlatishga xarakat qiling)

# %%
for col in df.columns:
    if col=='Stock':
        df['Stock'].fillna('In Stock',inplace=True)
    else:
      if df[col].isnull().any():
        if df[col].dtype == 'object':
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
            if abs(df[col].skew())>1:
                df[col].fillna(df[col].median(),inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  4362 non-null   object
#  1   Price     4362 non-null   float64
#  2   Rating    4362 non-null   float64
#  3   Stock     4362 non-null   object
#  4   Discount  4362 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 170.5+ KB

# %%
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0        C  5548.0  1.870322      In Stock       0.0
# 1        C  3045.0  4.757798      In Stock      38.0
# 2        C  4004.0  3.038293      In Stock       0.0
# 3        C  4808.0  1.492085      In Stock      33.0
# 4        C  1817.0  3.038293  Out of Stock      23.0

# %%
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype == 'object':
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
            if abs(df[col].skew()>1):
                df[col].fillna(df[col].median(),inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
                continue
            df['Stock'].fillna('In Stock',axis=1,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12016\4008447581.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_12016\4008447581.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0        C  5548.0  1.870322      In Stock       0.0
# 1        C  3045.0  4.757798      In Stock      38.0
# 2        C  4004.0  3.038293      In Stock       0.0
# 3        C  4808.0  1.492085      In Stock      33.0
# 4        C  1817.0  3.038293  Out of Stock      23.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  4362 non-null   object
#  1   Price     4362 non-null   float64
#  2   Rating    4362 non-null   float64
#  3   Stock     4362 non-null   object
#  4   Discount  4362 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 170.5+ KB

# %%
df.isnull().sum()
# Out:
# Category    0
# Price       0
# Rating      0
# Stock       0
# Discount    0
# dtype: int64

# %%
df.nunique()
# Out:
# Category       4
# Price       3423
# Rating      2313
# Stock          2
# Discount      51
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype=='object':
        if df[col].nunique()<=2:
            dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
            df=pd.concat([df.drop(columns=col),dummies],axis=1)
        else:
            df[col]=encoder.fit_transform(df[col])

# %% [markdown]
# # Scaling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Category            4362 non-null   int64
#  1   Price               4362 non-null   float64
#  2   Rating              4362 non-null   float64
#  3   Discount            4362 non-null   float64
#  4   Stock_In Stock      4362 non-null   int64
#  5   Stock_Out of Stock  4362 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 204.6 KB

# %%
df.head()
# Out:
#    Category   Price    Rating  Discount  Stock_In Stock  Stock_Out of Stock
# 0         2  5548.0  1.870322       0.0               1                   0
# 1         2  3045.0  4.757798      38.0               1                   0
# 2         2  4004.0  3.038293       0.0               1                   0
# 3         2  4808.0  1.492085      33.0               1                   0
# 4         2  1817.0  3.038293      23.0               0                   1

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns.drop(['Category']) 
#izoh target qiymat scaling qilindmaydi

# %%
num_col
# Out:
# Index(['Price', 'Rating', 'Discount', 'Stock_In Stock', 'Stock_Out of Stock'], dtype='object')

# %% [markdown]
# # StandardSCaler

# %%
scaler=StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
df['Price']=scaler.fit_transform(df[['Price']])

# %%
df.head()
# Out:
#    Category     Price    Rating  Discount  Stock_In Stock  Stock_Out of Stock
# 0         2  0.190851  1.870322       0.0               1                   0
# 1         2 -0.708722  4.757798      38.0               1                   0
# 2         2 -0.364059  3.038293       0.0               1                   0
# 3         2 -0.075104  1.492085      33.0               1                   0
# 4         2 -1.150062  3.038293      23.0               0                   1

# %% [markdown]
# # MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler
# Out:
# MinMaxScaler()

# %%
df['Discount']=scaler.fit_transform(df[['Discount']])

# %%
df.head()
# Out:
#    Category     Price    Rating  Discount  Stock_In Stock  Stock_Out of Stock
# 0         2  0.190851  1.870322  0.000000               1                   0
# 1         2 -0.708722  4.757798  0.775510               1                   0
# 2         2 -0.364059  3.038293  0.000000               1                   0
# 3         2 -0.075104  1.492085  0.673469               1                   0
# 4         2 -1.150062  3.038293  0.469388               0                   1

# %% [markdown]
# # RobustScaler

# %%
scaler=RobustScaler()

# %%
scaler
# Out:
# RobustScaler()

# %%
df['Rating']=scaler.fit_transform(df[['Rating']])

# %%
df.head()
# Out:
#    Category     Price    Rating  Discount  Stock_In Stock  Stock_Out of Stock
# 0         2  0.190851 -5.054888  0.000000               1                   0
# 1         2 -0.708722  7.441890  0.775510               1                   0
# 2         2 -0.364059  0.000000  0.000000               1                   0
# 3         2 -0.075104 -6.691870  0.673469               1                   0
# 4         2 -1.150062  0.000000  0.469388               0                   1

# %% [markdown]
# # For Loop + Scaling

# %%
#1-usul
scaler=MinMaxScaler()
for col in df.columns:
    if df[col].dtype!='object':
        df[col]=scaler.fit_transform(df[[col]])

# %%
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns
df.drop(['Category'],axis=1)
# izoh Target qiymat scaling qilinmaydi
# Out:
#        Price    Rating         Stock  Discount
# 0     5548.0  1.870322           NaN       0.0
# 1     3045.0  4.757798           NaN      38.0
# 2     4004.0       NaN      In Stock       0.0
# 3     4808.0  1.492085           NaN      33.0
# 4     1817.0       NaN  Out of Stock      23.0
# ...      ...       ...           ...       ...
# 4357  4436.0  4.728335           NaN      49.0
# 4358  6236.0       NaN  Out of Stock       4.0
# 4359  3283.0       NaN  Out of Stock       9.0
# 4360  2999.0  4.425995           NaN      40.0
# 4361     NaN  2.184471           NaN       0.0
#
# [4362 rows x 4 columns]

# %%
num_col
# Out:
# Index(['Price', 'Rating', 'Discount'], dtype='object')

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#    Category     Price    Rating  Discount  Stock_In Stock  Stock_Out of Stock
# 0         4  0.550268  0.217628  0.000000               0                   0
# 1         4  0.297363  0.939957  0.775510               0                   0
# 2         4  0.394261       NaN  0.000000               1                   0
# 3         4  0.475498  0.123008  0.673469               0                   0
# 4         4  0.173285       NaN  0.469388               0                   1

# %%
# 2 usul
num_col=df.select_dtypes(include=['int64' , 'float64']).columns.drop('Category')
for col in num_col:
    df[col]=scaler.fit_transform(df[[col]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Category            4362 non-null   int64
#  1   Price               4188 non-null   float64
#  2   Rating              2312 non-null   float64
#  3   Discount            3970 non-null   float64
#  4   Stock_In Stock      4362 non-null   float64
#  5   Stock_Out of Stock  4362 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 204.6 KB

# %%
df.head()
# Out:
#    Category     Price    Rating  Discount  Stock_In Stock  Stock_Out of Stock
# 0         4  0.550268  0.217628  0.000000             0.0                 0.0
# 1         4  0.297363  0.939957  0.775510             0.0                 0.0
# 2         4  0.394261       NaN  0.000000             1.0                 0.0
# 3         4  0.475498  0.123008  0.673469             0.0                 0.0
# 4         4  0.173285       NaN  0.469388             0.0                 1.0
