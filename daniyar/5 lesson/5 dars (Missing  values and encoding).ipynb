# %% [markdown]
# # Encoding

# %%
df=pd.read_csv('Sales_with_NaNs_v1.3.csv')

# %%
df.head()
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4        NaN       High Value    229.685623          NaN
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Group                         8599 non-null   object
#  1   Customer_Segment              8034 non-null   object
#  2   Sales_Before                  8478 non-null   float64
#  3   Sales_After                   9233 non-null   float64
#  4   Customer_Satisfaction_Before  8330 non-null   float64
#  5   Customer_Satisfaction_After   8360 non-null   float64
#  6   Purchase_Made                 9195 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %% [markdown]
# # Keraksiz ustunlarni tashlab yuborish

# %%
df.drop('Customer_Segment',axis=1)
# Out:
#           Group  Sales_Before  Sales_After  Customer_Satisfaction_Before  \
# 0       Control    240.548359   300.007568                     74.684767
# 1     Treatment    246.862114   381.337555                    100.000000
# 2       Control    156.978084   179.330464                     98.780735
# 3       Control    192.126708   229.278031                     49.333766
# 4           NaN    229.685623          NaN                     83.974852
# ...         ...           ...          ...                           ...
# 9995  Treatment    259.695935   415.181694                     88.438776
# 9996    Control    186.488285   216.225457                     92.261537
# 9997  Treatment    208.107142   322.893351                     55.915870
# 9998  Treatment           NaN   431.974901                     66.082462
# 9999    Control           NaN   124.402398                     55.692277
#
#       Customer_Satisfaction_After Purchase_Made
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Group                         8599 non-null   object
#  1   Customer_Segment              8034 non-null   object
#  2   Sales_Before                  8478 non-null   float64
#  3   Sales_After                   9233 non-null   float64
#  4   Customer_Satisfaction_Before  8330 non-null   float64
#  5   Customer_Satisfaction_After   8360 non-null   float64
#  6   Purchase_Made                 9195 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df.isnull().sum()
# Out:
# Group                           1401
# Customer_Segment                1966
# Sales_Before                    1522
# Sales_After                      767
# Customer_Satisfaction_Before    1670
# Customer_Satisfaction_After     1640
# Purchase_Made                    805
# dtype: int64

# %% [markdown]
# # Mean

# %%
df['Sales_Before'].fillna(df['Sales_Before'].mean(),inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13172\3207146027.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sales_Before'].fillna(df['Sales_Before'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Group                           1401
# Customer_Segment                1966
# Sales_Before                       0
# Sales_After                      767
# Customer_Satisfaction_Before    1670
# Customer_Satisfaction_After     1640
# Purchase_Made                    805
# dtype: int64

# %% [markdown]
# # Mode

# %%
df['Group'].fillna(df['Group'].mode()[0],inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13172\486326339.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Group'].fillna(df['Group'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Group                              0
# Customer_Segment                1966
# Sales_Before                       0
# Sales_After                      767
# Customer_Satisfaction_Before    1670
# Customer_Satisfaction_After     1640
# Purchase_Made                    805
# dtype: int64

# %% [markdown]
# # Median

# %%
df['Sales_After'].fillna(df['Sales_After'].median(),inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13172\3570922985.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sales_After'].fillna(df['Sales_After'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Group                              0
# Customer_Segment                1966
# Sales_Before                       0
# Sales_After                        0
# Customer_Satisfaction_Before    1670
# Customer_Satisfaction_After     1640
# Purchase_Made                    805
# dtype: int64

# %%
df.describe()
# Out:
#        Sales_Before   Sales_After  Customer_Satisfaction_Before  \
# count  10000.000000  10000.000000                   8330.000000
# mean     203.716998    279.895835                     70.252076
# std       50.892795     82.331734                     16.957010
# min       24.852966     32.414352                     22.202441
# 25%      173.612027    226.217125                     56.365513
# 50%      203.716998    273.129170                     69.490898
# 75%      230.990024    326.736168                     83.426798
# max      545.422547    818.219997                    100.000000
#
#        Customer_Satisfaction_After
# count                  8360.000000
# mean                     73.872593
# std                      18.128351
# min                      18.224938
# 25%                      59.925030
# 50%                      73.844594
# 75%                      90.044365
# max                     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Group                         10000 non-null  object
#  1   Customer_Segment              8034 non-null   object
#  2   Sales_Before                  10000 non-null  float64
#  3   Sales_After                   10000 non-null  float64
#  4   Customer_Satisfaction_Before  8330 non-null   float64
#  5   Customer_Satisfaction_After   8360 non-null   float64
#  6   Purchase_Made                 9195 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df.head()
# Out:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4    Control       High Value    229.685623   273.129170
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                          NaN            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes

# %% [markdown]
# # Fixed

# %%
df['Purchase_Made'].fillna('Yes',inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13172\2708597007.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Purchase_Made'].fillna('Yes',inplace=True)

# %%
df.isnull().sum()
# Out:
# Group                              0
# Customer_Segment                1966
# Sales_Before                       0
# Sales_After                        0
# Customer_Satisfaction_Before    1670
# Customer_Satisfaction_After     1640
# Purchase_Made                      0
# dtype: int64

# %% [markdown]
# # Drop qatorlar boyicha

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Group                           0
# Customer_Segment                0
# Sales_Before                    0
# Sales_After                     0
# Customer_Satisfaction_Before    0
# Customer_Satisfaction_After     0
# Purchase_Made                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5558 entries, 1 to 9999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Group                         5558 non-null   object
#  1   Customer_Segment              5558 non-null   object
#  2   Sales_Before                  5558 non-null   float64
#  3   Sales_After                   5558 non-null   float64
#  4   Customer_Satisfaction_Before  5558 non-null   float64
#  5   Customer_Satisfaction_After   5558 non-null   float64
#  6   Purchase_Made                 5558 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 347.4+ KB

# %% [markdown]
# # drop ustun boyicha, malum bir ustunda juda kop(50% dan kop) qiymatlar tushib qolganda tashlab yuboramiz bu usutunni butunlay

# %%
df.drop('Group',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_Segment                0
# Sales_Before                    0
# Sales_After                     0
# Customer_Satisfaction_Before    0
# Customer_Satisfaction_After     0
# Purchase_Made                   0
# dtype: int64

# %%
dummies=pd.get_dummies(df['Customer_Segment'],prefix='ustun',dtype=int)

# %%
dummies
# Out:
#       ustun_High Value  ustun_Low Value  ustun_Medium Value
# 1                    1                0                   0
# 2                    1                0                   0
# 3                    0                0                   1
# 4                    1                0                   0
# 6                    1                0                   0
# ...                ...              ...                 ...
# 9989                 0                0                   1
# 9992                 0                0                   1
# 9996                 1                0                   0
# 9998                 0                0                   1
# 9999                 0                1                   0
#
# [5558 rows x 3 columns]

# %%
df=pd.concat([df.drop(columns=['Customer_Segment']),dummies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5558 entries, 1 to 9999
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sales_Before                  5558 non-null   float64
#  1   Sales_After                   5558 non-null   float64
#  2   Customer_Satisfaction_Before  5558 non-null   float64
#  3   Customer_Satisfaction_After   5558 non-null   float64
#  4   Purchase_Made                 5558 non-null   object
#  5   ustun_High Value              5558 non-null   int64
#  6   ustun_Low Value               5558 non-null   int64
#  7   ustun_Medium Value            5558 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 390.8+ KB

# %%
df=pd.concat(df_1,df_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df=pd.concat(df_1,df_2)
#
# NameError: name 'df_1' is not defined

# %%
df['Customer_Segment']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer_Segment'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['ustun_High Value']
# Out:
# 1       1
# 2       1
# 3       0
# 4       1
# 6       1
#        ..
# 9989    0
# 9992    0
# 9996    1
# 9998    0
# 9999    0
# Name: ustun_High Value, Length: 5558, dtype: int64

# %%
print(df.index)
# Out:
# Index([   1,    2,    3,    4,    6,    7,    8,    9,   11,   13,
#        ...
#        9981, 9983, 9984, 9985, 9987, 9989, 9992, 9996, 9998, 9999],
#       dtype='int64', length=5558)

# %%
df = df.reset_index(drop=True)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=5558, step=1)

# %% [markdown]
# # Label Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5558 entries, 0 to 5557
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sales_Before                  5558 non-null   float64
#  1   Sales_After                   5558 non-null   float64
#  2   Customer_Satisfaction_Before  5558 non-null   float64
#  3   Customer_Satisfaction_After   5558 non-null   float64
#  4   Purchase_Made                 5558 non-null   object
#  5   ustun_High Value              5558 non-null   int64
#  6   ustun_Low Value               5558 non-null   int64
#  7   ustun_Medium Value            5558 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 347.5+ KB

# %%
import pandas as pd

# %%
# !pip install scikit-learn
# Out:
# ...
#   Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.1 MB 4.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/8.1 MB 5.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/8.1 MB 6.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.1 MB 7.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/8.1 MB 8.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.1 MB 9.0 MB/s eta 0:00:01
#    -------------- ------------------------- 3.0/8.1 MB 9.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.6/8.1 MB 9.9 MB/s eta 0:00:01
#    -------------------- ------------------- 4.1/8.1 MB 9.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 10.0 MB/s eta 0:00:01
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
print(type(encoder))
# Out:
# <class 'sklearn.preprocessing._label.LabelEncoder'>

# %%
df['Purchase_Made']=encoder.fit_transform(df['Purchase_Made'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5558 entries, 0 to 5557
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sales_Before                  5558 non-null   float64
#  1   Sales_After                   5558 non-null   float64
#  2   Customer_Satisfaction_Before  5558 non-null   float64
#  3   Customer_Satisfaction_After   5558 non-null   float64
#  4   Purchase_Made                 5558 non-null   int64
#  5   ustun_High Value              5558 non-null   int64
#  6   ustun_Low Value               5558 non-null   int64
#  7   ustun_Medium Value            5558 non-null   int64
# dtypes: float64(4), int64(4)
# memory usage: 347.5 KB

# %%
df.head()
# Out:
#    Sales_Before  Sales_After  Customer_Satisfaction_Before  \
# 0    246.862114   381.337555                    100.000000
# 1    156.978084   179.330464                     98.780735
# 2    192.126708   229.278031                     49.333766
# 3    229.685623   273.129170                     83.974852
# 4    191.713918   222.409356                     89.967827
#
#    Customer_Satisfaction_After  Purchase_Made  ustun_High Value  \
# 0                   100.000000              1                 1
# 1                   100.000000              0                 1
# 2                    39.811841              1                 0
# 3                    87.738591              1                 1
# 4                    85.120975              1                 1
#
#    ustun_Low Value  ustun_Medium Value
# 0                0                   0
# 1                0                   0
# 2                0                   1
# 3                0                   0
# ...
