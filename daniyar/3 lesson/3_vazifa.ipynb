# %%
# Imtixondan o'tishni nazorat qilish uchun  condition tuzing
# Pasport olish uchun condition tuzing

# %%
a=50 
if a>49:
    print('pass')
elif a<49:
    print('fail')
# Out:
# pass

# %%
a=18
if a>17:
    print('eligible')
else:
    print('not eligible')
# Out:
# eligible
