# %% [markdown]
# # Data bilan tanishuv

# %%
# Install qilish
    #1.  pip install pandas
    #2.  %pip install pandas
    #3.  !pip install pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv('global_cattle_disease_detection_dataset.csv')

# %%
import pandas as pd

# %%
#1 df.head
df.head(5)
# Out:
#        Cattle_ID              Breed         Region Country Climate_Zone  \
# 0  CATTLE_000001         Tharparkar         Africa      CA     Tropical
# 1  CATTLE_000002         Africander  South_America      ET         Arid
# 2  CATTLE_000003  Holstein-Friesian        Oceania      KE    Temperate
# 3  CATTLE_000004          Fleckvieh      Europe_NA      BR     Tropical
# 4  CATTLE_000005         Danish_Red        Oceania      US  Subtropical
#
#   Management_System  Age_Months  Weight_kg  Parity Lactation_Stage  ...  \
# 0         Intensive          32      259.9       4            Late  ...
# 1    Semi_Intensive          63      593.9       6           Early  ...
# 2         Intensive         132      675.4       3             Mid  ...
# 3    Semi_Intensive          73      260.5       5            Late  ...
# 4         Extensive          50      477.8       6           Early  ...
#
#    Anthrax_Vaccine IBR_Vaccine  BVD_Vaccine  Rabies_Vaccine  \
# ...

# %%
df.tail(3)
# Out:
#             Cattle_ID      Breed         Region Country   Climate_Zone  \
# 249997  CATTLE_249998  Gangatiri      Europe_NA      KE  Mediterranean
# 249998  CATTLE_249999   Ayrshire  South_America      PK    Continental
# 249999  CATTLE_250000        Gir     South_Asia      DE       Tropical
#
#        Management_System  Age_Months  Weight_kg  Parity Lactation_Stage  ...  \
# 249997    Semi_Intensive          71      401.2       1            Late  ...
# 249998         Extensive          52      495.4       2            Late  ...
# 249999             Mixed          24      592.8       6             Mid  ...
#
#         Anthrax_Vaccine IBR_Vaccine  BVD_Vaccine  Rabies_Vaccine  \
# 249997                1           1            1               1
# 249998                1           1            1               0
# 249999                1           0            1               1
#
#         Previous_Week_Avg_Yield  Body_Condition_Score  Milking_Interval_hrs  \
# ...

# %%
df.nunique()  #xar bir ustindagi klasslar soni
# Out:
# Cattle_ID                  250000
# Breed                          40
# Region                          6
# Country                        15
# Climate_Zone                    6
# Management_System               5
# Age_Months                    120
# Weight_kg                    5001
# Parity                          6
# Lactation_Stage                 3
# Days_in_Milk                  364
# Feed_Type                       8
# Feed_Quantity_kg              221
# Water_Intake_L               1001
# Walking_Distance_km          1079
# Grazing_Duration_hrs          131
# Rumination_Time_hrs           101
# Resting_Hours                 131
# Body_Temperature_C             61
# Heart_Rate_bpm                 88
# Respiratory_Rate               44
# Ambient_Temperature_C         551
# Humidity_percent              901
# Season                          5
# Housing_Score                  71
# Milk_Yield_L                 3122
# FMD_Vaccine                     2
# ...

# %%
df['Disease_Status'].nunique()
# Out:
# 45

# %%
df['Disease_Status']
# Out:
# 0              Foot_and_Mouth
# 1         Ketosis_Subclinical
# 2                     Healthy
# 3                     Healthy
# 4                     Healthy
#                  ...
# 249995                Healthy
# 249996               Foot_Rot
# 249997                Healthy
# 249998                Healthy
# 249999     Protein_Deficiency
# Name: Disease_Status, Length: 250000, dtype: object

# %%
df[['Disease_Status','Farm_ID','Date']]
# Out:
#              Disease_Status    Farm_ID        Date
# 0            Foot_and_Mouth  FARM_0825  2023-02-06
# 1       Ketosis_Subclinical  FARM_0106  2022-10-31
# 2                   Healthy  FARM_0201  2024-11-01
# 3                   Healthy  FARM_0174  2023-07-07
# 4                   Healthy  FARM_0028  2024-09-20
# ...                     ...        ...         ...
# 249995              Healthy  FARM_0170  2024-04-08
# 249996             Foot_Rot  FARM_0122  2024-08-06
# 249997              Healthy  FARM_0147  2023-02-08
# 249998              Healthy  FARM_0807  2022-12-13
# 249999   Protein_Deficiency  FARM_0957  2023-12-28
#
# [250000 rows x 3 columns]

# %%
df.head()
# Out:
#        Cattle_ID              Breed         Region Country Climate_Zone  \
# 0  CATTLE_000001         Tharparkar         Africa      CA     Tropical
# 1  CATTLE_000002         Africander  South_America      ET         Arid
# 2  CATTLE_000003  Holstein-Friesian        Oceania      KE    Temperate
# 3  CATTLE_000004          Fleckvieh      Europe_NA      BR     Tropical
# 4  CATTLE_000005         Danish_Red        Oceania      US  Subtropical
#
#   Management_System  Age_Months  Weight_kg  Parity Lactation_Stage  ...  \
# 0         Intensive          32      259.9       4            Late  ...
# 1    Semi_Intensive          63      593.9       6           Early  ...
# 2         Intensive         132      675.4       3             Mid  ...
# 3    Semi_Intensive          73      260.5       5            Late  ...
# 4         Extensive          50      477.8       6           Early  ...
#
#    Anthrax_Vaccine IBR_Vaccine  BVD_Vaccine  Rabies_Vaccine  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Cattle_ID                250000 non-null  object
#  1   Breed                    250000 non-null  object
#  2   Region                   250000 non-null  object
#  3   Country                  250000 non-null  object
#  4   Climate_Zone             250000 non-null  object
#  5   Management_System        250000 non-null  object
#  6   Age_Months               250000 non-null  int64
#  7   Weight_kg                250000 non-null  float64
#  8   Parity                   250000 non-null  int64
#  9   Lactation_Stage          250000 non-null  object
#  10  Days_in_Milk             250000 non-null  int64
#  11  Feed_Type                250000 non-null  object
#  12  Feed_Quantity_kg         250000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Cattle_ID                  0
# Breed                      0
# Region                     0
# Country                    0
# Climate_Zone               0
# Management_System          0
# Age_Months                 0
# Weight_kg                  0
# Parity                     0
# Lactation_Stage            0
# Days_in_Milk               0
# Feed_Type                  0
# Feed_Quantity_kg           0
# Water_Intake_L             0
# Walking_Distance_km        0
# Grazing_Duration_hrs       0
# Rumination_Time_hrs        0
# Resting_Hours              0
# Body_Temperature_C         0
# Heart_Rate_bpm             0
# Respiratory_Rate           0
# Ambient_Temperature_C      0
# Humidity_percent           0
# Season                     0
# Housing_Score              0
# Milk_Yield_L               0
# FMD_Vaccine                0
# Brucellosis_Vaccine        0
# HS_Vaccine                 0
# BQ_Vaccine                 0
# Anthrax_Vaccine            0
# IBR_Vaccine                0
# ...

# %%
df.isnull().any()
# Out:
# Cattle_ID                  False
# Breed                      False
# Region                     False
# Country                    False
# Climate_Zone               False
# Management_System          False
# Age_Months                 False
# Weight_kg                  False
# Parity                     False
# Lactation_Stage            False
# Days_in_Milk               False
# Feed_Type                  False
# Feed_Quantity_kg           False
# Water_Intake_L             False
# Walking_Distance_km        False
# Grazing_Duration_hrs       False
# Rumination_Time_hrs        False
# Resting_Hours              False
# Body_Temperature_C         False
# Heart_Rate_bpm             False
# Respiratory_Rate           False
# Ambient_Temperature_C      False
# Humidity_percent           False
# Season                     False
# Housing_Score              False
# Milk_Yield_L               False
# FMD_Vaccine                False
# Brucellosis_Vaccine        False
# ...

# %% [markdown]
# # Conditions

# %%
#agar son musbat bolsa yaqshi aks holda yomon degan sozni ekranga chiqaring

# %%
a=4
if a>0:
    print('Yaqshi')
elif a<0:
    print ('Yomon')    
else: 
    print ('nol')
# Out:
# Yaqshi

# %%
baxo=4
if baxo==5:
    print('alo')
elif baxo==4:
    print('yaqshi')
elif baxo==3:
    print('ortacha')
elif baxo==2:
    print('yomon')
else:
    print ('xatolik bor yoki juda yomon')
# Out:
# yaqshi
