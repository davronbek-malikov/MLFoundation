# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
df=pd.read_csv('Smartphone_Usage_Productivity_Dataset_50000.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    49997 non-null  str
#  1   Age                        49993 non-null  float64
#  2   Gender                     49991 non-null  str
#  3   Occupation                 49998 non-null  str
#  4   Device_Type                49998 non-null  str
#  5   Daily_Phone_Hours          49990 non-null  float64
#  6   Social_Media_Hours         49993 non-null  float64
#  7   Work_Productivity_Score    49990 non-null  float64
#  8   Sleep_Hours                49988 non-null  float64
#  9   Stress_Level               49996 non-null  float64
#  10  App_Usage_Count            49997 non-null  float64
#  11  Caffeine_Intake_Cups       49999 non-null  float64
#  12  Weekend_Screen_Time_Hours  49996 non-null  float64
# dtypes: float64(9), str(4)
# memory usage: 5.0 MB

# %% [markdown]
# # Data bilan tanishuv

# %%
df.head()
# Out:
#   User_ID   Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1  58.0    Male    Professional     Android                1.3
# 1      U2  25.0    Male    Professional     Android                1.2
# 2      U3  19.0    Male         Student         iOS                5.3
# 3      U4  35.0  Female  Business Owner         iOS                5.8
# 4      U5  33.0    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                      6.0          8.8           4.0
# 1                 1.5                      5.0          6.4           1.0
# 2                 5.7                      5.0          9.0           4.0
# 3                 2.5                      2.0          NaN           3.0
# 4                 1.3                      4.0          NaN           3.0
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# 0             42.0                   1.0                        NaN
# 1             51.0                   3.0                        NaN
# 2             14.0                   5.0                        NaN
# 3             36.0                   6.0                       12.8
# 4             37.0                   5.0                        9.9

# %%
df.tail()
# Out:
#       User_ID   Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 49995  U49996  44.0    Male  Business Owner     Android                5.9
# 49996  U49997  42.0   Other  Business Owner     Android                2.9
# 49997  U49998  27.0  Female      Freelancer         iOS                1.4
# 49998  U49999  41.0  Female  Business Owner         iOS                8.9
# 49999  U50000  46.0   Other      Freelancer     Android                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 49995                 5.4                      5.0          6.6           1.0
# 49996                 7.4                      9.0          6.3           2.0
# 49997                 2.5                      4.0          6.7           9.0
# 49998                 3.0                      6.0          5.5           2.0
# 49999                 2.8                      3.0          5.4           1.0
#
#        App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# 49995             11.0                   5.0                        3.0
# 49996             20.0                   4.0                        6.2
# 49997             39.0                   4.0                        5.1
# 49998             51.0                   0.0                        9.2
# 49999             54.0                   5.0                        6.9

# %%
df.drop(columns=('User_ID'),inplace=True)

# %%
df.head()
# Out:
#     Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0  58.0    Male    Professional     Android                1.3
# 1  25.0    Male    Professional     Android                1.2
# 2  19.0    Male         Student         iOS                5.3
# 3  35.0  Female  Business Owner         iOS                5.8
# 4  33.0    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                      6.0          8.8           4.0
# 1                 1.5                      5.0          6.4           1.0
# 2                 5.7                      5.0          9.0           4.0
# 3                 2.5                      2.0          NaN           3.0
# 4                 1.3                      4.0          NaN           3.0
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# 0             42.0                   1.0                        NaN
# 1             51.0                   3.0                        NaN
# 2             14.0                   5.0                        NaN
# 3             36.0                   6.0                       12.8
# 4             37.0                   5.0                        9.9

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        49993 non-null  float64
#  1   Gender                     49991 non-null  str
#  2   Occupation                 49998 non-null  str
#  3   Device_Type                49998 non-null  str
#  4   Daily_Phone_Hours          49990 non-null  float64
#  5   Social_Media_Hours         49993 non-null  float64
#  6   Work_Productivity_Score    49990 non-null  float64
#  7   Sleep_Hours                49988 non-null  float64
#  8   Stress_Level               49996 non-null  float64
#  9   App_Usage_Count            49997 non-null  float64
#  10  Caffeine_Intake_Cups       49999 non-null  float64
#  11  Weekend_Screen_Time_Hours  49996 non-null  float64
# dtypes: float64(9), str(3)
# memory usage: 4.6 MB

# %% [markdown]
# # Data Preprocessing

# %%
# Missing

# %%
df.isnull().sum()
# Out:
# Age                           7
# Gender                        9
# Occupation                    2
# Device_Type                   2
# Daily_Phone_Hours            10
# Social_Media_Hours            7
# Work_Productivity_Score      10
# Sleep_Hours                  12
# Stress_Level                  4
# App_Usage_Count               3
# Caffeine_Intake_Cups          1
# Weekend_Screen_Time_Hours     4
# dtype: int64

# %%
# For loop + Missing
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype=='string':
            df[col] = df[col].fillna(df[col].mode()[0])
        else:
            df[col] = df[col].fillna(df[col].mean())

# %%
df.isnull().any()
# Out:
# Age                          False
# Gender                       False
# Occupation                   False
# Device_Type                  False
# Daily_Phone_Hours            False
# Social_Media_Hours           False
# Work_Productivity_Score      False
# Sleep_Hours                  False
# Stress_Level                 False
# App_Usage_Count              False
# Caffeine_Intake_Cups         False
# Weekend_Screen_Time_Hours    False
# dtype: bool

# %%
# encoding

# %%
print(df.dtypes)
# Out:
# Age                          float64
# Gender                           str
# Occupation                       str
# Device_Type                      str
# Daily_Phone_Hours            float64
# Social_Media_Hours           float64
# Work_Productivity_Score      float64
# Sleep_Hours                  float64
# Stress_Level                 float64
# App_Usage_Count              float64
# Caffeine_Intake_Cups         float64
# Weekend_Screen_Time_Hours    float64
# dtype: object

# %%
df.nunique()
# Out:
# Age                           44
# Gender                         3
# Occupation                     4
# Device_Type                    2
# Daily_Phone_Hours            112
# Social_Media_Hours            77
# Work_Productivity_Score       11
# Sleep_Hours                   52
# Stress_Level                  11
# App_Usage_Count               57
# Caffeine_Intake_Cups           8
# Weekend_Screen_Time_Hours    122
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
# for loop + encoding
for col in df.columns:
    if df[col].dtype=='string':
        if df[col].nunique()<=2:
            dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
            df=pd.concat([df.drop(columns=[col]),dummies],axis=1)
        else:
            df[col]=encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        50000 non-null  float64
#  1   Gender                     50000 non-null  int64
#  2   Occupation                 50000 non-null  int64
#  3   Daily_Phone_Hours          50000 non-null  float64
#  4   Social_Media_Hours         50000 non-null  float64
#  5   Work_Productivity_Score    50000 non-null  float64
#  6   Sleep_Hours                50000 non-null  float64
#  7   Stress_Level               50000 non-null  float64
#  8   App_Usage_Count            50000 non-null  float64
#  9   Caffeine_Intake_Cups       50000 non-null  float64
#  10  Weekend_Screen_Time_Hours  50000 non-null  float64
#  11  Device_Type_Android        50000 non-null  int64
#  12  Device_Type_iOS            50000 non-null  int64
# dtypes: float64(9), int64(4)
# memory usage: 5.0 MB

# %%
# Scaling

# %%
df.head()
# Out:
#     Age  Gender  Occupation  Daily_Phone_Hours  Social_Media_Hours  \
# 0  58.0       1           2                1.3                 6.7
# 1  25.0       1           2                1.2                 1.5
# 2  19.0       1           3                5.3                 5.7
# 3  35.0       0           0                5.8                 2.5
# 4  33.0       1           1                7.9                 1.3
#
#    Work_Productivity_Score  Sleep_Hours  Stress_Level  App_Usage_Count  \
# 0                      6.0     8.800000           4.0             42.0
# 1                      5.0     6.400000           1.0             51.0
# 2                      5.0     9.000000           4.0             14.0
# 3                      2.0     6.497873           3.0             36.0
# 4                      4.0     6.497873           3.0             37.0
#
#    Caffeine_Intake_Cups  Weekend_Screen_Time_Hours  Device_Type_Android  \
# 0                   1.0                   8.006989                    1
# 1                   3.0                   8.006989                    1
# 2                   5.0                   8.006989                    0
# 3                   6.0                  12.800000                    0
# 4                   5.0                   9.900000                    1
#
#    Device_Type_iOS
# 0                0
# 1                0
# 2                1
# 3                1
# 4                0

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
scaler=MinMaxScaler()

# %%
scaler
# Out:
# MinMaxScaler()

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns.drop('Stress_Level')

# %%
num_col
# Out:
# Index(['Age', 'Gender', 'Occupation', 'Daily_Phone_Hours',
#        'Social_Media_Hours', 'Work_Productivity_Score', 'Sleep_Hours',
#        'App_Usage_Count', 'Caffeine_Intake_Cups', 'Weekend_Screen_Time_Hours',
#        'Device_Type_Android', 'Device_Type_iOS'],
#       dtype='str')

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#         Age  Gender  Occupation  Daily_Phone_Hours  Social_Media_Hours  \
# 0  0.952381     0.5    0.666667           0.027273            0.826667
# 1  0.166667     0.5    0.666667           0.018182            0.133333
# 2  0.023810     0.5    1.000000           0.390909            0.693333
# 3  0.404762     0.0    0.000000           0.436364            0.266667
# 4  0.357143     0.5    0.333333           0.627273            0.106667
#
#    Work_Productivity_Score  Sleep_Hours  Stress_Level  App_Usage_Count  \
# 0                 0.555556     0.960000           4.0         0.672727
# 1                 0.444444     0.480000           1.0         0.836364
# 2                 0.444444     1.000000           4.0         0.163636
# 3                 0.111111     0.499575           3.0         0.563636
# 4                 0.333333     0.499575           3.0         0.581818
#
#    Caffeine_Intake_Cups  Weekend_Screen_Time_Hours  Device_Type_Android  \
# 0              0.166667                   0.500582                  1.0
# 1              0.500000                   0.500582                  1.0
# 2              0.833333                   0.500582                  0.0
# 3              1.000000                   0.900000                  0.0
# 4              0.833333                   0.658333                  1.0
#
#    Device_Type_iOS
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              0.0

# %% [markdown]
# # Model selection

# %%
# Linear Regression import qilish
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# # Training

# %%
x=df.drop('Stress_Level',axis=1)

# %%
y=df['Stress_Level']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Prediction

# %%
y_pred=lr.predict(x_test)

# %%
y_pred[0]
# Out:
# np.float64(5.4370873129775035)

# %%
y_pred_int = y_pred.round().astype(int)

# %%
y_pred_int
# Out:
# array([5, 5, 6, ..., 6, 5, 6], shape=(10000,))

# %%
x_train.shape
# Out:
# (40000, 12)

# %%
y_train.shape
# Out:
# (40000,)

# %%
x_test.shape
# Out:
# (10000, 12)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
print('mae: ',mae)
print('mse: ',mse)
print('r2: ',r2)
# Out:
# mae:  2.501744379727208
# mse:  8.242203614244316
# r2:  -0.00041255672307305424
