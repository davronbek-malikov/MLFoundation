# %% [markdown]
# # Data Types uchun misol

# %%
age = 24
print(age)
# Out:
# 24

# %%
height = 1.82
print(height)
# Out:
# 1.82

# %%
name = "Askarali"
print(name)
# Out:
# Askarali

# %%
x = 4
print(x < 4)
# Out:
# False

# %% [markdown]
# # Operations

# %%
a = 10
b = 7
print(a + b)
print(a - b)
print(a * b)
print(a ** b)
print(a / b)
print(a // b)
print(a % b)
# Out:
# 17
# 3
# 70
# 10000000
# 1.4285714285714286
# 1
# 3

# %%
# Taqqoslash
x = 5
y = 10
print(x > y)
print(x < y)
print(x == y)
# Out:
# False
# True
# False

# %% [markdown]
# # Conditions

# %%
a = 8
if a > 0:
    print('Musbat son')
# Out:
# Musbat son

# %%
a = 5
if a % 2 == 0:
    print("Juft son")
else:
    print("Toq son")
# Out:
# Toq son

# %%
age = 20
if age >= 18:
    print("Kirish mumkin")
else:
    print("Kirish mumkin emas")
# Out:
# Kirish mumkin
