# %% [markdown]
# # 1.So'zning boshi va oxirini belgilash

# %%
s='Uzbekistan'
s[0]   #so'zning birinchi harfni chiqarish uchun
# Out:
# 'U'

# %%
s[-1]
# Out:
# 'n'

# %% [markdown]
# # 2. Ikki sonning musbat va juft ekanligini topish

# %%
a = 4
b = 5

if a > 0 and a % 2 == 0:
    print("Birinchi son musbat va juft")
else:
    prinr("Birinchi son musbat juft emas")

if b > 0 and b % 2 == 0:
    print("Ikkinchi son musbat va juft")
else:
    print("Ikkinchi son musbat juft emas")
# Out:
# Birinchi son musbat va juft
# Ikkinchi son musbat juft emas

# %% [markdown]
# # 3.Berilgan so'zni oxiridan 2-harfni topadigan kod

# %%
s = 'Uzbekistan'
s[-2]
# Out:
# 'a'

# %% [markdown]
# # 4. Istalgan sonni to'q yoki manfiy ekanligini aniqlash

# %%
a = 1

if a < 0 or a % 2 == 1:
    print("Bu son to'q va manfiy")
else:
    print("Bu son to`q ham va juft ham emas")
# Out:
# Bu son to'q va manfiy

# %% [markdown]
# # Python misollar

# %%
#int
a=5
b=4
print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a*b)
print(a**b)
print(a%b)
# Out:
# 9
# 1
# 1.25
# 1
# 20
# 625
# 1

# %%
#float
a=5.4
b=4.6
print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a*b)
print(a**b)
print(a%b)
# Out:
# 10.0
# 0.8000000000000007
# 1.173913043478261
# 1.0
# 24.84
# 2338.898068224241
# 0.8000000000000007

# %%
#string
a = 'Assalomu'
b = 'Aleykum'
print(a+b)
# Out:
# AssalomuAleykum

# %%
#Boolean
a = 16
b = 10
print(a==b)
# Out:
# False
