# %%
# Imtixondan o'tishni nazorat qilish uchun  condition tuzing
# Pasport olish uchun condition tuzing

# %% [markdown]
# # 1.Imtixondan o'tishni nazorat qilish uchun condition.

# %%
ball = 70  
if ball > 80 or ball == 80:
    print('Muvafaqqiyatli')
elif ball < 70:
    print('Muvafaqqiyatsiz')
else:
    print('Qayta imtixon')
# Out:
# Qayta imtixon

# %% [markdown]
# # 2.Pasport olish uchun condition

# %%
yosh = 18
if yosh > 18 or yosh == 18:
    print('Passport')
else:
    print('Metirka')
# Out:
# Passport

# %% [markdown]
# # PPT vazifa

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.7 MB 9.4 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/9.7 MB 8.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.7 MB 9.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 9.6 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.3 MB 11.5 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.3 MB 10.3 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.3 MB 9.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.3 MB 9.7 MB/s eta 0:00:01
# ...

# %%
df=pd.read_csv('netflix_titles.csv')
