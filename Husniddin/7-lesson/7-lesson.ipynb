# %%
import pandas as pd

# %%
hr = pd.read_csv("data.csv")

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
hr.isnull().sum()
# Out:
# Unnamed: 0          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
hr['song_title']=encoder.fit_transform(hr['song_title'])

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   int64
# ...

# %%
hr.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target  song_title            artist
# 0             4.0    0.286       1        1043            Future
# ...

# %%
hr.nunique()
# Out:
# Unnamed: 0          2017
# acousticness        1394
# danceability         632
# duration_ms         1921
# energy               719
# instrumentalness    1107
# key                   12
# liveness             793
# loudness            1808
# mode                   2
# speechiness          792
# tempo               1919
# time_signature         4
# valence              853
# target                 2
# song_title          1956
# artist              1343
# dtype: int64

# %%
hr['artist']=encoder.fit_transform(hr['artist'])

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   int64
# ...

# %%
df = pd.read_csv('fullGas.csv')

# %%
df.isnull().sum()
# Out:
# Make                        0
# Model                     221
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                     1695
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Fuel_Consumption_l      27721
# Drivetrain               8634
# Gearbox                   480
# Gears                   15379
# Power_hp                    0
# Engine_Size_cc           5930
# Cylinders               10162
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
df.drop('Fuel_Consumption_l', axis=1, inplace=True)

# %%
df['Engine_Size_cc'].fillna(df['Engine_Size_cc'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_2204\2448250505.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine_Size_cc'].fillna(df['Engine_Size_cc'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  40494 non-null  object
#  1   Model                 40273 non-null  object
#  2   Body                  40493 non-null  object
#  3   Mileage_km            40494 non-null  int64
#  4   Price                 40494 non-null  int64
#  5   Year                  38799 non-null  float64
#  6   Country               37902 non-null  object
#  7   Condition             40494 non-null  object
#  8   Fuel_Type             40465 non-null  object
#  9   Drivetrain            31860 non-null  object
#  10  Gearbox               40014 non-null  object
#  11  Gears                 25115 non-null  float64
#  12  Power_hp              40494 non-null  int64
#  13  Engine_Size_cc        34564 non-null  float64
#  14  Cylinders             30332 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Make                        0
# Model                     221
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                     1695
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Gears                   15379
# Power_hp                    0
# Engine_Size_cc              0
# Cylinders               10162
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
df['Year'].fillna(df['Year'].mean(), inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_2204\3405564687.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Year'].fillna(df['Year'].mean(), inplace=True)

# %%
df['Model'].fillna(df['Model'].mode()[0], inplace=True)

# %%
df['Year'].fillna(df['Year'].mean(), inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_20804\1784172141.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Year'].fillna(df['Year'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Gears                   15379
# Power_hp                    0
# Engine_Size_cc           5930
# Cylinders               10162
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
df['Body'].fillna(df['Body'].mode()[0], inplace=True)

# %%
df['Country'].fillna(df['Country'].mode()[0], inplace=True)

# %%
df.nunique()
# Out:
# Make                       46
# Model                    1256
# Body                        9
# Mileage_km              20521
# Price                    7709
# Year                       88
# Country                     8
# Condition                   2
# Fuel_Type                  10
# Drivetrain                  3
# Gearbox                     3
# Gears                      17
# Power_hp                  572
# Engine_Size_cc            767
# Cylinders                  13
# Seats                      11
# Doors                       7
# Color                      14
# Upholstery                  6
# Full_Service_History        2
# Non_Smoker_Vehicle          2
# Previous_Owners            13
# Seller                      2
# Image_url               40452
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        0
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                     0
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Gears                   15379
# Power_hp                    0
# Engine_Size_cc           5930
# Cylinders               10162
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        df[col].fillna(df[col].median(), inplace=True)
    else:
        df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_20804\2481817300.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_20804\2481817300.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Body                    0
# Mileage_km              0
# Price                   0
# Year                    0
# Country                 0
# Condition               0
# Fuel_Type               0
# Drivetrain              0
# Gearbox                 0
# Gears                   0
# Power_hp                0
# Engine_Size_cc          0
# Cylinders               0
# Seats                   0
# Doors                   0
# Color                   0
# Upholstery              0
# Full_Service_History    0
# Non_Smoker_Vehicle      0
# Previous_Owners         0
# Seller                  0
# Image_url               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  40494 non-null  object
#  1   Model                 40494 non-null  object
#  2   Body                  40494 non-null  object
#  3   Mileage_km            40494 non-null  int64
#  4   Price                 40494 non-null  int64
#  5   Year                  40494 non-null  float64
#  6   Country               40494 non-null  object
#  7   Condition             40494 non-null  object
#  8   Fuel_Type             40494 non-null  object
#  9   Drivetrain            40494 non-null  object
#  10  Gearbox               40494 non-null  object
#  11  Gears                 40494 non-null  float64
#  12  Power_hp              40494 non-null  int64
#  13  Engine_Size_cc        40494 non-null  float64
#  14  Cylinders             40494 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %% [markdown]
# Preprocessing

# %%
for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype=='object':
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
            df[col].fillna(df[col].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  40494 non-null  object
#  1   Model                 40494 non-null  object
#  2   Body                  40494 non-null  object
#  3   Mileage_km            40494 non-null  int64
#  4   Price                 40494 non-null  int64
#  5   Year                  40494 non-null  float64
#  6   Country               40494 non-null  object
#  7   Condition             40494 non-null  object
#  8   Fuel_Type             40494 non-null  object
#  9   Drivetrain            40494 non-null  object
#  10  Gearbox               40494 non-null  object
#  11  Gears                 40494 non-null  float64
#  12  Power_hp              40494 non-null  int64
#  13  Engine_Size_cc        40494 non-null  float64
#  14  Cylinders             40494 non-null  float64
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        if df[col].nunique()<=5:
            dummies=pd.get_dummies(df[col], prefix=col, dtype=int)
            df=pd.concat([df.drop(columns=col), dummies], axis=1)
        else:
            df[col]=encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Make                          40494 non-null  int64
#  1   Model                         40494 non-null  int64
#  2   Body                          40494 non-null  int64
#  3   Mileage_km                    40494 non-null  int64
#  4   Price                         40494 non-null  int64
#  5   Year                          40494 non-null  float64
#  6   Country                       40494 non-null  int64
#  7   Fuel_Type                     40494 non-null  int64
#  8   Gears                         40494 non-null  float64
#  9   Power_hp                      40494 non-null  int64
#  10  Engine_Size_cc                40494 non-null  float64
#  11  Cylinders                     40494 non-null  float64
# ...
