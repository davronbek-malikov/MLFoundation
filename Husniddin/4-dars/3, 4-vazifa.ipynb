# %%
# Imtixondan o'tishni nazorat qilish uchun  condition tuzing

# put exam result
er = int(input("Imtihon natijasini kiriting: "))

if er > 84:
    print("Yaxshi. 5 baho oldingiz.")
elif er > 69 and er < 85:
    print("Bo'ladi, yomon emas. 4 baho.")
elif er < 70 and er > 54:
    print("Yaxshi emas. 3 baho.")
else:
    print("Yomon. 2 baho.")
# Out:
# Yaxshi. 5 baho oldingiz.

# %%
# Pasport olish uchun condition tuzing

age = int(input("Yoshingizni kiriting: "))
metrka = input("Tug'ilganlik guvohnomasi bormi? (ha/yo'q): ")
ariza = input("Ariza topshirdingizmi? (ha/yo'q): ")

if age >= 16 and metrka == "ha" and ariza == "ha":
    print("Passport olishga ruxsat berildi. Salomat bo'ling.")
else:
    print("Passport olish shartlari to'liq emas. To'ldirishingizni xohlab qolamiz.")
# Out:
# Passport olish shartlari to'liq emas. To'ldirishingizni xohlab qolamiz.

# %%
import pandas as pd

# %%
hr = pd.read_csv('fullGas.csv')

# %%
hr.head()
# Out:
#      Make Model     Body  Mileage_km  Price    Year Country Condition  \
# 0  Abarth   595  Compact       98000  16900  2020.0      IT      Used
# 1  Abarth   595    Sedan       91500  12500  2017.0      IT      Used
# 2  Abarth   595  Compact       40000  17990  2015.0      IT      Used
# 3  Abarth   500  Compact      133000   9300  2008.0      IT      Used
# 4  Abarth   595  Compact       61019  14990  2021.0      BE      Used
#
#   Fuel_Type  Fuel_Consumption_l  ... Cylinders Seats  Doors   Color  \
# 0  Gasoline                 6.7  ...       4.0   4.0    3.0   White
# 1  Gasoline                 6.0  ...       4.0   4.0    3.0    Grey
# 2  Gasoline                 6.5  ...       4.0   4.0    3.0  Bronze
# 3  Gasoline                 6.5  ...       4.0   4.0    3.0   Black
# 4  Gasoline                 NaN  ...       4.0   4.0    3.0  Yellow
#
#      Upholstery  Full_Service_History  Non_Smoker_Vehicle  Previous_Owners  \
# ...

# %%
hr.tail()
# Out:
#         Make              Model              Body  Mileage_km  Price    Year  \
# 40489  Volvo  V60 Cross Country     Station wagon       73627  32990  2023.0
# 40490  Volvo               XC60  Off-Road/Pick-up       93671  26990  2020.0
# 40491  Volvo                V90     Station wagon       60200  32490  2020.0
# 40492  Volvo               XC40  Off-Road/Pick-up       49088  29450  2022.0
# 40493  Volvo               XC90  Off-Road/Pick-up      124750  43990  2022.0
#
#       Country Condition          Fuel_Type  Fuel_Consumption_l  ... Cylinders  \
# 40489      DE      Used             Diesel                 NaN  ...       NaN
# 40490      IT      Used    Electric/Diesel                 NaN  ...       4.0
# 40491      DE      Used           Gasoline                 NaN  ...       4.0
# 40492      NL      Used  Electric/Gasoline                 NaN  ...       3.0
# 40493      DE      Used             Diesel                 NaN  ...       4.0
#
# ...

# %%
hr.nunique()
# Out:
# Make                       46
# Model                    1256
# Body                        9
# Mileage_km              20521
# Price                    7709
# Year                       87
# Country                     8
# Condition                   2
# Fuel_Type                  10
# Fuel_Consumption_l        217
# Drivetrain                  3
# Gearbox                     3
# Gears                      17
# Power_hp                  572
# Engine_Size_cc            767
# Cylinders                  13
# Seats                      11
# Doors                       7
# Color                      14
# Upholstery                  6
# Full_Service_History        2
# Non_Smoker_Vehicle          2
# Previous_Owners            13
# Seller                      2
# Image_url               40452
# dtype: int64

# %%
hr['Doors'].nunique()
# Out:
# 7

# %%
hr['Doors']
# Out:
# 0        3.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
#         ...
# 40489    5.0
# 40490    5.0
# 40491    5.0
# 40492    5.0
# 40493    5.0
# Name: Doors, Length: 40494, dtype: float64

# %%
hr.head()
# Out:
#      Make Model     Body  Mileage_km  Price    Year Country Condition  \
# 0  Abarth   595  Compact       98000  16900  2020.0      IT      Used
# 1  Abarth   595    Sedan       91500  12500  2017.0      IT      Used
# 2  Abarth   595  Compact       40000  17990  2015.0      IT      Used
# 3  Abarth   500  Compact      133000   9300  2008.0      IT      Used
# 4  Abarth   595  Compact       61019  14990  2021.0      BE      Used
#
#   Fuel_Type  Fuel_Consumption_l  ... Cylinders Seats  Doors   Color  \
# 0  Gasoline                 6.7  ...       4.0   4.0    3.0   White
# 1  Gasoline                 6.0  ...       4.0   4.0    3.0    Grey
# 2  Gasoline                 6.5  ...       4.0   4.0    3.0  Bronze
# 3  Gasoline                 6.5  ...       4.0   4.0    3.0   Black
# 4  Gasoline                 NaN  ...       4.0   4.0    3.0  Yellow
#
#      Upholstery  Full_Service_History  Non_Smoker_Vehicle  Previous_Owners  \
# ...

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40494 entries, 0 to 40493
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  40494 non-null  object
#  1   Model                 40273 non-null  object
#  2   Body                  40493 non-null  object
#  3   Mileage_km            40494 non-null  int64
#  4   Price                 40494 non-null  int64
#  5   Year                  38799 non-null  float64
#  6   Country               37902 non-null  object
#  7   Condition             40494 non-null  object
#  8   Fuel_Type             40465 non-null  object
#  9   Fuel_Consumption_l    12773 non-null  float64
#  10  Drivetrain            31860 non-null  object
#  11  Gearbox               40014 non-null  object
#  12  Gears                 25115 non-null  float64
#  13  Power_hp              40494 non-null  int64
#  14  Engine_Size_cc        34564 non-null  float64
# ...

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                     221
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                     1695
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Fuel_Consumption_l      27721
# Drivetrain               8634
# Gearbox                   480
# Gears                   15379
# Power_hp                    0
# Engine_Size_cc           5930
# Cylinders               10162
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr.isnull().any()
# Out:
# Make                    False
# Model                    True
# Body                     True
# Mileage_km              False
# Price                   False
# Year                     True
# Country                  True
# Condition               False
# Fuel_Type                True
# Drivetrain               True
# Gearbox                  True
# Gears                    True
# Power_hp                False
# Engine_Size_cc           True
# Cylinders                True
# Seats                    True
# Doors                    True
# Color                    True
# Upholstery               True
# Full_Service_History    False
# Non_Smoker_Vehicle      False
# Previous_Owners          True
# Seller                   True
# Image_url               False
# dtype: bool

# %%
hr.drop('Gears', axis=1, inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                     221
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                     1695
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr['Year'].fillna(hr['Year'].mean(), inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\3972480104.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Year'].fillna(hr['Year'].mean(), inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                     221
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr['Model'].fillna(hr['Model'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\3511080676.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Model'].fillna(hr['Model'].mode()[0], inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                  2592
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr.head()
# Out:
#      Make Model     Body  Mileage_km  Price    Year Country Condition  \
# 0  Abarth   595  Compact       98000  16900  2020.0      IT      Used
# 1  Abarth   595    Sedan       91500  12500  2017.0      IT      Used
# 2  Abarth   595  Compact       40000  17990  2015.0      IT      Used
# 3  Abarth   500  Compact      133000   9300  2008.0      IT      Used
# 4  Abarth   595  Compact       61019  14990  2021.0      BE      Used
#
#   Fuel_Type         Drivetrain  ... Engine_Size_cc  Seats  Doors   Color  \
# 0  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0   White
# 1  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0    Grey
# 2  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0  Bronze
# 3  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0   Black
# 4  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0  Yellow
#
#      Upholstery Full_Service_History Non_Smoker_Vehicle  Previous_Owners  \
# ...

# %%
hr['Country'].fillna(hr['Country'].mode()[0], inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        1
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                     0
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr['Body'].fillna('Compact', inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        0
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                     0
# Condition                   0
# Fuel_Type                  29
# Drivetrain               8634
# Gearbox                   480
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr.head()
# Out:
#      Make Model     Body  Mileage_km  Price    Year Country Condition  \
# 0  Abarth   595  Compact       98000  16900  2020.0      IT      Used
# 1  Abarth   595    Sedan       91500  12500  2017.0      IT      Used
# 2  Abarth   595  Compact       40000  17990  2015.0      IT      Used
# 3  Abarth   500  Compact      133000   9300  2008.0      IT      Used
# 4  Abarth   595  Compact       61019  14990  2021.0      BE      Used
#
#   Fuel_Type         Drivetrain  ... Engine_Size_cc  Seats  Doors   Color  \
# 0  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0   White
# 1  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0    Grey
# 2  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0  Bronze
# 3  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0   Black
# 4  Gasoline  Front Wheel Drive  ...         1368.0    4.0    3.0  Yellow
#
#      Upholstery Full_Service_History Non_Smoker_Vehicle  Previous_Owners  \
# ...

# %%
hr['Fuel_Type'].fillna(hr['Fuel_Type'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\3930471538.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Fuel_Type'].fillna(hr['Fuel_Type'].mode()[0], inplace=True)

# %%
hr['Drivetrain'].fillna(hr['Drivetrain'].mode()[0], inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        0
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                     0
# Condition                   0
# Fuel_Type                   0
# Drivetrain                  0
# Gearbox                   480
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr['Gearbox']
# Out:
# 0        Automatic
# 1           Manual
# 2           Manual
# 3           Manual
# 4           Manual
#            ...
# 40489    Automatic
# 40490    Automatic
# 40491    Automatic
# 40492    Automatic
# 40493    Automatic
# Name: Gearbox, Length: 40494, dtype: object

# %%
hr['Gearbox'].fillna('Automatic', inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        0
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                     0
# Condition                   0
# Fuel_Type                   0
# Drivetrain                  0
# Gearbox                     0
# Power_hp                    0
# Engine_Size_cc           5930
# Seats                    1797
# Doors                     977
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr['Engine_Size_cc']
# Out:
# 0        1368.0
# 1        1368.0
# 2        1368.0
# 3        1368.0
# 4        1368.0
#           ...
# 40489    1969.0
# 40490    1969.0
# 40491    1969.0
# 40492    1477.0
# 40493    1969.0
# Name: Engine_Size_cc, Length: 40494, dtype: float64

# %%
hr['Engine_Size_cc'].fillna(hr['Engine_Size_cc'].mean(), inplace=True)

# %%
hr['Seats'].fillna(hr['Seats'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\151976739.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Seats'].fillna(hr['Seats'].mode()[0], inplace=True)

# %%
hr['Doors'].fillna(hr['Doors'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\4134526565.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Doors'].fillna(hr['Doors'].mode()[0], inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                        0
# Model                       0
# Body                        0
# Mileage_km                  0
# Price                       0
# Year                        0
# Country                     0
# Condition                   0
# Fuel_Type                   0
# Drivetrain                  0
# Gearbox                     0
# Power_hp                    0
# Engine_Size_cc              0
# Seats                       0
# Doors                       0
# Color                    2575
# Upholstery               7272
# Full_Service_History        0
# Non_Smoker_Vehicle          0
# Previous_Owners         18223
# Seller                    150
# Image_url                   0
# dtype: int64

# %%
hr['Color'].fillna(hr['Color'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\264780648.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Color'].fillna(hr['Color'].mode()[0], inplace=True)

# %%
hr['Upholstery'].fillna(hr['Doors'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\1392788580.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Upholstery'].fillna(hr['Doors'].mode()[0], inplace=True)

# %%
hr.drop('Previous_Owners', axis=1, inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                      0
# Model                     0
# Body                      0
# Mileage_km                0
# Price                     0
# Year                      0
# Country                   0
# Condition                 0
# Fuel_Type                 0
# Drivetrain                0
# Gearbox                   0
# Power_hp                  0
# Engine_Size_cc            0
# Seats                     0
# Doors                     0
# Color                     0
# Upholstery                0
# Full_Service_History      0
# Non_Smoker_Vehicle        0
# Seller                  150
# Image_url                 0
# dtype: int64

# %%
hr['Seller'].fillna(hr['Seller'].mode()[0], inplace=True)
# Out:
# C:\Users\윈도우10\AppData\Local\Temp\ipykernel_21688\2181208715.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hr['Seller'].fillna(hr['Seller'].mode()[0], inplace=True)

# %%
hr.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Body                    0
# Mileage_km              0
# Price                   0
# Year                    0
# Country                 0
# Condition               0
# Fuel_Type               0
# Drivetrain              0
# Gearbox                 0
# Power_hp                0
# Engine_Size_cc          0
# Seats                   0
# Doors                   0
# Color                   0
# Upholstery              0
# Full_Service_History    0
# Non_Smoker_Vehicle      0
# Seller                  0
# Image_url               0
# dtype: int64
