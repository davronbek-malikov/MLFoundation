# %%
import pandas as pd

df = pd.read_csv('./../Data/boston-housing-dataset.csv')

# %% [markdown]
# # Data review

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# # Encoding raqamlashtrish

# %% [markdown]
# # Scalling

# %% [markdown]
# # Model selection

# %% [markdown]
# # Train
