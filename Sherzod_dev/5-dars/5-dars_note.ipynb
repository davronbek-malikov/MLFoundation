# %% [markdown]
# ## Data Profiling
#
# head() tail() info() isnull() bpshi oxiri datning turi va orasida tushib qolganlarini tekshirib beradi.

# %% [markdown]
# ## Missing Value Handling
#
# orin bosuvchi toldiruvchi deb tarjima qilseg boladi bunda aniq javob emas filna orqali ortacha 0.5 0.25 chorak, dataning markazida turga yoki eng baland (max) lari bilan datani toldirish.
#
# ### Nima uchun kerak? 정답에 가까운 답을 얻기 위해서 필요합니다.

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %% [markdown]
# Misol age degan bolimni ol. va unda bosh joy bolsa markazdagi data bilan toldir
