# %% [markdown]
# # For loop
# ### Bitta bitta chiqarib hal qilaman degani

# %%
for i in range(0,100,10):
    if i == 50:
        continue
    else: print(i)
# Out:
# 0
# 10
# 20
# 30
# 40
# 60
# 70
# 80
# 90
