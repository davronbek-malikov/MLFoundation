# %% [markdown]
# ## AI
# #### Supervosed      지도학습
#
# #### UnSupervised   비지도학습
#
# #### Reinforcement  강화학습

# %%
# 1-javob
s = 'Hello'
print(s[0],s[-1] )
# 2-javob
number1 = 44;
number2 = 33;
print(number1 > 0 and number1 % 2 == 0);
print(number2 > 0 and number2 % 2 == 0);
# 3-javob
print(s[-2])
# Out:
# H o
# True
# False
# l

# %%
num = 4

if num % 2 != 0:
    print("toq son")

if num < 0:
    print("manfiy son")

if num % 2 == 0 and num >= 0:
    print("juft son")
