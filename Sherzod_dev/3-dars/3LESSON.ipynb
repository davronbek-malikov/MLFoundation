# %% [markdown]
# # Data bn tanishuv

# %%
import pandas as pd

# %%
# Install qilish
    #1. pip install pandas
    #2. %pip install pandas
    #3. !pip install pandas

# %%
df=pd.read_csv('../Data/Iris.csv')

# %%
# head boshida 5 ta qatorni ko'rsatadi
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# tail oxirida 3 ta qatorni ko'rsatadi
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.nunique()   # xar bir ustundagi classlar soni
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
df['Id'].nunique() # Id ustunidagi unique qiymatlar soni
# Out:
# 150

# %%
df['Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()   #data xaqida umumuy malumot olish
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7038 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7042 non-null   object
#  5   tenure            7042 non-null   float64
#  6   PhoneService      7042 non-null   object
#  7   MultipleLines     7042 non-null   object
#  8   InternetService   7042 non-null   object
#  9   OnlineSecurity    7042 non-null   object
#  10  OnlineBackup      7042 non-null   object
#  11  DeviceProtection  7042 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       5
# Partner             0
# Dependents          1
# tenure              1
# PhoneService        1
# MultipleLines       1
# InternetService     1
# OnlineSecurity      1
# OnlineBackup        1
# DeviceProtection    1
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.isnull().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen        True
# Partner             False
# Dependents           True
# tenure               True
# PhoneService         True
# MultipleLines        True
# InternetService      True
# OnlineSecurity       True
# OnlineBackup         True
# DeviceProtection     True
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %% [markdown]
# # Conditions

# %%
#agar son musbat bolsa yaxshi aks xolda yomon degan sozni ekranga chiqaring

# %%
a=4
if a>0:
    print('Yaxshi')
elif a<0:
    print('Yomon')
else:
    print('nol')
# Out:
# Yaxshi

# %%
baxo=4
if baxo==5:
    print('alo')
elif baxo==4:
    print('yaxshi')
elif baxo==3:
    print('ortacha')
elif baxo==2:
    print('yomon')
else:
    print('xatolik bor yoki juda yomon')
# Out:
# yaxshi
