# %% [markdown]
# ## Algorithm bu tartib
# ##### algorithm bu model yasashgacha olib boradigon yol
# ##### biz Algorithmni model yasashgacha bolgan jarayonda Ishlatamiz
# ## Model bu natijamiz
# ##### model oxirgi olingan Natija boladi biz uni har hil joylarda ishlatishimiz mumkin
