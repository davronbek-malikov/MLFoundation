# %% [markdown]
# ## 2-Oy 1-dars report
# ### def nima?
# #### aqilli quti def bitta ishni qayta qayta qilishni automatlashtradi

# %%
# def definition tariflash + function_name + qavsichida parametr ()
# : (Ikki nuqta) – Python-ga: "Tayyor tur, hozir pastki qatordan boshlab bajaraidigan ishlarimni (algoritmni) yozaman" degani.

def function_name():
	# Mana shu surilgan qatorlar yuqoridagi def ga tegishli" degan ma'noni bildiradi.
	print("Hello World")
# funksiyani chaqirish
function_name()
# Out:
# Hello World

# %%
# for takrorlash zanjiri
# ozgaruvchi + list[]
royxat = [1,2,3,4,5]
# for aylanib chiqarish i = varible in qayerdan olay? royhatni ichidan oladi
for i in royxat:
	print(i)
