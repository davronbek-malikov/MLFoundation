# %% [markdown]
# imtihonga tayorgallik + 4 ta algorithmga data + code

# %%
import pandas as pd 
df = pd.read_csv("") 
df.info()

# %% [markdown]
# ## Preprocessing datalarni toldirish

# %%
def datalarni_toldirsin(df):
    for col in df.columns:
        if df[col].insull().any():
            if df[col].dtype == "object":
                df[col].fillna(df[col].mode()[0], inplace=True)
            else:
                df[col].fillna(df[col].mean(), inplace=True)
    return(df)
df = datalarni_toldirsin(df)

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder
def encoding_qilsin(df):
    label_encoder = LabelEncoder()
    for col in df.columns:
        if df[col].dtype == "object":
            if df[col] = label_encoder.fit_transform(df[col])
    return df
df = encoding_qilsin(df)

# %% [markdown]
# ## Data Scalerlash

# %%
from sklearn.preprocessing import StandardScaler
def scalerla(df):
    scla = StandardScaler()
    df = scla.fit_transform(df)
    return df
df = scalerla(df)

# %% [markdown]
# ## train va testga ajrat

# %%
from sklearn.model_selection import train_test_split 
x = df.drop("", axis=1)
y = df[""]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
