# %% [markdown]
# ### Data nimani aytadi
#
# - Dataset **to‘liq**
# - Missing values yo‘q
# - Keyingi tahlil xavfsiz bajarilishi mumkin
#
# ---
#
# # 3. Crude Oil (Neft) Ma’lumotlari
#
# ### Natija
#
# | Sana | Brent | WTI | Phase |
# |-----|-----|-----|-----|
# |2026-02-16|74.2|70.1|Pre-Conflict|
# |2026-02-23|78.5|74.0|Escalation|
# |2026-03-01|94.5|90.0|Peak|
# |2026-03-02|96.0|91.5|Peak|
# |2026-03-03|95.0|90.5|Peak|
#
# ### Data nimani aytadi
#
# Neft narxi:
# 74 → 96
#
# ya’ni konflikt paytida **keskin oshgan**.
#
# ---
#
# # 4. Petrol Price Increase by Country (Bar Chart)
#
# ### Natija
#
# Eng yuqori o‘sish:
#
# | Mamlakat | O‘sish |
# |---|---|
# |Pakistan|20.66%|
# |Iran|15.56%|
# |UK|13.79%|
# |Germany|≈12%|
# |France|≈11%|
#
# Eng past:
#
# | Mamlakat | O‘sish |
# |---|---|
# |India|0%|
# |Afghanistan|0%|
# |Saudi Arabia|0%|
#
# ### Data nimani aytadi
#
# - Eng katta o‘sish: **Pakistan va Iran**
# - Yevropa mamlakatlari: **10–14% o‘sish**
# - Ba’zi mamlakatlar: **narx stabil**
#
# ---
#
# # 5. Petrol Price Increase by Region (Box Plot)
#
# ### Natija
#
# Regionlar:
#
# - South Asia
# - Europe
# - North America
# - East Asia
# - Middle East
#
# ### Data nimani aytadi
#
# **South Asia**
#
# - katta farq
# - 0% dan 20% gacha
#
# **Europe**
#
# - bir xil o‘sish
# - taxminan **10–14%**
#
# **Middle East**
#
# - Saudiya: 0%
# - Iran: 15.56%
#
# ---
#
# # 6. Top 5 Countries (Plotly Bar)
#
# ### Natija
#
# Top mamlakatlar:
#
# 1. Pakistan
# 2. Iran
# 3. UK
# 4. Germany
# 5. France
#
# ### Data nimani aytadi
#
# Bu mamlakatlar **geosiyosiy shokga eng sezgir**.
#
# ---
#
# # 7. Crude Oil Prices During Conflict (Line Chart)
#
# ### Natija
#
# Narx harakati:
#
#
# GDP impact ↑
# Inflation risk ↑
#
#
#
#
# ---
#
# # 13. ARIMA — Brent Oil Price Forecast
#
# ### Natija
#
# ARIMA modeli yordamida **neft narxi prognozi** qilindi.
#
# Grafik:
#
# - real narx
# - forecast narx
# - confidence interval
#
# ### Data nimani aytadi
#
# Agar trend davom etsa:
# Event → Price reaction
#
#
#
#
# ---
#
# # 15. Choropleth Map (World Map)
#
# ### Natija
#
# Xaritada mamlakatlar rang bilan ko‘rsatiladi:
#
# - ko‘k → past o‘sish
# - qizil → yuqori o‘sish
#
# ### Data nimani aytadi
#
# Global miqyosda:
#
# > qaysi hududlarda benzin narxi ko‘p o‘sgani ko‘rinadi
#
# ---
#
# # Umumiy Xulosa
#
# Data quyidagilarni ko‘rsatadi:
#
# 1. Konflikt paytida **xom neft narxi keskin oshgan**
# 2. Benzin narxi mamlakatlarga qarab **turlicha o‘sgan**
# 3. **Import dependency** narx o‘sishiga katta ta’sir qiladi
# 4. Geosiyosiy voqealar **energiya bozoriga tez ta’sir qiladi**
