# %% [markdown]
# TUSHIB QOLDIRILGAN QIMANLARNI TOLDIRISH

# %%
import pandas as pd

# %%
df=pd.read_csv('clinvar_conflicting.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10876\1084741125.py:1: DtypeWarning: Columns (0,38,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('clinvar_conflicting.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65188 entries, 0 to 65187
# Data columns (total 46 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CHROM               65188 non-null  object
#  1   POS                 65188 non-null  int64
#  2   REF                 65188 non-null  object
#  3   ALT                 65188 non-null  object
#  4   AF_ESP              65188 non-null  float64
#  5   AF_EXAC             65188 non-null  float64
#  6   AF_TGP              65188 non-null  float64
#  7   CLNDISDB            65188 non-null  object
#  8   CLNDISDBINCL        167 non-null    object
#  9   CLNDN               65188 non-null  object
#  10  CLNDNINCL           167 non-null    object
#  11  CLNHGVS             65188 non-null  object
#  12  CLNSIGINCL          167 non-null    object
#  13  CLNVC               65188 non-null  object
#  14  CLNVI               27659 non-null  object
# ...

# %%
df.head()
# Out:
#   CHROM      POS REF ALT  AF_ESP  AF_EXAC  AF_TGP  \
# 0     1  1168180   G   C  0.0771  0.10020  0.1066
# 1     1  1470752   G   A  0.0000  0.00000  0.0000
# 2     1  1737942   A   G  0.0000  0.00001  0.0000
# 3     1  2160305   G   A  0.0000  0.00000  0.0000
# 4     1  2160305   G   T  0.0000  0.00000  0.0000
#
#                                             CLNDISDB CLNDISDBINCL  \
# 0                                    MedGen:CN169374          NaN
# 1  MedGen:C1843891,OMIM:607454,Orphanet:ORPHA9877...          NaN
# 2  Human_Phenotype_Ontology:HP:0000486,MedGen:C00...          NaN
# 3  MedGen:C1321551,OMIM:182212,SNOMED_CT:83092002...          NaN
# 4     MedGen:C1321551,OMIM:182212,SNOMED_CT:83092002          NaN
#
#                                                CLNDN  ...  \
# 0                                      not_specified  ...
# 1             Spinocerebellar_ataxia_21|not_provided  ...
# 2  Strabismus|Nystagmus|Hypothyroidism|Intellectu...  ...
# ...

# %%
df.nunique()
# Out:
# CHROM                    38
# POS                   63115
# REF                     866
# ALT                     458
# AF_ESP                 2842
# AF_EXAC                6667
# AF_TGP                 2087
# CLNDISDB               9234
# CLNDISDBINCL             93
# CLNDN                  9260
# CLNDNINCL               101
# CLNHGVS               65188
# CLNSIGINCL              137
# CLNVC                     7
# CLNVI                 27654
# MC                       90
# ORIGIN                   31
# SSR                       2
# CLASS                     2
# Allele                  374
# Consequence              48
# IMPACT                    4
# SYMBOL                 2328
# Feature_type              2
# Feature                2369
# BIOTYPE                   2
# EXON                   3264
# INTRON                 1929
# cDNA_position         13970
# CDS_position          13663
# Protein_position       7339
# Amino_acids            1262
# Codons                 2220
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65188 entries, 0 to 65187
# Data columns (total 46 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CHROM               65188 non-null  object
#  1   POS                 65188 non-null  int64
#  2   REF                 65188 non-null  object
#  3   ALT                 65188 non-null  object
#  4   AF_ESP              65188 non-null  float64
#  5   AF_EXAC             65188 non-null  float64
#  6   AF_TGP              65188 non-null  float64
#  7   CLNDISDB            65188 non-null  object
#  8   CLNDISDBINCL        167 non-null    object
#  9   CLNDN               65188 non-null  object
#  10  CLNDNINCL           167 non-null    object
#  11  CLNHGVS             65188 non-null  object
#  12  CLNSIGINCL          167 non-null    object
#  13  CLNVC               65188 non-null  object
#  14  CLNVI               27659 non-null  object
# ...

# %%
df=pd.read_csv('clinvar_conflicting.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10876\1084741125.py:1: DtypeWarning: Columns (0,6,16,17,18,34,38,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('clinvar_conflicting.csv')

# %%
df.isnull().any()
# Out:
# CHROM                 False
# POS                   False
# REF                   False
# ALT                   False
# AF_ESP                False
# AF_EXAC               False
# AF_TGP                False
# CLNDISDB               True
# CLNDISDBINCL           True
# CLNDN                  True
# CLNDNINCL              True
# CLNHGVS                True
# CLNSIGINCL             True
# CLNVC                 False
# CLNVI                  True
# MC                     True
# ORIGIN                 True
# SSR                    True
# CLASS                 False
# Allele                False
# Consequence           False
# IMPACT                False
# SYMBOL                 True
# Feature_type           True
# Feature                True
# BIOTYPE                True
# EXON                   True
# INTRON                 True
# cDNA_position          True
# CDS_position           True
# Protein_position       True
# Amino_acids            True
# Codons                 True
# ...

# %%
df.isnull().sum()
# Out:
# CHROM                     0
# POS                       0
# REF                       0
# ALT                       0
# AF_ESP                    0
# AF_EXAC                   0
# AF_TGP                    0
# CLNDISDB                  1
# CLNDISDBINCL          64979
# CLNDN                     1
# CLNDNINCL             64979
# CLNHGVS                   1
# CLNSIGINCL            64980
# CLNVC                     0
# CLNVI                 37529
# MC                      846
# ORIGIN                    1
# SSR                   65015
# CLASS                     0
# Allele                    0
# Consequence               0
# IMPACT                    0
# SYMBOL                   17
# Feature_type             14
# Feature                  14
# BIOTYPE                  16
# EXON                   8894
# INTRON                56342
# cDNA_position          8885
# CDS_position           9955
# Protein_position       9955
# Amino_acids           10004
# Codons                10005
# ...

# %%
df.drop('SSR', axis=1, inplace=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.drop('SSR', axis=1, inplace=true)
#
# NameError: name 'true' is not defined

# %%
df.drop('SSR', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65147 entries, 0 to 65146
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CHROM               65147 non-null  object
#  1   POS                 65147 non-null  int64
#  2   REF                 65147 non-null  object
#  3   ALT                 65147 non-null  object
#  4   AF_ESP              65147 non-null  float64
#  5   AF_EXAC             65147 non-null  float64
#  6   AF_TGP              65147 non-null  object
#  7   CLNDISDB            65146 non-null  object
#  8   CLNDISDBINCL        168 non-null    object
#  9   CLNDN               65146 non-null  object
#  10  CLNDNINCL           168 non-null    object
#  11  CLNHGVS             65146 non-null  object
#  12  CLNSIGINCL          167 non-null    object
#  13  CLNVC               65147 non-null  object
#  14  CLNVI               27618 non-null  object
# ...

# %%
df.info('SYMBOL')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65147 entries, 0 to 65146
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CHROM               65147 non-null  object
#  1   POS                 65147 non-null  int64
#  2   REF                 65147 non-null  object
#  3   ALT                 65147 non-null  object
#  4   AF_ESP              65147 non-null  float64
#  5   AF_EXAC             65147 non-null  float64
#  6   AF_TGP              65147 non-null  object
#  7   CLNDISDB            65146 non-null  object
#  8   CLNDISDBINCL        168 non-null    object
#  9   CLNDN               65146 non-null  object
#  10  CLNDNINCL           168 non-null    object
#  11  CLNHGVS             65146 non-null  object
#  12  CLNSIGINCL          167 non-null    object
#  13  CLNVC               65147 non-null  object
#  14  CLNVI               27618 non-null  object
# ...

# %%
df['SYMBOL']
# Out:
# 0        B3GALT6
# 1        TMEM240
# 2           GNB1
# 3            SKI
# 4            SKI
#           ...
# 65142         F8
# 65143         F8
# 65144         F8
# 65145     RAB39B
# 65146      CLIC2
# Name: SYMBOL, Length: 65147, dtype: object

# %%
df['SYMBOL'].fillna(df['SYMBOL'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# CHROM                     0
# POS                       0
# REF                       0
# ALT                       0
# AF_ESP                    0
# AF_EXAC                   0
# AF_TGP                    0
# CLNDISDB                  1
# CLNDISDBINCL          64979
# CLNDN                     1
# CLNDNINCL             64979
# CLNHGVS                   1
# CLNSIGINCL            64980
# CLNVC                     0
# CLNVI                 37529
# MC                      846
# ORIGIN                    1
# CLASS                     0
# Allele                    0
# Consequence               0
# IMPACT                    0
# SYMBOL                    0
# Feature_type             14
# Feature                  14
# BIOTYPE                  16
# EXON                   8894
# INTRON                56342
# cDNA_position          8885
# CDS_position           9955
# Protein_position       9955
# Amino_acids           10004
# Codons                10005
# DISTANCE              65038
# ...

# %%
df[['Feature_type', 'Feature', 'BIOTYPE']]
# Out:
#       Feature_type         Feature         BIOTYPE
# 0       Transcript     NM_080605.3  protein_coding
# 1       Transcript  NM_001114748.1  protein_coding
# 2       Transcript     NM_002074.4  protein_coding
# 3       Transcript  XM_005244775.1  protein_coding
# 4       Transcript  XM_005244775.1  protein_coding
# ...            ...             ...             ...
# 65142   Transcript     NM_000132.3  protein_coding
# 65143   Transcript     NM_000132.3  protein_coding
# 65144   Transcript     NM_000132.3  protein_coding
# 65145   Transcript     NM_171998.2  protein_coding
# 65146   Transcript  XM_005274646.1  protein_coding
#
# [65147 rows x 3 columns]

# %%
df['BIOTYPE'].fillna(df['BIOTYPE'].mode()[0],inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10876\2970339420.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BIOTYPE'].fillna(df['BIOTYPE'].mode()[0],inplace=True)

# %%
df['BIOTYPE']
# Out:
# 0        protein_coding
# 1        protein_coding
# 2        protein_coding
# 3        protein_coding
# 4        protein_coding
#               ...
# 65142    protein_coding
# 65143    protein_coding
# 65144    protein_coding
# 65145    protein_coding
# 65146    protein_coding
# Name: BIOTYPE, Length: 65147, dtype: object

# %%
df.isnull().sum()
# Out:
# CHROM                     0
# POS                       0
# REF                       0
# ALT                       0
# AF_ESP                    0
# AF_EXAC                   0
# AF_TGP                    0
# CLNDISDB                  1
# CLNDISDBINCL          64979
# CLNDN                     1
# CLNDNINCL             64979
# CLNHGVS                   1
# CLNSIGINCL            64980
# CLNVC                     0
# CLNVI                 37529
# MC                      846
# ORIGIN                    1
# CLASS                     0
# Allele                    0
# Consequence               0
# IMPACT                    0
# SYMBOL                    0
# Feature_type              0
# Feature                  14
# BIOTYPE                   0
# EXON                   8894
# INTRON                56342
# cDNA_position          8885
# CDS_position           9955
# Protein_position       9955
# Amino_acids           10004
# Codons                10005
# DISTANCE              65038
# ...

# %%
df['Feature_type'].fillna('transcript',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10876\4188473738.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Feature_type'].fillna('transcript',inplace=True)

# %%
df.drop('CLNDISDBINCL', axis=1, inplace=True)

# %%
df.drop('CLNDNINCL', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65147 entries, 0 to 65146
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CHROM               65147 non-null  object
#  1   POS                 65147 non-null  int64
#  2   REF                 65147 non-null  object
#  3   ALT                 65147 non-null  object
#  4   AF_ESP              65147 non-null  float64
#  5   AF_EXAC             65147 non-null  float64
#  6   AF_TGP              65147 non-null  object
#  7   CLNDISDB            65146 non-null  object
#  8   CLNDN               65146 non-null  object
#  9   CLNHGVS             65146 non-null  object
#  10  CLNVC               65147 non-null  object
#  11  CLNVI               27618 non-null  object
#  12  MC                  64301 non-null  object
#  13  ORIGIN              65146 non-null  object
#  14  CLASS               65147 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# CHROM                     0
# POS                       0
# REF                       0
# ALT                       0
# AF_ESP                    0
# AF_EXAC                   0
# AF_TGP                    0
# CLNDISDB                  1
# CLNDN                     1
# CLNHGVS                   1
# CLNVC                     0
# CLNVI                 37529
# MC                      846
# ORIGIN                    1
# CLASS                     0
# Allele                    0
# Consequence               0
# IMPACT                    0
# SYMBOL                    0
# Feature_type              0
# Feature                  14
# BIOTYPE                   0
# EXON                   8894
# INTRON                56342
# cDNA_position          8885
# CDS_position           9955
# Protein_position       9955
# Amino_acids           10004
# Codons                10005
# DISTANCE              65038
# STRAND                   15
# BAM_EDIT              33214
# SIFT                  40350
# ...
