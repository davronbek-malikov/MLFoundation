# %% [markdown]
# #Encoding

# %%
import pandas as pd

# %%
df=pd.read_csv('Obesity Classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      108 non-null    int64
#  1   Age     108 non-null    int64
#  2   Gender  108 non-null    object
#  3   Height  108 non-null    int64
#  4   Weight  108 non-null    int64
#  5   BMI     108 non-null    float64
#  6   Label   108 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 6.0+ KB

# %%
df.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    0
# Weight    0
# BMI       0
# Label     0
# dtype: int64

# %%
df.nunique()
# Out:
# ID        108
# Age        75
# Gender      2
# Height     10
# Weight     23
# BMI        25
# Label       4
# dtype: int64

# %% [markdown]
# ONE_HOT ENCODING

# %%
dummuies=pd.get_dummies(df['Label'],prefix='pre',dtype=int)

# %%
dummuies
# Out:
#      pre_Normal Weight  pre_Obese  pre_Overweight  pre_Underweight
# 0                    1          0               0                0
# 1                    1          0               0                0
# 2                    0          0               1                0
# 3                    0          0               0                1
# 4                    0          1               0                0
# ..                 ...        ...             ...              ...
# 103                  0          0               0                1
# 104                  0          0               0                1
# 105                  0          0               0                1
# 106                  0          0               0                1
# 107                  0          0               0                1
#
# [108 rows x 4 columns]

# %%
df=pd.concat([df.drop(columns=['Label']),dummuies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 108 non-null    int64
#  1   Age                108 non-null    int64
#  2   Height             108 non-null    int64
#  3   Weight             108 non-null    int64
#  4   BMI                108 non-null    float64
#  5   pre_Normal Weight  108 non-null    int64
#  6   pre_Obese          108 non-null    int64
#  7   pre_Overweight     108 non-null    int64
#  8   pre_Underweight    108 non-null    int64
#  9   post_Female        108 non-null    int64
#  10  post_Male          108 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 9.4 KB

# %%
df=pd.concat([df.drop(columns=['Gender']),dummuies],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 108 non-null    int64
#  1   Age                108 non-null    int64
#  2   Height             108 non-null    int64
#  3   Weight             108 non-null    int64
#  4   BMI                108 non-null    float64
#  5   pre_Normal Weight  108 non-null    int64
#  6   pre_Obese          108 non-null    int64
#  7   pre_Overweight     108 non-null    int64
#  8   pre_Underweight    108 non-null    int64
#  9   post_Female        108 non-null    int64
#  10  post_Male          108 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 9.4 KB

# %%
df.head()
# Out:
#    ID  Age  Height  Weight   BMI  pre_Normal Weight  pre_Obese  \
# 0   1   25     175      80  25.3                  1          0
# 1   2   30     160      60  22.5                  1          0
# 2   3   35     180      90  27.3                  0          0
# 3   4   40     150      50  20.0                  0          0
# 4   5   45     190     100  31.2                  0          1
#
#    pre_Overweight  pre_Underweight  post_Female  post_Male
# 0               0                0            0          1
# 1               0                0            1          0
# 2               1                0            0          1
# 3               0                1            1          0
# 4               0                0            0          1

# %%
df.drop('ID', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                108 non-null    int64
#  1   Height             108 non-null    int64
#  2   Weight             108 non-null    int64
#  3   BMI                108 non-null    float64
#  4   pre_Normal Weight  108 non-null    int64
#  5   pre_Obese          108 non-null    int64
#  6   pre_Overweight     108 non-null    int64
#  7   pre_Underweight    108 non-null    int64
#  8   post_Female        108 non-null    int64
#  9   post_Male          108 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 8.6 KB

# %%
df=pd.read_csv('Obesity Classification.csv')

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    1
# Height    1
# Weight    3
# BMI       3
# Label     3
# dtype: int64

# %%
df.head()
# Out:
#    ID Age  Gender Height  Weight   BMI          Label
# 0   1  25    Male    175    80.0  25.3  Normal Weight
# 1   2  30  Female    160    60.0  22.5  Normal Weight
# 2   3  35    Male    180    90.0  27.3     Overweight
# 3   4  40  Female    150    50.0  20.0    Underweight
# 4   5  45    Male    190   100.0  31.2          Obese

# %%
df['Gender']. fillna('Male', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18380\3959443400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender']. fillna('Male', inplace=True)

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    1
# Weight    3
# BMI       3
# Label     3
# dtype: int64

# %%
df['Height'].fillna(df['Height'].mode()[0],inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18380\3530653789.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Height'].fillna(df['Height'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    0
# Weight    3
# BMI       3
# Label     3
# dtype: int64

# %%
df.isnull().any()
# Out:
# ID        False
# Age       False
# Gender    False
# Height    False
# Weight     True
# BMI        True
# Label      True
# dtype: bool

# %%
df['Weight'].fillna(df['Weight'].mean(),inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18380\371550695.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weight'].fillna(df['Weight'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    0
# Weight    0
# BMI       3
# Label     3
# dtype: int64

# %%
df['BMI'].fillna(df['BMI'].median(),inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18380\4225218744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BMI'].fillna(df['BMI'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    0
# Weight    0
# BMI       0
# Label     3
# dtype: int64

# %%
df.head()
# Out:
#    ID Age  Gender Height  Weight   BMI          Label
# 0   1  25    Male    175    80.0  25.3  Normal Weight
# 1   2  30  Female    160    60.0  22.5  Normal Weight
# 2   3  35    Male    180    90.0  27.3     Overweight
# 3   4  40  Female    150    50.0  20.0    Underweight
# 4   5  45    Male    190   100.0  31.2          Obese

# %%
df.drop('ID', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    1
# Height    1
# Weight    3
# BMI       3
# Label     3
# dtype: int64

# %%
dummies=pd.get_dummies(df['Label'],prefix='post',dtype=int)

# %%
dummies
# Out:
#     post_Normal Weight  post_Obese  post_Overweight  post_Underweight
# 0                    1           0                0                 0
# 1                    1           0                0                 0
# 2                    0           0                1                 0
# 3                    0           0                0                 1
# 4                    0           1                0                 0
# ..                 ...         ...              ...               ...
# 92                   0           0                0                 1
# 93                   0           0                0                 1
# 94                   0           0                0                 1
# 95                   0           0                0                 1
# 96                   0           0                0                 1
#
# [97 rows x 4 columns]

# %%
df=pd.concat([df.drop(colums=['Label'])dummies]axis=1)
# Out:
#   Cell In[114], line 1
#     df=pd.concat([df.drop(colums=['Label'])dummies]axis=1)
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df=pd.concat([df.drop(colums=['Label'])dummies],axis=1)
# Out:
#   Cell In[115], line 1
#     df=pd.concat([df.drop(colums=['Label'])dummies],axis=1)
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df=pd.concat([df.drop(columns=['Label']),dummies], axis=1)

# %%
df.head()
# Out:
#    ID Age  Gender Height  Weight   BMI  post_Normal Weight  post_Obese  \
# 0   1  25    Male    175    80.0  25.3                   1           0
# 1   2  30  Female    160    60.0  22.5                   1           0
# 2   3  35    Male    180    90.0  27.3                   0           0
# 3   4  40  Female    150    50.0  20.0                   0           0
# 4   5  45    Male    190   100.0  31.2                   0           1
#
#    post_Overweight  post_Underweight
# 0                0                 0
# 1                0                 0
# 2                1                 0
# 3                0                 1
# 4                0                 0

# %%
df.isnull().sum()
# Out:
# ID                    0
# Age                   0
# Gender                0
# Height                0
# Weight                0
# BMI                   0
# post_Normal Weight    0
# post_Obese            0
# post_Overweight       0
# post_Underweight      0
# dtype: int64

# %%
df.nunique()
# Out:
# ID                    97
# Age                   69
# Gender                 2
# Height                12
# Weight                24
# BMI                   26
# post_Normal Weight     2
# post_Obese             2
# post_Overweight        2
# post_Underweight       2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  97 non-null     int64
#  1   Age                 97 non-null     object
#  2   Gender              96 non-null     object
#  3   Height              97 non-null     object
#  4   Weight              97 non-null     float64
#  5   BMI                 97 non-null     float64
#  6   post_Normal Weight  97 non-null     int64
#  7   post_Obese          97 non-null     int64
#  8   post_Overweight     97 non-null     int64
#  9   post_Underweight    97 non-null     int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 7.7+ KB

# %%
df.drop('ID', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 97 non-null     object
#  1   Gender              97 non-null     object
#  2   Height              97 non-null     object
#  3   Weight              97 non-null     float64
#  4   BMI                 97 non-null     float64
#  5   post_Normal Weight  97 non-null     int64
#  6   post_Obese          97 non-null     int64
#  7   post_Overweight     97 non-null     int64
#  8   post_Underweight    97 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 6.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder

# %%
men=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      97 non-null     int64
#  1   Age     97 non-null     object
#  2   Gender  96 non-null     object
#  3   Height  96 non-null     object
#  4   Weight  94 non-null     float64
#  5   BMI     94 non-null     float64
#  6   Label   94 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 5.4+ KB

# %%
df['Gender']=encoder.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    ID Age  Gender Height  Weight   BMI          Label
# 0   1  25       1    175    80.0  25.3  Normal Weight
# 1   2  30       0    160    60.0  22.5  Normal Weight
# 2   3  35       1    180    90.0  27.3     Overweight
# 3   4  40       0    150    50.0  20.0    Underweight
# 4   5  45       1    190   100.0  31.2          Obese

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      97 non-null     int64
#  1   Age     97 non-null     object
#  2   Gender  97 non-null     int64
#  3   Height  96 non-null     object
#  4   Weight  94 non-null     float64
#  5   BMI     94 non-null     float64
#  6   Label   94 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.4+ KB

# %%
df['Age']=encoder.fit_transform(df['Age'])

# %%
df.head()
# Out:
#    ID  Age  Gender Height  Weight   BMI          Label
# 0   1   19       1    175    80.0  25.3  Normal Weight
# 1   2   25       0    160    60.0  22.5  Normal Weight
# 2   3   29       1    180    90.0  27.3     Overweight
# 3   4   33       0    150    50.0  20.0    Underweight
# 4   5   38       1    190   100.0  31.2          Obese

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      97 non-null     int64
#  1   Age     97 non-null     int64
#  2   Gender  97 non-null     int64
#  3   Height  97 non-null     int64
#  4   Weight  94 non-null     float64
#  5   BMI     94 non-null     float64
#  6   Label   97 non-null     int64
# dtypes: float64(2), int64(5)
# memory usage: 5.4 KB

# %%
df['Height']=encoder.fit_transform(df['Height'])

# %%
df['Label']=encoder.fit_transform(df['Label'])

# %%
df.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI  Label
# 0   1   19       1       5    80.0  25.3      0
# 1   2   25       0       4    60.0  22.5      0
# 2   3   29       1       6    90.0  27.3      2
# 3   4   33       0       3    50.0  20.0      3
# 4   5   38       1       7   100.0  31.2      1

# %%
men
# Out:
# LabelEncoder()

# %%
df['Age']=men.fit_tarnsform(df['Age'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df['Age']=men.fit_tarnsform(df['Age'])
#
# AttributeError: 'LabelEncoder' object has no attribute 'fit_tarnsform'

# %%
df=pd.read_csv('Obesity Classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      97 non-null     int64
#  1   Age     97 non-null     object
#  2   Gender  96 non-null     object
#  3   Height  96 non-null     object
#  4   Weight  94 non-null     float64
#  5   BMI     94 non-null     float64
#  6   Label   97 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.4+ KB

# %%
df['Label']=men.fit_transform(df['Label'])
