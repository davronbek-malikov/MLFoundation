# %% [markdown]
# # Data Types, Operations va Conditions ta'luqli misollar

# %%
# Foydalanuvchidan yosh va ismini so'rab ularni tegishli data typeda saqlang

ism = input("Ismingizni yozing: ")
yosh = int(input("Yoshingizni yozing: "))

print(f"Hurmatli {ism}, sizning yoshingiz {yosh}da.")
# Out:
# Hurmatli Murodjon, sizning yoshingiz 30da.

# %%
# Qiymati 3.14 bo'lgan o'zgaruvchi yarating va uning turini tekshiring
pi = 3.14 
print(type(pi))
# Out:
# <class 'float'>

# %% [markdown]
# # Operations

# %%
# ikki sonni qo'shuvchi va ayiruvchi amal bajaruvchi kod yozing 
a = int(input('Birinchi sonni kiriting: '))
b = int(input('Ikkinchi sonni kiriting: '))

print(a+b)
print(a-b)
# Out:
# 11
# 1

# %%
# Son x = 7 va y = 10 uchun x > y va x != y natijalarini konsolga chiqaruvchi kod yozing. 
x = 7 
y = 10 

print(x>y)
print(x != y)
# Out:
# False
# True

# %% [markdown]
# # Conditions
