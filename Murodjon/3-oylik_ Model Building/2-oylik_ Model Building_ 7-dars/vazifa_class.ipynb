# %% [markdown]
# # O'zim haqimda classdan foydalangan holda ma'lumot berdim.

# %%
class Info_indivuduality:
    def __init__(self, ism, yosh, manzil, tel, email):
        self.ism = ism
        self.yosh = yosh
        self.manzil = manzil
        self.tel = tel
        self.email = email

    def shaxs_haqida_malumot_ber(self):
        print(f"--- O'zim haqimda ma'lumot ---")
        print(f"Ismim: {self.ism}")
        print(f"Yoshim: {self.yosh}da")
        print(f"Hozirdagi manzilim: {self.manzil}")
        print(f"Telefon raqamim: {self.tel}")
        print(f"Email pochtam: {self.email}")

murodjon = Info_indivuduality(
    ism="Murodjon", 
    yosh=30, 
    manzil="Koreya, Gimhae-si", 
    tel="010-7295-5961", 
    email="murodjon19950619@gmail.com"
)

murodjon.shaxs_haqida_malumot_ber()
# Out:
# --- O'zim haqimda ma'lumot ---
# Ismim: Murodjon
# Yoshim: 30da
# Hozirdagi manzilim: Koreya, Gimhae-si
# Telefon raqamim: 010-7295-5961
# Email pochtam: murodjon19950619@gmail.com
