# %% [markdown]
# # confusion_matrix va classification_report

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_actual = [1, 0, 1, 1, 1, 0, 0, 1, 1, 0]
y_pred = [1, 0, 1, 1, 1, 1, 1, 0, 0, 0]

cm = confusion_matrix(y_actual,y_pred)

# %%
cm
# Out:
# array([[2, 2],
#        [2, 4]])

# %%
class_report = classification_report(y_actual, y_pred)

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         4
#            1       0.67      0.67      0.67         6
#
#     accuracy                           0.60        10
#    macro avg       0.58      0.58      0.58        10
# weighted avg       0.60      0.60      0.60        10
