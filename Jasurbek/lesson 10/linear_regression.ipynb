# %%
import pandas as pd

# %%
df=pd.read_csv("kdrama.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  250 non-null    str
#  1   Aired Date            250 non-null    str
#  2   Year of release       250 non-null    int64
#  3   Original Network      250 non-null    str
#  4   Aired On              250 non-null    str
#  5   Number of Episodes    250 non-null    int64
#  6   Duration              250 non-null    str
#  7   Content Rating        245 non-null    str
#  8   Rating                250 non-null    float64
#  9   Synopsis              250 non-null    str
#  10  Genre                 250 non-null    str
#  11  Tags                  250 non-null    str
#  12  Director              249 non-null    str
#  13  Screenwriter          249 non-null    str
#  14  Cast                  250 non-null    str
#  15  Production companies  248 non-null    str
# ...

# %% [markdown]
# Data

# %%
df.head()
# Out:
#                   Name                   Aired Date  Year of release  \
# 0       Move to Heaven                 May 14, 2021             2021
# 1       Flower of Evil  Jul 29, 2020 - Sep 23, 2020             2020
# 2    Hospital Playlist  Mar 12, 2020 - May 28, 2020             2020
# 3  Hospital Playlist 2  Jun 17, 2021 - Sep 16, 2021             2021
# 4            My Mister  Mar 21, 2018 - May 17, 2018             2018
#
#   Original Network              Aired On  Number of Episodes       Duration  \
# 0          Netflix                Friday                  10        52 min.
# 1              tvN   Wednesday, Thursday                  16  1 hr. 10 min.
# 2   Netflix,  tvN               Thursday                  12  1 hr. 30 min.
# 3   Netflix,  tvN               Thursday                  12  1 hr. 40 min.
# 4              tvN   Wednesday, Thursday                  16  1 hr. 17 min.
#
#                           Content Rating  Rating  \
# ...

# %%
df.drop(columns=["Rank","Cast","Genres"], inplace=True, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  250 non-null    str
#  1   Aired Date            250 non-null    str
#  2   Year of release       250 non-null    int64
#  3   Original Network      250 non-null    str
#  4   Aired On              250 non-null    str
#  5   Number of Episodes    250 non-null    int64
#  6   Duration              250 non-null    str
#  7   Content Rating        245 non-null    str
#  8   Rating                250 non-null    float64
#  9   Synopsis              250 non-null    str
#  10  Genre                 250 non-null    str
#  11  Tags                  250 non-null    str
#  12  Director              249 non-null    str
#  13  Screenwriter          249 non-null    str
#  14  Production companies  248 non-null    str
# dtypes: float64(1), int64(2), str(12)
# ...

# %% [markdown]
# D/P
# Handling missing values

# %%
df.isnull().sum()
# Out:
# Name                    0
# Aired Date              0
# Year of release         0
# Original Network        0
# Aired On                0
# Number of Episodes      0
# Duration                0
# Content Rating          5
# Rating                  0
# Synopsis                0
# Genre                   0
# Tags                    0
# Director                1
# Screenwriter            1
# Production companies    2
# dtype: int64

# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype

for col in df.columns:
    if df[col].isnull().any():
        
        if is_numeric_dtype(df[col]):
            df[col] = df[col].fillna(df[col].mean())

# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype

for col in df.columns:
    if df[col].isnull().any():
        
        if is_numeric_dtype(df[col]):
            df[col] = df[col].fillna(df[col].mean())
        else:
            mode_val = df[col].mode()
            if not mode_val.empty:
                df[col] = df[col].fillna(mode_val[0])

# %%
df.isnull().sum()
# Out:
# Name                    0
# Aired Date              0
# Year of release         0
# Original Network        0
# Aired On                0
# Number of Episodes      0
# Duration                0
# Content Rating          0
# Rating                  0
# Synopsis                0
# Genre                   0
# Tags                    0
# Director                0
# Screenwriter            0
# Production companies    0
# dtype: int64

# %%
df.head()
# Out:
#                   Name                   Aired Date  Year of release  \
# 0       Move to Heaven                 May 14, 2021             2021
# 1       Flower of Evil  Jul 29, 2020 - Sep 23, 2020             2020
# 2    Hospital Playlist  Mar 12, 2020 - May 28, 2020             2020
# 3  Hospital Playlist 2  Jun 17, 2021 - Sep 16, 2021             2021
# 4            My Mister  Mar 21, 2018 - May 17, 2018             2018
#
#   Original Network              Aired On  Number of Episodes       Duration  \
# 0          Netflix                Friday                  10        52 min.
# 1              tvN   Wednesday, Thursday                  16  1 hr. 10 min.
# 2   Netflix,  tvN               Thursday                  12  1 hr. 30 min.
# 3   Netflix,  tvN               Thursday                  12  1 hr. 40 min.
# 4              tvN   Wednesday, Thursday                  16  1 hr. 17 min.
#
#                           Content Rating  Rating  \
# ...

# %% [markdown]
# encoding

# %%
df.nunique()
# Out:
# Name                    250
# Aired Date              248
# Year of release          17
# Original Network         45
# Aired On                 21
# Number of Episodes       30
# Duration                 38
# Content Rating            4
# Rating                   10
# Synopsis                250
# Genre                   205
# Tags                    250
# Director                184
# Screenwriter            182
# Production companies    171
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

for col in df.columns:
	if df[col].dtype == 'object' or df[col].dtype == 'str':
		if df[col].nunique()<=5:
			dummies=pd.get_dummies(df[col], prefix=col, dtype=int)
			df=pd.concat([df.drop(columns=[col]), dummies], axis=1)
		else: df[col]=encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 18 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Name                                                  250 non-null    int64
#  1   Aired Date                                            250 non-null    int64
#  2   Year of release                                       250 non-null    int64
#  3   Original Network                                      250 non-null    int64
#  4   Aired On                                              250 non-null    int64
#  5   Number of Episodes                                    250 non-null    int64
#  6   Duration                                              250 non-null    int64
#  7   Rating                                                250 non-null    float64
# ...

# %%
df.head()
# Out:
#    Name  Aired Date  Year of release  Original Network  Aired On  \
# 0   132         159             2021                20         5
# 1    64          97             2020                43         4
# 2    84         131             2020                23        14
# 3    85         111             2021                23        14
# 4   139         138             2018                43         4
#
#    Number of Episodes  Duration  Rating  Synopsis  Genre  Tags  Director  \
# 0                  10        33     9.2        99    114    19        84
# 1                  16         1     9.1        48    175   121        53
# 2                  12        12     9.1       211     90   216       158
# 3                  12        15     9.1        84     90   247       158
# 4                  16         5     9.1       167    140    12        91
#
#    Screenwriter  Production companies  Content Rating_13+ - Teens 13 or older  \
# ...

# %% [markdown]
# Scaling

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 18 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Name                                                  250 non-null    int64
#  1   Aired Date                                            250 non-null    int64
#  2   Year of release                                       250 non-null    int64
#  3   Original Network                                      250 non-null    int64
#  4   Aired On                                              250 non-null    int64
#  5   Number of Episodes                                    250 non-null    int64
#  6   Duration                                              250 non-null    int64
#  7   Rating                                                250 non-null    float64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
scaler
# Out:
# MinMaxScaler()

# %%
print(df["Rating"].dtype)
# Out:
# float64

# %%
num_col=df.select_dtypes(include=["float64","int64"]).columns.drop("Rating", errors="ignore")

# %%
num_col
# Out:
# Index(['Name', 'Aired Date', 'Year of release', 'Original Network', 'Aired On',
#        'Number of Episodes', 'Duration', 'Synopsis', 'Genre', 'Tags',
#        'Director', 'Screenwriter', 'Production companies',
#        'Content Rating_13+ - Teens 13 or older',
#        'Content Rating_15+ - Teens 15 or older',
#        'Content Rating_18+ Restricted (violence & profanity)',
#        'Content Rating_G - All Ages'],
#       dtype='str')

# %%
df[num_col]=scaler.fit_transform(df[num_col])

# %%
df.head()
# Out:
#        Name  Aired Date  Year of release  Original Network  Aired On  \
# 0  0.530120    0.643725         0.947368          0.454545      0.25
# 1  0.257028    0.392713         0.894737          0.977273      0.20
# 2  0.337349    0.530364         0.894737          0.522727      0.70
# 3  0.341365    0.449393         0.947368          0.522727      0.70
# 4  0.558233    0.558704         0.789474          0.977273      0.20
#
#    Number of Episodes  Duration  Rating  Synopsis     Genre      Tags  \
# 0            0.068182  0.891892     9.2  0.397590  0.558824  0.076305
# 1            0.113636  0.027027     9.1  0.192771  0.857843  0.485944
# 2            0.083333  0.324324     9.1  0.847390  0.441176  0.867470
# 3            0.083333  0.405405     9.1  0.337349  0.441176  0.991968
# 4            0.113636  0.135135     9.1  0.670683  0.686275  0.048193
#
#    Director  Screenwriter  Production companies  \
# 0  0.459016      0.994475              0.570588
# ...

# %% [markdown]
# Model selection

# %%
from sklearn.linear_model import LinearRegression


lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# Training

# %%
x=df.drop("Rating", axis=1)

# %%
y=df["Rating"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([8.3644781 , 8.67409087, 8.61503833, 8.72736711, 8.52261163,
#        8.49090157, 8.49290828, 8.30401979, 8.378628  , 8.68843046,
#        8.61652205, 8.56964403, 8.47694935, 8.51642827, 8.679573  ,
#        8.52382725, 8.37140781, 8.63761144, 8.31369025, 8.47466994,
#        8.55412721, 8.61463387, 8.63930594, 8.65663211, 8.48045687,
#        8.67482772, 8.5830113 , 8.69088541, 8.60820242, 8.47854614,
#        8.52880679, 8.59490254, 8.37390808, 8.62699872, 8.54876467,
#        8.6450981 , 8.60103387, 8.45495281, 8.51059166, 8.34764657,
#        8.4993298 , 8.67516368, 8.63187388, 8.34255658, 8.44415099,
#        8.60978194, 8.43166177, 8.63634071, 8.27253451, 8.59756924])

# %%
df.head()
# Out:
#        Name  Aired Date  Year of release  Original Network  Aired On  \
# 0  0.530120    0.643725         0.947368          0.454545      0.25
# 1  0.257028    0.392713         0.894737          0.977273      0.20
# 2  0.337349    0.530364         0.894737          0.522727      0.70
# 3  0.341365    0.449393         0.947368          0.522727      0.70
# 4  0.558233    0.558704         0.789474          0.977273      0.20
#
#    Number of Episodes  Duration  Rating  Synopsis     Genre      Tags  \
# 0            0.068182  0.891892     9.2  0.397590  0.558824  0.076305
# 1            0.113636  0.027027     9.1  0.192771  0.857843  0.485944
# 2            0.083333  0.324324     9.1  0.847390  0.441176  0.867470
# 3            0.083333  0.405405     9.1  0.337349  0.441176  0.991968
# 4            0.113636  0.135135     9.1  0.670683  0.686275  0.048193
#
#    Director  Screenwriter  Production companies  \
# 0  0.459016      0.994475              0.570588
# ...

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("mae: ", mae)
print("mse: ", mse)
print("r2: ", r2)
# Out:
# mae:  0.16724937744899093
# mse:  0.044447840559384895
# r2:  0.23450260816710933
