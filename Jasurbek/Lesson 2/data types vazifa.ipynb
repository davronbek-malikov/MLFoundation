# %% [markdown]
# # Data Types

# %%
#int
#float
#str
#Boolean

# %%
#int
a=3
type(a)
# Out:
# int

# %%
#float
b=4.7
type(b)
# Out:
# float

# %%
a=3.0

type(a)
# Out:
# float

# %%
#astype(int)

# %%
#str
s='Hello'
type(s)
# Out:
# str

# %%
a='3'
type(s)
# Out:
# str

# %%
#Boolean
1>3
# Out:
# False

# %%
3==3
# Out:
# True

# %%
3!=3
# Out:
# False

# %% [markdown]
# # Indexing

# %%
s='Hello'
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# 'o'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn (1).csv')

# %%
df.head()

# %% [markdown]
# # Operations

# %%
# Math(+,-,*,/,//,%,**)
a=4
b=3
print(a/b)

# %%
print(a//b)   # butun qismini olish

# %%
print(a%b)  # qoldiq

# %%
print(a**b)    # sonning darajasi

# %%
print(pow(a,b))     # sonning darajasi

# %% [markdown]
# # Logic operations

# %%
# and---- ikkkala tomon togri bolish kk
# or ----- bitta tomon yoki ikkala tomon xam

# %% [markdown]
# # Comperative Operations

# %%
# >,<, ==, !=

# %% [markdown]
# # Vazifa

# %% [markdown]
# # Istalgan so'zni boshidagi va oxiridagi xarfini topadigan kod yozing
# # Berilgan ikki sonni musbat va juft ekanligini topadigan kod yozing
# # Berilgan so'zni oxiridan ikkinchi xarfini topadigan kod yozing
# # Istalgan sonni toq  yoki manfiy ekanligini tekshiradigan kod yozing

# %%
#Berilgan so'zni oxiridan ikkinchi xarfini topadigan kod yozing



s='Jasurbek'
s[0]
# Out:
# 'J'

# %%
s='jasurbek'
s[-2]
# Out:
# 'e'

# %%
s='jasurbek'
s[-5]
# Out:
# 'u'

# %%
a=4
print(a+5)
# Out:
# 9

# %%
a=4
b=8
c=-1
print(a+b/-1)
# Out:
# -4.0

# %%
# Istalgan sonni toq  yoki manfiy ekanligini tekshiradigan kod yozing


son = int(-5)
if son<0:
    print("bu son manfiy")
# Out:
# bu son manfiy

# %%
son = int(-2)
if son<0:
    print("bu son manfiy")
# Out:
# bu son manfiy

# %%
if son < -3:
    print("Holati: MANFIY")
elif son > 5:
    print("Holati: MUSBAT")
else:
    print("(6)")
# Out:
# (6)

# %%
# Istalgan so'zni boshidagi va oxiridagi xarfini topadigan kod yozing

# %%
s='ozbekison tengdir'
s[0]
# Out:
# 'o'

# %%
s='ozbekison tengdir'
s[-1]
# Out:
# 'r'
