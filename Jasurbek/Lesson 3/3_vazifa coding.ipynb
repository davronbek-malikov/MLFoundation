# %% [markdown]
# # Imtixondan o'tishni nazorat qilish uchun  condition tuzing

# %%
baxo=35
if baxo==50:
    print('alo')
elif baxo==40:
    print('yaxshi')
elif baxo==3:
    print('ortacha')
elif baxo==20:
    print('yomon')
else:
    print('qayta topshiruv')
# Out:
# qayta topshiruv

# %% [markdown]
# # Pasport olish uchun condition tuzing

# %%
yoshi=16
if yoshi>=16:
    print('sizga ruxsat')
elif yoshi<17:
    print('siz kech kelganz uchun jarima tolang')
    print('ariza yozing') 
else:print('sizga ruxsat yoq')
# Out:
# sizga ruxsat
