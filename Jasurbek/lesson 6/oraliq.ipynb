# %% [markdown]
# Agar berilgan son 2 ga bolinsa yaxshi aks holda yomon degan sozni ekranga chiqaring

# %%
son =6

if son % 2 == 0:
    print("yaxshi")
else:
    print("yomon")
# Out:
# yaxshi

# %% [markdown]
# Agar berilgan son musbat bolsa yaxshi aks holda yomon degan sozni ekranga chiqaring

# %%
son = -88
if son > 0:
    print("yaxshi")
else:
    print("yomon")
# Out:
# yomon

# %%
son=70
if son > 0:
    print("yaxshi")
else:
    print("yomon")
# Out:
# yaxshi

# %% [markdown]
# Agar berilgan son 5ga va 3ga bolinsa yaxshi aks holda yomon degan sozni ekranga chiqaring.

# %%
num=100
if num  % 5 == 0 and num % 3 ==0:
    print("yaxshi")
else:print("yomon")
# Out:
# yomon

# %% [markdown]
# Agar berilgan sozning oxirgi harfi "a" bo'lsa yaxshi aks holda yomon degan sozni ekranga chiwaring

# %%
str="qalesan"
if str [-1] == "a":
    print("yaxshi")
else:
    print("yomon")
# Out:
# yomon

# %% [markdown]
# Agar berilgan so'zning bosh harfi "b" va oxirgi harfi "a" bo'lsa yaxshi aks holda yomon degan so'zni ekranga chiwaring

# %%
str="bola"
if str[0]== "b" and str[-1]=="a":
    print("yaxshi")
else:print("yomon")
# Out:
# yaxshi

# %% [markdown]
# Berilgan sonning musbat ekanini isbotlang

# %%
num =5
if num >0:
   print("berilgan son musbat")
elif num ==0:
     print("berilgan son nolga teng")
else: print("berilgan son manfiy")
# Out:
# berilgan son musbat

# %% [markdown]
# Berilgan sonning manfiy ekanini isbotlang

# %%
num = -2
if num <0:
    print("berilgan son manfiy")
elif num >0:
    print("berilgan son musbat")
else:print("berilga son 0 ")
# Out:
# berilgan son manfiy

# %% [markdown]
# Berilgan sonning 2 ga bo'linishini isbotlang

# %%
num =40
if num %2==0:
    print("berilgan son ikkiga bolinadi")
else: print("berilgan son ikkiga bolinmaydi")
# Out:
# berilgan son ikkiga bolinadi
