# %% [markdown]
# # Encoding

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/sunnatabdurayimov/Downloads/Machine_Learning/ShahRukh_Khan.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Type             6 non-null      str
#  2    Country Origin   161 non-null    str
#  3    Director         193 non-null    str
#  4    Languages        193 non-null    str
#  5    Plot             193 non-null    str
#  6    Metascore        193 non-null    str
#  7    Genre            193 non-null    str
#  8    Rating           193 non-null    str
#  9    Relese Date      193 non-null    str
#  10   Rated            193 non-null    str
#  11   Awards           193 non-null    str
#  12   Actors           193 non-null    str
#  13   Poster link      193 non-null    str
# dtypes: str(14)
# memory usage: 21.2 KB

# %% [markdown]
# #drop
# #1-holat

# %%
df.columns.tolist()
# Out:
# ['Title ',
#  ' Type ',
#  ' Country Origin ',
#  ' Director ',
#  ' Languages ',
#  ' Plot ',
#  ' Metascore ',
#  ' Genre ',
#  ' Rating  ',
#  ' Relese Date ',
#  ' Rated ',
#  ' Awards ',
#  ' Actors ',
#  ' Poster link']

# %%
df.drop(' Director ', axis=1, inplace=True, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Type             6 non-null      str
#  2    Country Origin   161 non-null    str
#  3    Languages        193 non-null    str
#  4    Plot             193 non-null    str
#  5    Metascore        193 non-null    str
#  6    Genre            193 non-null    str
#  7    Rating           193 non-null    str
#  8    Relese Date      193 non-null    str
#  9    Rated            193 non-null    str
#  10   Awards           193 non-null    str
#  11   Actors           193 non-null    str
#  12   Poster link      193 non-null    str
# dtypes: str(13)
# memory usage: 19.7 KB

# %% [markdown]
# #drop
# #2-holat .qator bo'yicha

# %%
#df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Type             6 non-null      str
#  2    Country Origin   161 non-null    str
#  3    Languages        193 non-null    str
#  4    Plot             193 non-null    str
#  5    Metascore        193 non-null    str
#  6    Genre            193 non-null    str
#  7    Rating           193 non-null    str
#  8    Relese Date      193 non-null    str
#  9    Rated            193 non-null    str
#  10   Awards           193 non-null    str
#  11   Actors           193 non-null    str
#  12   Poster link      193 non-null    str
# dtypes: str(13)
# memory usage: 19.7 KB

# %%
df.isnull().sum()
# Out:
# Title                 0
#  Type               187
#  Country Origin      32
#  Languages            0
#  Plot                 0
#  Metascore            0
#  Genre                0
#  Rating               0
#  Relese Date          0
#  Rated                0
#  Awards               0
#  Actors               0
#  Poster link          0
# dtype: int64

# %%
df.fillna({' Type ':df[' Type '].mode()[0]},inplace=True)
# Out:
#                            Title      Type   Country Origin   \
# 0                           Don 3    movie            India
# 1     Rocketry: The Nambi Effect     movie            India
# 2       Koochie Koochie Hota Hai     movie            India
# 3                           Zero     movie            India
# 4                     Titu Talks    series            India
# ..                            ...       ...              ...
# 188                  Pehla Nasha     movie            India
# 189                       Rajani     movie            India
# 190                 Umang Tarang     movie            India
# 191                Golmaal Again     movie            India
# 192  101 Sexiest Celebrity Bodies    movie              USA
#
#                  Languages   \
# 0                    Hindi
# 1     Hindi& Tamil& Telugu
# 2                    Hindi
# 3                    Hindi
# 4                    Hindi
# ..                      ...
# 188                  Hindi
# ...

# %%
df.isnull().sum()
# Out:
# Title                0
#  Type                0
#  Country Origin     32
#  Languages           0
#  Plot                0
#  Metascore           0
#  Genre               0
#  Rating              0
#  Relese Date         0
#  Rated               0
#  Awards              0
#  Actors              0
#  Poster link         0
# dtype: int64

# %%
df.fillna({' Country Origin ':df[' Country Origin '].mode()[0]},inplace=True)
# Out:
#                            Title      Type   Country Origin   \
# 0                           Don 3    movie            India
# 1     Rocketry: The Nambi Effect     movie            India
# 2       Koochie Koochie Hota Hai     movie            India
# 3                           Zero     movie            India
# 4                     Titu Talks    series            India
# ..                            ...       ...              ...
# 188                  Pehla Nasha     movie            India
# 189                       Rajani     movie            India
# 190                 Umang Tarang     movie            India
# 191                Golmaal Again     movie            India
# 192  101 Sexiest Celebrity Bodies    movie              USA
#
#                  Languages   \
# 0                    Hindi
# 1     Hindi& Tamil& Telugu
# 2                    Hindi
# 3                    Hindi
# 4                    Hindi
# ..                      ...
# 188                  Hindi
# ...

# %%
df.isnull().sum()
# Out:
# Title               0
#  Type               0
#  Country Origin     0
#  Languages          0
#  Plot               0
#  Metascore          0
#  Genre              0
#  Rating             0
#  Relese Date        0
#  Rated              0
#  Awards             0
#  Actors             0
#  Poster link        0
# dtype: int64

# %%
df.nunique()
# Out:
# Title               164
#  Type                 3
#  Country Origin      14
#  Languages           30
#  Plot               135
#  Metascore           11
#  Genre               80
#  Rating              55
#  Relese Date        149
#  Rated               12
#  Awards              57
#  Actors             161
#  Poster link        135
# dtype: int64

# %% [markdown]
# # One-Hot encoding

# %%
dummies=pd.get_dummies(df[' Type '],prefix='col',dtype=int)

# %%
dummies
# Out:
#      col_   col_ movie   col_ series
# 0        0            1             0
# 1        0            1             0
# 2        0            1             0
# 3        0            1             0
# 4        0            0             1
# ..     ...          ...           ...
# 188      0            1             0
# 189      0            1             0
# 190      0            1             0
# 191      0            1             0
# 192      0            1             0
#
# [193 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Type             193 non-null    str
#  2    Country Origin   193 non-null    str
#  3    Languages        193 non-null    str
#  4    Plot             193 non-null    str
#  5    Metascore        193 non-null    str
#  6    Genre            193 non-null    str
#  7    Rating           193 non-null    str
#  8    Relese Date      193 non-null    str
#  9    Rated            193 non-null    str
#  10   Awards           193 non-null    str
#  11   Actors           193 non-null    str
#  12   Poster link      193 non-null    str
# dtypes: str(13)
# memory usage: 19.7 KB

# %%
df=pd.concat([df.drop(columns=[' Type ']),dummies])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 386 entries, 0 to 192
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Country Origin   193 non-null    str
#  2    Languages        193 non-null    str
#  3    Plot             193 non-null    str
#  4    Metascore        193 non-null    str
#  5    Genre            193 non-null    str
#  6    Rating           193 non-null    str
#  7    Relese Date      193 non-null    str
#  8    Rated            193 non-null    str
#  9    Awards           193 non-null    str
#  10   Actors           193 non-null    str
#  11   Poster link      193 non-null    str
#  12  col_              193 non-null    float64
#  13  col_ movie        193 non-null    float64
#  14  col_ series       193 non-null    float64
# dtypes: float64(3), str(12)
# memory usage: 48.2 KB

# %% [markdown]
# # df=pd.concat(df_1,df_2)- 2ta datasetni birlashtiruvchi kod

# %% [markdown]
# # Label encoding

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 386 entries, 0 to 192
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Country Origin   193 non-null    str
#  2    Languages        193 non-null    str
#  3    Plot             193 non-null    str
#  4    Metascore        193 non-null    str
#  5    Genre            193 non-null    str
#  6    Rating           193 non-null    str
#  7    Relese Date      193 non-null    str
#  8    Rated            193 non-null    str
#  9    Awards           193 non-null    str
#  10   Actors           193 non-null    str
#  11   Poster link      193 non-null    str
#  12  col_              193 non-null    float64
#  13  col_ movie        193 non-null    float64
#  14  col_ series       193 non-null    float64
# dtypes: float64(3), str(12)
# memory usage: 48.2 KB

# %%
# %pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
encoder
# Out:
# LabelEncoder()

# %%
df[' Country Origin ']=encoder.fit_transform(df[' Country Origin '])

# %%
df.head()
# Out:
#                         Title    Country Origin               Languages   \
# 0                        Don 3                 5                  Hindi
# 1  Rocketry: The Nambi Effect                  5   Hindi& Tamil& Telugu
# 2    Koochie Koochie Hota Hai                  5                  Hindi
# 3                        Zero                  5                  Hindi
# 4                  Titu Talks                  5                  Hindi
#
#                                                Plot   Metascore   \
# 0                                               N/A         N/A
# 1  Based by the life of ISRO Scientist Nambi Nara...        N/A
# 2  The film is an animated take on Kuch Kuch Hota...        N/A
# 3   The story revolves around Bauua Singh (Shah R...        N/A
# 4   Bhuvan Bam plays his famous character 'Titu M...        N/A
#
#                                   Genre   Rating    Relese Date        Rated   \
# ...

# %%
df[' Languages ']=encoder.fit_transform(df[' Languages '])

# %%
df[' Actors ']=encoder.fit_transform(df[' Actors '])

# %%
df.head()
# Out:
#                         Title    Country Origin    Languages   \
# 0                        Don 3                 5            6
# 1  Rocketry: The Nambi Effect                  5           17
# 2    Koochie Koochie Hota Hai                  5            6
# 3                        Zero                  5            6
# 4                  Titu Talks                  5            6
#
#                                                Plot   Metascore   \
# 0                                               N/A         N/A
# 1  Based by the life of ISRO Scientist Nambi Nara...        N/A
# 2  The film is an animated take on Kuch Kuch Hota...        N/A
# 3   The story revolves around Bauua Singh (Shah R...        N/A
# 4   Bhuvan Bam plays his famous character 'Titu M...        N/A
#
#                                   Genre   Rating    Relese Date        Rated   \
# 0                      Action& Thriller       N/A           N/A          N/A
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 386 entries, 0 to 192
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             193 non-null    str
#  1    Country Origin   386 non-null    int64
#  2    Languages        386 non-null    int64
#  3    Plot             193 non-null    str
#  4    Metascore        193 non-null    str
#  5    Genre            193 non-null    str
#  6    Rating           193 non-null    str
#  7    Relese Date      193 non-null    str
#  8    Rated            193 non-null    str
#  9    Awards           193 non-null    str
#  10   Actors           386 non-null    int64
#  11   Poster link      193 non-null    str
#  12  col_              193 non-null    float64
#  13  col_ movie        193 non-null    float64
#  14  col_ series       193 non-null    float64
# dtypes: float64(3), int64(3), str(9)
# memory usage: 48.2 KB
