# %% [markdown]
# # Data types

# %% [markdown]
# #int
# #float
# #str
# #Booleam

# %%
#int
a=3
type(a)
# Out:
# int

# %%
#float
b=3.5
type(b)
# Out:
# float

# %%
#str
c="Hello"
type(c)
# Out:
# str

# %%
#Booleam
2>4
# Out:
# False

# %%
#Booleam
5==5
# Out:
# True

# %% [markdown]
# # Operations

# %%
a=5
b=3
print(a-b)
# Out:
# 2

# %%
print(a/b)
# Out:
# 1.6666666666666667

# %%
a=5 #butun qismini olish
b=3
print(a//b)
# Out:
# 1

# %%
print(a%b)
# Out:
# 2

# %%
a=3 # sonning darajasi
b=4
print(a**b)
# Out:
# 81

# %%
print(pow(a,b)) #daraja
# Out:
# 81

# %% [markdown]
# # Logic Operatsions

# %% [markdown]
# #and ----ikkala tomon to'g'ri bo'lishi kerak
# #or----bitta tomon yoki ikkala tomon ham

# %% [markdown]
# # Comperative operations

# %% [markdown]
# # >,<,==,!=

# %% [markdown]
# # Indexing

# %%
s='Hello'
s[2]
# Out:
# 'l'

# %%
s[-4]
# Out:
# 'e'
